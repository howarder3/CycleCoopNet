# %%
# 导入pillow
from PIL import Image
from IPython.display import display # to display images
 
    
for i in range(1,12):
    
    # 加载原始图片
    img = Image.open("C:\\Users\\soslab\\Desktop\\val\\"+str(i)+"_AB.jpg")

    display(img)    
    # print(img.shape)

    # 从左上角开始 剪切 256*256的图片
    # (left, upper, right, lower)
    img2 = img.crop((0, 0, 256, 256))
    display(img2)    

    img2.save(str(i)+"_A.jpg")

    img3 = img.crop((256, 0, 512, 256))
    display(img3)    

    img3.save(str(i)+"_B.jpg")


    # width = img.size[0]  # 图片大小
    # height = img.size[1]
    # print(img.size)
    # img4 = img.crop(
    #     (
    #         width - 256,
    #         height - 256,
    #         width,
    #         height
    #     )
    # )
    # display(img4)

    # # img3.save("lena3.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x256 at 0x202BCAD3B70>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x202BCAD39E8>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x202BCA51588>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x256 at 0x202BCAD3A90>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x202BB9CA8D0>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x202BB8C8CC0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x256 at 0x202BCAD3A58>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x202BCA51588>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x202BB9CA8D0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x256 at 0x202BCAD3A20>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x202BCAD3A58>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x202BCA51588>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x256 at 0x202BCAD32E8>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x202BB9CA8D0>
# ...
