# %% [markdown]
# # TensorFlow Convolutional Neural Network for Image Classification

# %%
# !pip install cv2
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\soslab\appdata\local\conda\conda\envs\mlenv\lib\site-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\soslab\appdata\local\conda\conda\envs\mlenv\lib\site-packages (from opencv-python) (1.16.2)

# %%
import time
import math
import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import dataset
import cv2

from sklearn.metrics import confusion_matrix
from datetime import timedelta

# %matplotlib inline

# %% [markdown]
# ## Configuration and Hyperparameters

# %%
# Convolutional Layer 1.
filter_size1 = 3 
num_filters1 = 32

# Convolutional Layer 2.
filter_size2 = 3
num_filters2 = 32

# Convolutional Layer 3.
filter_size3 = 3
num_filters3 = 64

# Fully-connected layer.
fc_size = 128             # Number of neurons in fully-connected layer.

# Number of color channels for the images: 1 channel for gray-scale.
num_channels = 3

# image dimensions (only squares for now)
img_size = 128

# Size of image when flattened to a single dimension
img_size_flat = img_size * img_size * num_channels

# Tuple with height and width of images used to reshape arrays.
img_shape = (img_size, img_size)

# class info
classes = ['dogs', 'cats']
num_classes = len(classes)

# batch size
batch_size = 32

# validation split
validation_size = .16

# how long to wait after validation loss stops improving before terminating training
early_stopping = None  # use None if you don't want to implement early stoping

train_path = 'data/train/'
test_path = 'data/test/'
checkpoint_dir = "models/"

# %% [markdown]
# ## Load Data

# %%
data = dataset.read_train_sets(train_path, img_size, classes, validation_size=validation_size)
test_images, test_ids = dataset.read_test_set(test_path, img_size)
# Out:
# Reading training images
# Loading dogs files (Index: 0)
# Loading cats files (Index: 1)
# Reading test images

# %%
print("Size of:")
print("- Training-set:\t\t{}".format(len(data.train.labels)))
print("- Test-set:\t\t{}".format(len(test_images)))
print("- Validation-set:\t{}".format(len(data.valid.labels)))
# Out:
# Size of:
# - Training-set:		336
# - Test-set:		0
# - Validation-set:	64

# %% [markdown]
# ### Helper-function for plotting images

# %% [markdown]
# Function used to plot 9 images in a 3x3 grid (or fewer, depending on how many images are passed), and writing the true and predicted classes below each image.

# %%
def plot_images(images, cls_true, cls_pred=None):
    
    if len(images) == 0:
        print("no images to show")
        return 
    else:
        random_indices = random.sample(range(len(images)), min(len(images), 9))
        
    if cls_pred is not None:
        images, cls_true, cls_pred  = zip(*[(images[i], cls_true[i], cls_pred[i]) for i in random_indices])
    else:
        images, cls_true  = zip(*[(images[i], cls_true[i]) for i in random_indices])
    
    # Create figure with 3x3 sub-plots.
    fig, axes = plt.subplots(3, 3)
    fig.subplots_adjust(hspace=0.3, wspace=0.3)

    for i, ax in enumerate(axes.flat):
        # Plot image.
        ax.imshow(images[i].reshape(img_size, img_size, num_channels))

        # Show true and predicted classes.
        if cls_pred is None:
            xlabel = "True: {0}".format(cls_true[i])
        else:
            xlabel = "True: {0}, Pred: {1}".format(cls_true[i], cls_pred[i])

        # Show the classes as the label on the x-axis.
        ax.set_xlabel(xlabel)
        
        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])
    
    # Ensure the plot is shown correctly with multiple plots
    # in a single Notebook cell.
    plt.show()

# %% [markdown]
# ### Plot a few images to see if data is correct

# %%
# Get some random images and their labels from the train set.

images, cls_true  = data.train.images, data.train.cls

# Plot the images and labels using our helper-function above.
plot_images(images=images, cls_true=cls_true)

# %% [markdown]
# ## TensorFlow Graph
#
# The entire purpose of TensorFlow is to have a so-called computational graph that can be executed much more efficiently than if the same calculations were to be performed directly in Python. TensorFlow can be more efficient than NumPy because TensorFlow knows the entire computation graph that must be executed, while NumPy only knows the computation of a single mathematical operation at a time.
#
# TensorFlow can also automatically calculate the gradients that are needed to optimize the variables of the graph so as to make the model perform better. This is because the graph is a combination of simple mathematical expressions so the gradient of the entire graph can be calculated using the chain-rule for derivatives.
#
# A TensorFlow graph consists of the following parts which will be detailed below:
#
# * Placeholder variables used for inputting data to the graph.
# * Variables that are going to be optimized so as to make the convolutional network perform better.
# * The mathematical formulas for the convolutional network.
# * A cost measure that can be used to guide the optimization of the variables.
# * An optimization method which updates the variables.

# %% [markdown]
# ### Helper-functions for creating new variables

# %% [markdown]
# Functions for creating new TensorFlow variables in the given shape and initializing them with random values. Note that the initialization is not actually done at this point, it is merely being defined in the TensorFlow graph.

# %%
def new_weights(shape):
    return tf.Variable(tf.truncated_normal(shape, stddev=0.05))

# %%
def new_biases(length):
    return tf.Variable(tf.constant(0.05, shape=[length]))

# %% [markdown]
# ### Helper-function for creating a new Convolutional Layer

# %% [markdown]
# This function creates a new convolutional layer in the computational graph for TensorFlow. Nothing is actually calculated here, we are just adding the mathematical formulas to the TensorFlow graph.
#
# It is assumed that the input is a 4-dim tensor with the following dimensions:
#
# 1. Image number.
# 2. Y-axis of each image.
# 3. X-axis of each image.
# 4. Channels of each image.
#
# Note that the input channels may either be colour-channels, or it may be filter-channels if the input is produced from a previous convolutional layer.
#
# The output is another 4-dim tensor with the following dimensions:
#
# 1. Image number, same as input.
# 2. Y-axis of each image. If 2x2 pooling is used, then the height and width of the input images is divided by 2.
# 3. X-axis of each image. Ditto.
# 4. Channels produced by the convolutional filters.

# %%
def new_conv_layer(input,              # The previous layer.
                   num_input_channels, # Num. channels in prev. layer.
                   filter_size,        # Width and height of each filter.
                   num_filters,        # Number of filters.
                   use_pooling=True):  # Use 2x2 max-pooling.

    # Shape of the filter-weights for the convolution.
    # This format is determined by the TensorFlow API.
    shape = [filter_size, filter_size, num_input_channels, num_filters]

    # Create new weights aka. filters with the given shape.
    weights = new_weights(shape=shape)

    # Create new biases, one for each filter.
    biases = new_biases(length=num_filters)

    # Create the TensorFlow operation for convolution.
    # Note the strides are set to 1 in all dimensions.
    # The first and last stride must always be 1,
    # because the first is for the image-number and
    # the last is for the input-channel.
    # But e.g. strides=[1, 2, 2, 1] would mean that the filter
    # is moved 2 pixels across the x- and y-axis of the image.
    # The padding is set to 'SAME' which means the input image
    # is padded with zeroes so the size of the output is the same.
    layer = tf.nn.conv2d(input=input,
                         filter=weights,
                         strides=[1, 1, 1, 1],
                         padding='SAME')

    # Add the biases to the results of the convolution.
    # A bias-value is added to each filter-channel.
    layer += biases

    # Use pooling to down-sample the image resolution?
    if use_pooling:
        # This is 2x2 max-pooling, which means that we
        # consider 2x2 windows and select the largest value
        # in each window. Then we move 2 pixels to the next window.
        layer = tf.nn.max_pool(value=layer,
                               ksize=[1, 2, 2, 1],
                               strides=[1, 2, 2, 1],
                               padding='SAME')

    # Rectified Linear Unit (ReLU).
    # It calculates max(x, 0) for each input pixel x.
    # This adds some non-linearity to the formula and allows us
    # to learn more complicated functions.
    layer = tf.nn.relu(layer)

    # Note that ReLU is normally executed before the pooling,
    # but since relu(max_pool(x)) == max_pool(relu(x)) we can
    # save 75% of the relu-operations by max-pooling first.

    # We return both the resulting layer and the filter-weights
    # because we will plot the weights later.
    return layer, weights

# %% [markdown]
# ### Helper-function for flattening a layer
#
# A convolutional layer produces an output tensor with 4 dimensions. We will add fully-connected layers after the convolution layers, so we need to reduce the 4-dim tensor to 2-dim which can be used as input to the fully-connected layer.

# %%
def flatten_layer(layer):
    # Get the shape of the input layer.
    layer_shape = layer.get_shape()

    # The shape of the input layer is assumed to be:
    # layer_shape == [num_images, img_height, img_width, num_channels]

    # The number of features is: img_height * img_width * num_channels
    # We can use a function from TensorFlow to calculate this.
    num_features = layer_shape[1:4].num_elements()
    
    # Reshape the layer to [num_images, num_features].
    # Note that we just set the size of the second dimension
    # to num_features and the size of the first dimension to -1
    # which means the size in that dimension is calculated
    # so the total size of the tensor is unchanged from the reshaping.
    layer_flat = tf.reshape(layer, [-1, num_features])

    # The shape of the flattened layer is now:
    # [num_images, img_height * img_width * num_channels]

    # Return both the flattened layer and the number of features.
    return layer_flat, num_features

# %% [markdown]
# ### Helper-function for creating a new Fully-Connected Layer

# %% [markdown]
# This function creates a new fully-connected layer in the computational graph for TensorFlow. Nothing is actually calculated here, we are just adding the mathematical formulas to the TensorFlow graph.
#
# It is assumed that the input is a 2-dim tensor of shape `[num_images, num_inputs]`. The output is a 2-dim tensor of shape `[num_images, num_outputs]`.

# %%
def new_fc_layer(input,          # The previous layer.
                 num_inputs,     # Num. inputs from prev. layer.
                 num_outputs,    # Num. outputs.
                 use_relu=True): # Use Rectified Linear Unit (ReLU)?

    # Create new weights and biases.
    weights = new_weights(shape=[num_inputs, num_outputs])
    biases = new_biases(length=num_outputs)

    # Calculate the layer as the matrix multiplication of
    # the input and weights, and then add the bias-values.
    layer = tf.matmul(input, weights) + biases

    # Use ReLU?
    if use_relu:
        layer = tf.nn.relu(layer)

    return layer

# %% [markdown]
# ### Placeholder variables

# %% [markdown]
# Placeholder variables serve as the input to the TensorFlow computational graph that we may change each time we execute the graph. We call this feeding the placeholder variables and it is demonstrated further below.
#
# First we define the placeholder variable for the input images. This allows us to change the images that are input to the TensorFlow graph. This is a so-called tensor, which just means that it is a multi-dimensional vector or matrix. The data-type is set to `float32` and the shape is set to `[None, img_size_flat]`, where `None` means that the tensor may hold an arbitrary number of images with each image being a vector of length `img_size_flat`.

# %%
x = tf.placeholder(tf.float32, shape=[None, img_size_flat], name='x')

# %% [markdown]
# The convolutional layers expect `x` to be encoded as a 4-dim tensor so we have to reshape it so its shape is instead `[num_images, img_height, img_width, num_channels]`. Note that `img_height == img_width == img_size` and `num_images` can be inferred automatically by using -1 for the size of the first dimension. So the reshape operation is:

# %%
x_image = tf.reshape(x, [-1, img_size, img_size, num_channels])

# %% [markdown]
# Next we have the placeholder variable for the true labels associated with the images that were input in the placeholder variable `x`. The shape of this placeholder variable is `[None, num_classes]` which means it may hold an arbitrary number of labels and each label is a vector of length `num_classes`.

# %%
y_true = tf.placeholder(tf.float32, shape=[None, num_classes], name='y_true')

# %% [markdown]
# We could also have a placeholder variable for the class-number, but we will instead calculate it using argmax. Note that this is a TensorFlow operator so nothing is calculated at this point.

# %%
y_true_cls = tf.argmax(y_true, axis=1)

# %% [markdown]
# ### Convolutional Layer 1
#
# Create the first convolutional layer. It takes `x_image` as input and creates `num_filters1` different filters, each having width and height equal to `filter_size1`. Finally we wish to down-sample the image so it is half the size by using 2x2 max-pooling.

# %%
layer_conv1, weights_conv1 = \
    new_conv_layer(input=x_image,
                   num_input_channels=num_channels,
                   filter_size=filter_size1,
                   num_filters=num_filters1,
                   use_pooling=True)

# %%
layer_conv1
# Out:
# <tf.Tensor 'Relu:0' shape=(?, 64, 64, 32) dtype=float32>

# %% [markdown]
# ### Convolutional Layers 2 and 3
#
# Create the second and third convolutional layers, which take as input the output from the first and second convolutional layer respectively. The number of input channels corresponds to the number of filters in the previous convolutional layer.

# %%
layer_conv2, weights_conv2 = \
    new_conv_layer(input=layer_conv1,
                   num_input_channels=num_filters1,
                   filter_size=filter_size2,
                   num_filters=num_filters2,
                   use_pooling=True)

# %%
layer_conv2
# Out:
# <tf.Tensor 'Relu_1:0' shape=(?, 32, 32, 32) dtype=float32>

# %%
layer_conv3, weights_conv3 = \
    new_conv_layer(input=layer_conv2,
                   num_input_channels=num_filters2,
                   filter_size=filter_size3,
                   num_filters=num_filters3,
                   use_pooling=True)

# %%
layer_conv3
# Out:
# <tf.Tensor 'Relu_2:0' shape=(?, 16, 16, 64) dtype=float32>

# %% [markdown]
# ### Flatten Layer
#
# The convolutional layers output 4-dim tensors. We now wish to use these as input in a fully-connected network, which requires for the tensors to be reshaped or flattened to 2-dim tensors.

# %%
layer_flat, num_features = flatten_layer(layer_conv3)

# %%
layer_flat
# Out:
# <tf.Tensor 'Reshape_1:0' shape=(?, 16384) dtype=float32>

# %%
num_features
# Out:
# 16384

# %% [markdown]
# ### Fully-Connected Layer 1
#
# Add a fully-connected layer to the network. The input is the flattened layer from the previous convolution. The number of neurons or nodes in the fully-connected layer is `fc_size`. ReLU is used so we can learn non-linear relations.

# %%
layer_fc1 = new_fc_layer(input=layer_flat,
                         num_inputs=num_features,
                         num_outputs=fc_size,
                         use_relu=True)

# %% [markdown]
# Check that the output of the fully-connected layer is a tensor with shape (?, 128) where the ? means there is an arbitrary number of images and `fc_size` == 128.

# %%
layer_fc1
# Out:
# <tf.Tensor 'Relu_3:0' shape=(?, 128) dtype=float32>

# %% [markdown]
# ### Fully-Connected Layer 2
#
# Add another fully-connected layer that outputs vectors of length num_classes for determining which of the classes the input image belongs to. Note that ReLU is not used in this layer.

# %%
layer_fc2 = new_fc_layer(input=layer_fc1,
                         num_inputs=fc_size,
                         num_outputs=num_classes,
                         use_relu=False)

# %%
layer_fc2
# Out:
# <tf.Tensor 'add_4:0' shape=(?, 2) dtype=float32>

# %% [markdown]
# ### Predicted Class

# %% [markdown]
# The second fully-connected layer estimates how likely it is that the input image belongs to each of the 2 classes. However, these estimates are a bit rough and difficult to interpret because the numbers may be very small or large, so we want to normalize them so that each element is limited between zero and one and the all the elements sum to one. This is calculated using the so-called softmax function and the result is stored in `y_pred`.

# %%
y_pred = tf.nn.softmax(layer_fc2)

# %% [markdown]
# The class-number is the index of the largest element.

# %%
y_pred_cls = tf.argmax(y_pred, axis=1)

# %% [markdown]
# ### Cost-function to be optimized

# %% [markdown]
# To make the model better at classifying the input images, we must somehow change the variables for all the network layers. To do this we first need to know how well the model currently performs by comparing the predicted output of the model `y_pred` to the desired output `y_true`.
#
# The cross-entropy is a performance measure used in classification. The cross-entropy is a continuous function that is always positive and if the predicted output of the model exactly matches the desired output then the cross-entropy equals zero. The goal of optimization is therefore to minimize the cross-entropy so it gets as close to zero as possible by changing the variables of the network layers.
#
# TensorFlow has a built-in function for calculating the cross-entropy. Note that the function calculates the softmax internally so we must use the output of `layer_fc2` directly rather than `y_pred` which has already had the softmax applied.

# %%
cross_entropy = tf.nn.softmax_cross_entropy_with_logits_v2(logits=layer_fc2, labels=y_true)

# %% [markdown]
# We have now calculated the cross-entropy for each of the image classifications so we have a measure of how well the model performs on each image individually. But in order to use the cross-entropy to guide the optimization of the model's variables we need a single scalar value, so we simply take the average of the cross-entropy for all the image classifications.

# %%
cost = tf.reduce_mean(cross_entropy)

# %% [markdown]
# ### Optimization Method

# %% [markdown]
# Now that we have a cost measure that must be minimized, we can then create an optimizer. In this case it is the `AdamOptimizer` which is an advanced form of Gradient Descent.
#
# Note that optimization is not performed at this point. In fact, nothing is calculated at all, we just add the optimizer-object to the TensorFlow graph for later execution.

# %%
optimizer = tf.train.AdamOptimizer(learning_rate=1e-4).minimize(cost)

# %% [markdown]
# ### Performance Measures

# %% [markdown]
# We need a few more performance measures to display the progress to the user.
#
# This is a vector of booleans whether the predicted class equals the true class of each image.

# %%
correct_prediction = tf.equal(y_pred_cls, y_true_cls)

# %% [markdown]
# This calculates the classification accuracy by first type-casting the vector of booleans to floats, so that False becomes 0 and True becomes 1, and then calculating the average of these numbers.

# %%
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %% [markdown]
# ## TensorFlow Run

# %% [markdown]
# ### Create TensorFlow session
#
# Once the TensorFlow graph has been created, we have to create a TensorFlow session which is used to execute the graph.

# %%
session = tf.Session()

# %% [markdown]
# ### Initialize variables
#
# The variables for `weights` and `biases` must be initialized before we start optimizing them.

# %%
session.run(tf.global_variables_initializer())

# %% [markdown]
# ### Helper-function to perform optimization iterations

# %% [markdown]
# It takes a long time to calculate the gradient of the model using the entirety of a large dataset
# . We therefore only use a small batch of images in each iteration of the optimizer.
#
# If your computer crashes or becomes very slow because you run out of RAM, then you may try and lower this number, but you may then need to perform more optimization iterations.

# %%
train_batch_size = batch_size

# %%
def print_progress(epoch, feed_dict_train, feed_dict_validate, val_loss):
    # Calculate the accuracy on the training-set.
    acc = session.run(accuracy, feed_dict=feed_dict_train)
    val_acc = session.run(accuracy, feed_dict=feed_dict_validate)
    msg = "Epoch {0} --- Training Accuracy: {1:>6.1%}, Validation Accuracy: {2:>6.1%}, Validation Loss: {3:.3f}"
    print(msg.format(epoch + 1, acc, val_acc, val_loss))

# %% [markdown]
# Function for performing a number of optimization iterations so as to gradually improve the variables of the network layers. In each iteration, a new batch of data is selected from the training-set and then TensorFlow executes the optimizer using those training samples.  The progress is printed every 100 iterations.

# %%
# Counter for total number of iterations performed so far.
total_iterations = 0

def optimize(num_iterations):
    # Ensure we update the global variable rather than a local copy.
    global total_iterations

    # Start-time used for printing time-usage below.
    start_time = time.time()
    
    best_val_loss = float("inf")
    patience = 0

    for i in range(total_iterations,
                   total_iterations + num_iterations):

        # Get a batch of training examples.
        # x_batch now holds a batch of images and
        # y_true_batch are the true labels for those images.
        x_batch, y_true_batch, _, cls_batch = data.train.next_batch(train_batch_size)
        x_valid_batch, y_valid_batch, _, valid_cls_batch = data.valid.next_batch(train_batch_size)

        # Convert shape from [num examples, rows, columns, depth]
        # to [num examples, flattened image shape]

        x_batch = x_batch.reshape(train_batch_size, img_size_flat)
        x_valid_batch = x_valid_batch.reshape(train_batch_size, img_size_flat)

        # Put the batch into a dict with the proper names
        # for placeholder variables in the TensorFlow graph.
        feed_dict_train = {x: x_batch,
                           y_true: y_true_batch}
        
        feed_dict_validate = {x: x_valid_batch,
                              y_true: y_valid_batch}

        # Run the optimizer using this batch of training data.
        # TensorFlow assigns the variables in feed_dict_train
        # to the placeholder variables and then runs the optimizer.
        session.run(optimizer, feed_dict=feed_dict_train)
        

        # Print status at end of each epoch (defined as full pass through training dataset).
        if i % int(data.train.num_examples/batch_size) == 0: 
            val_loss = session.run(cost, feed_dict=feed_dict_validate)
            epoch = int(i / int(data.train.num_examples/batch_size))
            
            print_progress(epoch, feed_dict_train, feed_dict_validate, val_loss)
            
            if early_stopping:    
                if val_loss < best_val_loss:
                    best_val_loss = val_loss
                    patience = 0
                else:
                    patience += 1

                if patience == early_stopping:
                    break

    # Update the total number of iterations performed.
    total_iterations += num_iterations

    # Ending time.
    end_time = time.time()

    # Difference between start and end-times.
    time_dif = end_time - start_time

    # Print the time-usage.
    print("Time elapsed: " + str(timedelta(seconds=int(round(time_dif)))))

# %% [markdown]
# ### Helper-function to plot example errors

# %% [markdown]
# Function for plotting examples of images from the test-set that have been mis-classified.

# %%
def plot_example_errors(cls_pred, correct):
    # cls_pred is an array of the predicted class-number for
    # all images in the test-set.

    # correct is a boolean array whether the predicted class
    # is equal to the true class for each image in the test-set.

    # Negate the boolean array.
    incorrect = (correct == False)
    
    # Get the images from the test-set that have been
    # incorrectly classified.
    images = data.valid.images[incorrect]
    
    # Get the predicted classes for those images.
    cls_pred = cls_pred[incorrect]

    # Get the true classes for those images.
    cls_true = data.valid.cls[incorrect]

    # Plot the first 9 images.
    plot_images(images=images, cls_true=cls_true, cls_pred=cls_pred)

# %% [markdown]
# ### Helper-function to plot confusion matrix

# %%
def plot_confusion_matrix(cls_pred):
    # cls_pred is an array of the predicted class-number for
    # all images in the test-set.

    # Get the true classifications for the test-set.
    cls_true = data.valid.cls
    
    # Get the confusion matrix using sklearn.
    cm = confusion_matrix(y_true=cls_true,
                          y_pred=cls_pred)

    # Print the confusion matrix as text.
    print(cm)

    # Plot the confusion matrix as an image.
    plt.matshow(cm)

    # Make various adjustments to the plot.
    plt.colorbar()
    tick_marks = np.arange(num_classes)
    plt.xticks(tick_marks, range(num_classes))
    plt.yticks(tick_marks, range(num_classes))
    plt.xlabel('Predicted')
    plt.ylabel('True')

    # Ensure the plot is shown correctly with multiple plots
    # in a single Notebook cell.
    plt.show()

# %% [markdown]
# ### Helper-function for showing the performance

# %% [markdown]
# Function for printing the classification accuracy on the test-set.
#
# It takes a while to compute the classification for all the images in the test-set, that's why the results are re-used by calling the above functions directly from this function, so the classifications don't have to be recalculated by each function.
#
# Note that this function can use a lot of computer memory, which is why the test-set is split into smaller batches. If you have little RAM in your computer and it crashes, then you can try and lower the batch-size.

# %%
def print_validation_accuracy(show_example_errors=False, show_confusion_matrix=False):

    # Number of images in the test-set.
    num_test = len(data.valid.images)

    # Allocate an array for the predicted classes which
    # will be calculated in batches and filled into this array.
    cls_pred = np.zeros(shape=num_test, dtype=np.int)

    # Now calculate the predicted classes for the batches.
    # We will just iterate through all the batches.
    # There might be a more clever and Pythonic way of doing this.

    # The starting index for the next batch is denoted i.
    i = 0

    while i < num_test:
        # The ending index for the next batch is denoted j.
        j = min(i + batch_size, num_test)

        # Get the images from the test-set between index i and j.
        images = data.valid.images[i:j, :].reshape(batch_size, img_size_flat)
        

        # Get the associated labels.
        labels = data.valid.labels[i:j, :]

        # Create a feed-dict with these images and labels.
        feed_dict = {x: images,
                     y_true: labels}

        # Calculate the predicted class using TensorFlow.
        cls_pred[i:j] = session.run(y_pred_cls, feed_dict=feed_dict)

        # Set the start-index for the next batch to the
        # end-index of the current batch.
        i = j

    cls_true = np.array(data.valid.cls)
    cls_pred = np.array([classes[x] for x in cls_pred]) 

    # Create a boolean array whether each image is correctly classified.
    correct = (cls_true == cls_pred)

    # Calculate the number of correctly classified images.
    # When summing a boolean array, False means 0 and True means 1.
    correct_sum = correct.sum()

    # Classification accuracy is the number of correctly classified
    # images divided by the total number of images in the test-set.
    acc = float(correct_sum) / num_test

    # Print the accuracy.
    msg = "Accuracy on Test-Set: {0:.1%} ({1} / {2})"
    print(msg.format(acc, correct_sum, num_test))

    # Plot some examples of mis-classifications, if desired.
    if show_example_errors:
        print("Example errors:")
        plot_example_errors(cls_pred=cls_pred, correct=correct)

    # Plot the confusion matrix, if desired.
    if show_confusion_matrix:
        print("Confusion Matrix:")
        plot_confusion_matrix(cls_pred=cls_pred)

# %% [markdown]
# ## Performance after 1 optimization iteration

# %%
# !pip install --upgrade tensorflow-gpu==1.
# Out:
# Collecting tensorflow-gpu==1.
#   Could not find a version that satisfies the requirement tensorflow-gpu==1. (from versions: 1.2.0rc2, 1.2.0, 1.2.1, 1.3.0rc0, 1.3.0rc1, 1.3.0rc2, 1.3.0, 1.4.0rc0, 1.4.0rc1, 1.4.0, 1.5.0rc0, 1.5.0rc1, 1.5.0, 1.5.1, 1.6.0rc0, 1.6.0rc1, 1.6.0, 1.7.0rc0, 1.7.0rc1, 1.7.0, 1.7.1, 1.8.0rc0, 1.8.0rc1, 1.8.0, 1.9.0rc0, 1.9.0rc1, 1.9.0rc2, 1.9.0, 1.10.0rc0, 1.10.0rc1, 1.10.0, 1.11.0rc0, 1.11.0rc1, 1.11.0rc2, 1.11.0, 1.12.0rc0, 1.12.0rc1, 1.12.0rc2, 1.12.0, 1.12.2, 1.12.3, 1.13.0rc0, 1.13.0rc1, 1.13.0rc2, 1.13.1, 1.13.2, 1.14.0rc0, 1.14.0rc1, 1.14.0, 1.15.0rc0, 1.15.0rc1, 1.15.0rc2, 1.15.0rc3, 1.15.0, 2.0.0a0, 2.0.0b0, 2.0.0b1, 2.0.0rc0, 2.0.0rc1, 2.0.0rc2, 2.0.0)
# No matching distribution found for tensorflow-gpu==1.

# %%
optimize(num_iterations=1)
print_validation_accuracy()
# Out:
# Epoch 1 --- Training Accuracy:  46.9%, Validation Accuracy:  50.0%, Validation Loss: 0.691
# Time elapsed: 0:00:03
# Accuracy on Test-Set: 56.2% (36 / 64)

# %% [markdown]
# ## Performance after 100 optimization iterations
#
# After 100 optimization iterations, the model should have significantly improved its classification accuracy.

# %%
optimize(num_iterations=99)  # We already performed 1 iteration above.
# Out:
# Epoch 2 --- Training Accuracy:  53.1%, Validation Accuracy:  50.0%, Validation Loss: 0.727
# Epoch 3 --- Training Accuracy:  68.8%, Validation Accuracy:  56.2%, Validation Loss: 0.692
# Epoch 4 --- Training Accuracy:  59.4%, Validation Accuracy:  53.1%, Validation Loss: 0.696
# Epoch 5 --- Training Accuracy:  65.6%, Validation Accuracy:  53.1%, Validation Loss: 0.694
# Epoch 6 --- Training Accuracy:  65.6%, Validation Accuracy:  53.1%, Validation Loss: 0.696
# Epoch 7 --- Training Accuracy:  68.8%, Validation Accuracy:  46.9%, Validation Loss: 0.698
# Epoch 8 --- Training Accuracy:  75.0%, Validation Accuracy:  50.0%, Validation Loss: 0.699
# Epoch 9 --- Training Accuracy:  75.0%, Validation Accuracy:  50.0%, Validation Loss: 0.702
# Epoch 10 --- Training Accuracy:  71.9%, Validation Accuracy:  46.9%, Validation Loss: 0.703
# Time elapsed: 0:00:02

# %%
print_validation_accuracy(show_example_errors=True)
# Out:
# Accuracy on Test-Set: 39.1% (25 / 64)
# Example errors:

# %% [markdown]
# ## Performance after 1000 optimization iterations

# %%
optimize(num_iterations=900)  # We performed 100 iterations above.
# Out:
# Epoch 11 --- Training Accuracy:  71.9%, Validation Accuracy:  46.9%, Validation Loss: 0.704
# Epoch 12 --- Training Accuracy:  71.9%, Validation Accuracy:  46.9%, Validation Loss: 0.706
# Epoch 13 --- Training Accuracy:  71.9%, Validation Accuracy:  46.9%, Validation Loss: 0.706
# Epoch 14 --- Training Accuracy:  71.9%, Validation Accuracy:  46.9%, Validation Loss: 0.706
# Epoch 15 --- Training Accuracy:  68.8%, Validation Accuracy:  50.0%, Validation Loss: 0.712
# Epoch 16 --- Training Accuracy:  71.9%, Validation Accuracy:  50.0%, Validation Loss: 0.707
# Epoch 17 --- Training Accuracy:  71.9%, Validation Accuracy:  50.0%, Validation Loss: 0.706
# Epoch 18 --- Training Accuracy:  68.8%, Validation Accuracy:  50.0%, Validation Loss: 0.709
# Epoch 19 --- Training Accuracy:  71.9%, Validation Accuracy:  50.0%, Validation Loss: 0.709
# Epoch 20 --- Training Accuracy:  75.0%, Validation Accuracy:  50.0%, Validation Loss: 0.709
# Epoch 21 --- Training Accuracy:  71.9%, Validation Accuracy:  53.1%, Validation Loss: 0.713
# Epoch 22 --- Training Accuracy:  75.0%, Validation Accuracy:  53.1%, Validation Loss: 0.710
# Epoch 23 --- Training Accuracy:  75.0%, Validation Accuracy:  56.2%, Validation Loss: 0.710
# Epoch 24 --- Training Accuracy:  75.0%, Validation Accuracy:  56.2%, Validation Loss: 0.712
# Epoch 25 --- Training Accuracy:  71.9%, Validation Accuracy:  56.2%, Validation Loss: 0.718
# Epoch 26 --- Training Accuracy:  68.8%, Validation Accuracy:  56.2%, Validation Loss: 0.721
# Epoch 27 --- Training Accuracy:  68.8%, Validation Accuracy:  59.4%, Validation Loss: 0.725
# Epoch 28 --- Training Accuracy:  68.8%, Validation Accuracy:  62.5%, Validation Loss: 0.726
# Epoch 29 --- Training Accuracy:  75.0%, Validation Accuracy:  65.6%, Validation Loss: 0.729
# Epoch 30 --- Training Accuracy:  78.1%, Validation Accuracy:  65.6%, Validation Loss: 0.731
# Epoch 31 --- Training Accuracy:  75.0%, Validation Accuracy:  65.6%, Validation Loss: 0.734
# Epoch 32 --- Training Accuracy:  75.0%, Validation Accuracy:  65.6%, Validation Loss: 0.740
# Epoch 33 --- Training Accuracy:  75.0%, Validation Accuracy:  65.6%, Validation Loss: 0.745
# Epoch 34 --- Training Accuracy:  75.0%, Validation Accuracy:  56.2%, Validation Loss: 0.750
# Epoch 35 --- Training Accuracy:  78.1%, Validation Accuracy:  56.2%, Validation Loss: 0.753
# Epoch 36 --- Training Accuracy:  81.2%, Validation Accuracy:  56.2%, Validation Loss: 0.756
# Epoch 37 --- Training Accuracy:  81.2%, Validation Accuracy:  56.2%, Validation Loss: 0.762
# Epoch 38 --- Training Accuracy:  84.4%, Validation Accuracy:  56.2%, Validation Loss: 0.769
# Epoch 39 --- Training Accuracy:  84.4%, Validation Accuracy:  56.2%, Validation Loss: 0.775
# Epoch 40 --- Training Accuracy:  84.4%, Validation Accuracy:  56.2%, Validation Loss: 0.784
# Epoch 41 --- Training Accuracy:  84.4%, Validation Accuracy:  56.2%, Validation Loss: 0.795
# Epoch 42 --- Training Accuracy:  84.4%, Validation Accuracy:  59.4%, Validation Loss: 0.803
# Epoch 43 --- Training Accuracy:  84.4%, Validation Accuracy:  59.4%, Validation Loss: 0.813
# Epoch 44 --- Training Accuracy:  90.6%, Validation Accuracy:  59.4%, Validation Loss: 0.824
# Epoch 45 --- Training Accuracy:  93.8%, Validation Accuracy:  59.4%, Validation Loss: 0.831
# Epoch 46 --- Training Accuracy:  93.8%, Validation Accuracy:  59.4%, Validation Loss: 0.844
# Epoch 47 --- Training Accuracy:  96.9%, Validation Accuracy:  59.4%, Validation Loss: 0.852
# Epoch 48 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 0.867
# Epoch 49 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 0.878
# Epoch 50 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 0.893
# Epoch 51 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 0.907
# Epoch 52 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 0.924
# Epoch 53 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 0.940
# Epoch 54 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 0.957
# Epoch 55 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 0.975
# Epoch 56 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 1.001
# Epoch 57 --- Training Accuracy: 100.0%, Validation Accuracy:  46.9%, Validation Loss: 1.021
# Epoch 58 --- Training Accuracy: 100.0%, Validation Accuracy:  46.9%, Validation Loss: 1.052
# Epoch 59 --- Training Accuracy: 100.0%, Validation Accuracy:  46.9%, Validation Loss: 1.087
# Epoch 60 --- Training Accuracy: 100.0%, Validation Accuracy:  50.0%, Validation Loss: 1.130
# Epoch 61 --- Training Accuracy: 100.0%, Validation Accuracy:  50.0%, Validation Loss: 1.174
# Epoch 62 --- Training Accuracy: 100.0%, Validation Accuracy:  50.0%, Validation Loss: 1.192
# Epoch 63 --- Training Accuracy: 100.0%, Validation Accuracy:  43.8%, Validation Loss: 1.126
# Epoch 64 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.105
# Epoch 65 --- Training Accuracy:  93.8%, Validation Accuracy:  65.6%, Validation Loss: 1.190
# Epoch 66 --- Training Accuracy: 100.0%, Validation Accuracy:  65.6%, Validation Loss: 1.182
# Epoch 67 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.067
# Epoch 68 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 1.102
# Epoch 69 --- Training Accuracy: 100.0%, Validation Accuracy:  65.6%, Validation Loss: 1.156
# Epoch 70 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 1.206
# Epoch 71 --- Training Accuracy: 100.0%, Validation Accuracy:  65.6%, Validation Loss: 1.211
# Epoch 72 --- Training Accuracy: 100.0%, Validation Accuracy:  65.6%, Validation Loss: 1.222
# Epoch 73 --- Training Accuracy: 100.0%, Validation Accuracy:  65.6%, Validation Loss: 1.245
# Epoch 74 --- Training Accuracy: 100.0%, Validation Accuracy:  65.6%, Validation Loss: 1.272
# Epoch 75 --- Training Accuracy: 100.0%, Validation Accuracy:  65.6%, Validation Loss: 1.296
# Epoch 76 --- Training Accuracy: 100.0%, Validation Accuracy:  65.6%, Validation Loss: 1.319
# Epoch 77 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 1.342
# Epoch 78 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 1.361
# Epoch 79 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.384
# Epoch 80 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.407
# Epoch 81 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.428
# Epoch 82 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.446
# Epoch 83 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.469
# Epoch 84 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.486
# Epoch 85 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.507
# Epoch 86 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.525
# Epoch 87 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.547
# Epoch 88 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.565
# Epoch 89 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.588
# Epoch 90 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.600
# Epoch 91 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.622
# Epoch 92 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.638
# Epoch 93 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.655
# Epoch 94 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.673
# Epoch 95 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.691
# Epoch 96 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.710
# Epoch 97 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.723
# Epoch 98 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.742
# Epoch 99 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.761
# Epoch 100 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.773
# Time elapsed: 0:00:14

# %%
print_validation_accuracy(show_example_errors=True)
# Out:
# Accuracy on Test-Set: 50.0% (32 / 64)
# Example errors:

# %% [markdown]
# ## Performance after 10,000 optimization iterations

# %%
optimize(num_iterations=9000) # We performed 1000 iterations above.
# Out:
# Epoch 101 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.791
# Epoch 102 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.804
# Epoch 103 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.821
# Epoch 104 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.835
# Epoch 105 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.853
# Epoch 106 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.864
# Epoch 107 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.879
# Epoch 108 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.892
# Epoch 109 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.910
# Epoch 110 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.920
# Epoch 111 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.936
# Epoch 112 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.949
# Epoch 113 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.959
# Epoch 114 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.973
# Epoch 115 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.987
# Epoch 116 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.996
# Epoch 117 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.011
# Epoch 118 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.020
# Epoch 119 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.032
# Epoch 120 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.044
# Epoch 121 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.055
# Epoch 122 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.067
# Epoch 123 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.076
# Epoch 124 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.087
# Epoch 125 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.098
# Epoch 126 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.107
# Epoch 127 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.120
# Epoch 128 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.126
# Epoch 129 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.139
# Epoch 130 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.148
# Epoch 131 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.160
# Epoch 132 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.168
# Epoch 133 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.178
# Epoch 134 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.186
# Epoch 135 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.198
# Epoch 136 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.204
# Epoch 137 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.214
# Epoch 138 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.222
# Epoch 139 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.234
# Epoch 140 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.240
# Epoch 141 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.250
# Epoch 142 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.258
# Epoch 143 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.266
# Epoch 144 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.275
# Epoch 145 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.286
# Epoch 146 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.290
# Epoch 147 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.301
# Epoch 148 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.308
# Epoch 149 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.317
# Epoch 150 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.323
# Epoch 151 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.333
# Epoch 152 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.339
# Epoch 153 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.350
# Epoch 154 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.354
# Epoch 155 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.364
# Epoch 156 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.371
# Epoch 157 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.379
# Epoch 158 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.386
# Epoch 159 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.393
# Epoch 160 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.401
# Epoch 161 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.406
# Epoch 162 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.417
# Epoch 163 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.422
# Epoch 164 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.430
# Epoch 165 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.437
# Epoch 166 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.447
# Epoch 167 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.449
# Epoch 168 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.457
# Epoch 169 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.464
# Epoch 170 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.471
# Epoch 171 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.477
# Epoch 172 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.483
# Epoch 173 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.492
# Epoch 174 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.496
# Epoch 175 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.504
# Epoch 176 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.509
# Epoch 177 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.516
# Epoch 178 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.523
# Epoch 179 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.529
# Epoch 180 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.535
# Epoch 181 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.541
# Epoch 182 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.548
# Epoch 183 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.554
# Epoch 184 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.559
# Epoch 185 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.568
# Epoch 186 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.571
# Epoch 187 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.578
# Epoch 188 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.583
# Epoch 189 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.591
# Epoch 190 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.594
# Epoch 191 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.604
# Epoch 192 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.607
# Epoch 193 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.613
# Epoch 194 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.619
# Epoch 195 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.624
# Epoch 196 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.633
# Epoch 197 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.634
# Epoch 198 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.640
# Epoch 199 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.648
# Epoch 200 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.652
# Epoch 201 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.657
# Epoch 202 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.663
# Epoch 203 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.668
# Epoch 204 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.673
# Epoch 205 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.681
# Epoch 206 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.684
# Epoch 207 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.689
# Epoch 208 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.696
# Epoch 209 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.700
# Epoch 210 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.707
# Epoch 211 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.711
# Epoch 212 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.717
# Epoch 213 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.722
# Epoch 214 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.725
# Epoch 215 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.734
# Epoch 216 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.736
# Epoch 217 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.741
# Epoch 218 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.747
# Epoch 219 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.752
# Epoch 220 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.756
# Epoch 221 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.762
# Epoch 222 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.766
# Epoch 223 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.773
# Epoch 224 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.776
# Epoch 225 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.780
# Epoch 226 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.786
# Epoch 227 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.791
# Epoch 228 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.795
# Epoch 229 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.800
# Epoch 230 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.804
# Epoch 231 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.810
# Epoch 232 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.814
# Epoch 233 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.818
# Epoch 234 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.823
# Epoch 235 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.828
# Epoch 236 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.832
# Epoch 237 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.838
# Epoch 238 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.841
# Epoch 239 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.848
# Epoch 240 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.850
# Epoch 241 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.856
# Epoch 242 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.859
# Epoch 243 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.866
# Epoch 244 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.868
# Epoch 245 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.873
# Epoch 246 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.877
# Epoch 247 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.882
# Epoch 248 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.888
# Epoch 249 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.890
# Epoch 250 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.896
# Epoch 251 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.898
# Epoch 252 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.904
# Epoch 253 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.907
# Epoch 254 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.913
# Epoch 255 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.916
# Epoch 256 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.920
# Epoch 257 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.924
# Epoch 258 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.928
# Epoch 259 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.932
# Epoch 260 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.938
# Epoch 261 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.941
# Epoch 262 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.946
# Epoch 263 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.950
# Epoch 264 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.954
# Epoch 265 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.957
# Epoch 266 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.963
# Epoch 267 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.965
# Epoch 268 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.970
# Epoch 269 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.973
# Epoch 270 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.979
# Epoch 271 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.981
# Epoch 272 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.986
# Epoch 273 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.989
# Epoch 274 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.994
# Epoch 275 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 2.998
# Epoch 276 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.002
# Epoch 277 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.005
# Epoch 278 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.010
# Epoch 279 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.012
# Epoch 280 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.019
# Epoch 281 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.020
# Epoch 282 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.025
# Epoch 283 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.028
# Epoch 284 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.033
# Epoch 285 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.036
# Epoch 286 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.041
# Epoch 287 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.043
# Epoch 288 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.048
# Epoch 289 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.051
# Epoch 290 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.056
# Epoch 291 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.059
# Epoch 292 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.063
# Epoch 293 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.066
# Epoch 294 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.071
# Epoch 295 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.074
# Epoch 296 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.078
# Epoch 297 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.082
# Epoch 298 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.085
# Epoch 299 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.090
# Epoch 300 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.093
# Epoch 301 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.097
# Epoch 302 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.099
# Epoch 303 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.105
# Epoch 304 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.106
# Epoch 305 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.110
# Epoch 306 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.115
# Epoch 307 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.117
# Epoch 308 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.123
# Epoch 309 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.124
# Epoch 310 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.129
# Epoch 311 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.131
# Epoch 312 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.135
# Epoch 313 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.139
# Epoch 314 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.142
# Epoch 315 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.146
# Epoch 316 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.149
# Epoch 317 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.153
# Epoch 318 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.156
# Epoch 319 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.160
# Epoch 320 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.163
# Epoch 321 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.166
# Epoch 322 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.169
# Epoch 323 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.176
# Epoch 324 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.177
# Epoch 325 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.180
# Epoch 326 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.185
# Epoch 327 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.187
# Epoch 328 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.190
# Epoch 329 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.194
# Epoch 330 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.198
# Epoch 331 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.201
# Epoch 332 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.204
# Epoch 333 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.207
# Epoch 334 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.211
# Epoch 335 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.215
# Epoch 336 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.217
# Epoch 337 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.222
# Epoch 338 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.223
# Epoch 339 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.228
# Epoch 340 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.231
# Epoch 341 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.234
# Epoch 342 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.237
# Epoch 343 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.240
# Epoch 344 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.244
# Epoch 345 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.247
# Epoch 346 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.250
# Epoch 347 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.254
# Epoch 348 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.256
# Epoch 349 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.261
# Epoch 350 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.263
# Epoch 351 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.267
# Epoch 352 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.270
# Epoch 353 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.274
# Epoch 354 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.276
# Epoch 355 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.280
# Epoch 356 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.283
# Epoch 357 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.287
# Epoch 358 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.289
# Epoch 359 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.293
# Epoch 360 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.295
# Epoch 361 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.300
# Epoch 362 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.302
# Epoch 363 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.306
# Epoch 364 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.308
# Epoch 365 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.312
# Epoch 366 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.314
# Epoch 367 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.318
# Epoch 368 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.321
# Epoch 369 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.324
# Epoch 370 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.328
# Epoch 371 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.330
# Epoch 372 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.334
# Epoch 373 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.336
# Epoch 374 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.341
# Epoch 375 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.342
# Epoch 376 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.346
# Epoch 377 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.349
# Epoch 378 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.353
# Epoch 379 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.355
# Epoch 380 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.358
# Epoch 381 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.362
# Epoch 382 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.364
# Epoch 383 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.368
# Epoch 384 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.371
# Epoch 385 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.374
# Epoch 386 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.377
# Epoch 387 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.381
# Epoch 388 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.383
# Epoch 389 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.385
# Epoch 390 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.389
# Epoch 391 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.392
# Epoch 392 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.396
# Epoch 393 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.397
# Epoch 394 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.402
# Epoch 395 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 3.403
# Epoch 396 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.407
# Epoch 397 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.409
# Epoch 398 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.414
# Epoch 399 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.415
# Epoch 400 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.419
# Epoch 401 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.422
# Epoch 402 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.425
# Epoch 403 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.427
# Epoch 404 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.431
# Epoch 405 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.434
# Epoch 406 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.436
# Epoch 407 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.439
# Epoch 408 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.442
# Epoch 409 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.445
# Epoch 410 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.448
# Epoch 411 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.451
# Epoch 412 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.455
# Epoch 413 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.456
# Epoch 414 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.460
# Epoch 415 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.462
# Epoch 416 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.466
# Epoch 417 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.469
# Epoch 418 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.471
# Epoch 419 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.475
# Epoch 420 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.477
# Epoch 421 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.480
# Epoch 422 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.482
# Epoch 423 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.485
# Epoch 424 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.488
# Epoch 425 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.491
# Epoch 426 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.494
# Epoch 427 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.497
# Epoch 428 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.499
# Epoch 429 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.503
# Epoch 430 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.505
# Epoch 431 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.509
# Epoch 432 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.511
# Epoch 433 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.515
# Epoch 434 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.516
# Epoch 435 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.519
# Epoch 436 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.522
# Epoch 437 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.525
# Epoch 438 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.527
# Epoch 439 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.531
# Epoch 440 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.533
# Epoch 441 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.537
# Epoch 442 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.538
# Epoch 443 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.542
# Epoch 444 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.544
# Epoch 445 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.547
# Epoch 446 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.551
# Epoch 447 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.552
# Epoch 448 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.556
# Epoch 449 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.559
# Epoch 450 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.561
# Epoch 451 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.565
# Epoch 452 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.566
# Epoch 453 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.571
# Epoch 454 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.572
# Epoch 455 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.575
# Epoch 456 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.577
# Epoch 457 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.580
# Epoch 458 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.583
# Epoch 459 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.587
# Epoch 460 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.588
# Epoch 461 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.591
# Epoch 462 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.594
# Epoch 463 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.597
# Epoch 464 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.599
# Epoch 465 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.602
# Epoch 466 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.604
# Epoch 467 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.609
# Epoch 468 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.610
# Epoch 469 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.613
# Epoch 470 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.615
# Epoch 471 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.617
# Epoch 472 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.622
# Epoch 473 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.623
# Epoch 474 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.626
# Epoch 475 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.629
# Epoch 476 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.631
# Epoch 477 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.634
# Epoch 478 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.636
# Epoch 479 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.641
# Epoch 480 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.642
# Epoch 481 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.645
# Epoch 482 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.647
# Epoch 483 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.650
# Epoch 484 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.653
# Epoch 485 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.656
# Epoch 486 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.658
# Epoch 487 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.661
# Epoch 488 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.663
# Epoch 489 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.666
# Epoch 490 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.669
# Epoch 491 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.672
# Epoch 492 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.674
# Epoch 493 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.678
# Epoch 494 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.679
# Epoch 495 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.682
# Epoch 496 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.685
# Epoch 497 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.688
# Epoch 498 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.690
# Epoch 499 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.692
# Epoch 500 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.695
# Epoch 501 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.698
# Epoch 502 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.700
# Epoch 503 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.704
# Epoch 504 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.705
# Epoch 505 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.707
# Epoch 506 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.710
# Epoch 507 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.713
# Epoch 508 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.716
# Epoch 509 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.718
# Epoch 510 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.721
# Epoch 511 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.724
# Epoch 512 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.727
# Epoch 513 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.729
# Epoch 514 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.731
# Epoch 515 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.735
# Epoch 516 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.736
# Epoch 517 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.739
# Epoch 518 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.742
# Epoch 519 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.743
# Epoch 520 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.747
# Epoch 521 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.749
# Epoch 522 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.754
# Epoch 523 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.755
# Epoch 524 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.757
# Epoch 525 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.761
# Epoch 526 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.762
# Epoch 527 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.765
# Epoch 528 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.767
# Epoch 529 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.770
# Epoch 530 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.773
# Epoch 531 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.775
# Epoch 532 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.778
# Epoch 533 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.780
# Epoch 534 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.784
# Epoch 535 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.785
# Epoch 536 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.789
# Epoch 537 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.790
# Epoch 538 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.794
# Epoch 539 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.795
# Epoch 540 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.799
# Epoch 541 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.800
# Epoch 542 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.804
# Epoch 543 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.805
# Epoch 544 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.808
# Epoch 545 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.810
# Epoch 546 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.814
# Epoch 547 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.813
# Epoch 548 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.816
# Epoch 549 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.816
# Epoch 550 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.817
# Epoch 551 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.820
# Epoch 552 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.822
# Epoch 553 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.825
# Epoch 554 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.828
# Epoch 555 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.831
# Epoch 556 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.832
# Epoch 557 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.835
# Epoch 558 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.836
# Epoch 559 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.839
# Epoch 560 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.842
# Epoch 561 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.844
# Epoch 562 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.846
# Epoch 563 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.849
# Epoch 564 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.852
# Epoch 565 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.855
# Epoch 566 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.859
# Epoch 567 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.861
# Epoch 568 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.866
# Epoch 569 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.869
# Epoch 570 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.873
# Epoch 571 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.877
# Epoch 572 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.883
# Epoch 573 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.888
# Epoch 574 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.895
# Epoch 575 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.899
# Epoch 576 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.903
# Epoch 577 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.907
# Epoch 578 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.910
# Epoch 579 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.913
# Epoch 580 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.921
# Epoch 581 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.925
# Epoch 582 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.923
# Epoch 583 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.926
# Epoch 584 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.937
# Epoch 585 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.937
# Epoch 586 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.940
# Epoch 587 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.945
# Epoch 588 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.945
# Epoch 589 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.948
# Epoch 590 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.952
# Epoch 591 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.960
# Epoch 592 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.961
# Epoch 593 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.962
# Epoch 594 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.969
# Epoch 595 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.975
# Epoch 596 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.980
# Epoch 597 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.976
# Epoch 598 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.980
# Epoch 599 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.988
# Epoch 600 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.993
# Epoch 601 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.997
# Epoch 602 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.995
# Epoch 603 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 3.994
# Epoch 604 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.003
# Epoch 605 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.011
# Epoch 606 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.009
# Epoch 607 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.005
# Epoch 608 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.015
# Epoch 609 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.016
# Epoch 610 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.020
# Epoch 611 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.021
# Epoch 612 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.024
# Epoch 613 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.025
# Epoch 614 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.029
# Epoch 615 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.040
# Epoch 616 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.038
# ...
# Epoch 830 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.582
# Epoch 831 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.578
# Epoch 832 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.576
# Epoch 833 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.581
# Epoch 834 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.588
# Epoch 835 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.590
# Epoch 836 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 4.571
# Epoch 837 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.598
# Epoch 838 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.596
# Epoch 839 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.594
# Epoch 840 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.600
# Epoch 841 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 4.597
# Epoch 842 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 4.604
# Epoch 843 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.611
# Epoch 844 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.610
# Epoch 845 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 4.604
# Epoch 846 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.619
# Epoch 847 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.619
# Epoch 848 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 4.618
# Epoch 849 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.624
# Epoch 850 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.626
# Epoch 851 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.627
# Epoch 852 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.620
# Epoch 853 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.632
# Epoch 854 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.632
# Epoch 855 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 4.621
# Epoch 856 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.640
# Epoch 857 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.636
# Epoch 858 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 4.630
# Epoch 859 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.649
# Epoch 860 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 4.636
# Epoch 861 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.649
# Epoch 862 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 4.640
# Epoch 863 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.656
# Epoch 864 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.660
# Epoch 865 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.658
# Epoch 866 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.655
# Epoch 867 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.662
# Epoch 868 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.663
# Epoch 869 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.663
# Epoch 870 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.663
# Epoch 871 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.671
# Epoch 872 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.672
# Epoch 873 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.668
# Epoch 874 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.674
# Epoch 875 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.677
# Epoch 876 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.674
# Epoch 877 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.681
# Epoch 878 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.684
# Epoch 879 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.687
# Epoch 880 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.688
# Epoch 881 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.682
# Epoch 882 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.690
# Epoch 883 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.695
# Epoch 884 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.692
# Epoch 885 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 4.689
# Epoch 886 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.700
# Epoch 887 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.698
# Epoch 888 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.703
# Epoch 889 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.704
# Epoch 890 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.710
# Epoch 891 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.712
# Epoch 892 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.711
# Epoch 893 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.714
# Epoch 894 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.717
# Epoch 895 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.719
# Epoch 896 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.714
# Epoch 897 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.721
# Epoch 898 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.725
# Epoch 899 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.727
# Epoch 900 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.729
# Epoch 901 --- Training Accuracy: 100.0%, Validation Accuracy:  53.1%, Validation Loss: 4.719
# Epoch 902 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.737
# Epoch 903 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.736
# Epoch 904 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.735
# Epoch 905 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.733
# Epoch 906 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.740
# Epoch 907 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.745
# Epoch 908 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.744
# Epoch 909 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.741
# Epoch 910 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.753
# Epoch 911 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.744
# Epoch 912 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.751
# Epoch 913 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.749
# Epoch 914 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.757
# Epoch 915 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.759
# Epoch 916 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.763
# Epoch 917 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.764
# Epoch 918 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.766
# Epoch 919 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.764
# Epoch 920 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.768
# Epoch 921 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.771
# Epoch 922 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.775
# Epoch 923 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.773
# Epoch 924 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.772
# Epoch 925 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.779
# Epoch 926 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.775
# Epoch 927 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.783
# Epoch 928 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.771
# Epoch 929 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.788
# Epoch 930 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.783
# Epoch 931 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.788
# Epoch 932 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.793
# Epoch 933 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.797
# Epoch 934 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.799
# Epoch 935 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.801
# Epoch 936 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.801
# Epoch 937 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.804
# Epoch 938 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.805
# Epoch 939 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.802
# Epoch 940 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.806
# Epoch 941 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.810
# Epoch 942 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.816
# Epoch 943 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.816
# Epoch 944 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.811
# Epoch 945 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.817
# Epoch 946 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.817
# Epoch 947 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.827
# Epoch 948 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.828
# Epoch 949 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.817
# Epoch 950 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.825
# Epoch 951 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.833
# Epoch 952 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.833
# Epoch 953 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.828
# Epoch 954 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.836
# Epoch 955 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.837
# Epoch 956 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.841
# Epoch 957 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.844
# Epoch 958 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.843
# Epoch 959 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.841
# Epoch 960 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.846
# Epoch 961 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.840
# Epoch 962 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.847
# Epoch 963 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.848
# Epoch 964 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.838
# Epoch 965 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.857
# Epoch 966 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.863
# Epoch 967 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.866
# Epoch 968 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.867
# Epoch 969 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.863
# Epoch 970 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.870
# Epoch 971 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.873
# Epoch 972 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.873
# Epoch 973 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.873
# Epoch 974 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.869
# Epoch 975 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.874
# Epoch 976 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.879
# Epoch 977 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.880
# Epoch 978 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.885
# Epoch 979 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.886
# Epoch 980 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.889
# Epoch 981 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.892
# Epoch 982 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.894
# Epoch 983 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.895
# Epoch 984 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.898
# Epoch 985 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.893
# Epoch 986 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.898
# Epoch 987 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.894
# Epoch 988 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.907
# Epoch 989 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.900
# Epoch 990 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.904
# Epoch 991 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.910
# Epoch 992 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.901
# Epoch 993 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.909
# Epoch 994 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.911
# Epoch 995 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.915
# Epoch 996 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.919
# Epoch 997 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.916
# Epoch 998 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.924
# Epoch 999 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.925
# Epoch 1000 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 4.928
# Time elapsed: 0:02:19

# %%
print_validation_accuracy(show_example_errors=True, show_confusion_matrix=True)
# Out:
# Accuracy on Test-Set: 51.6% (33 / 64)
# Example errors:
# Confusion Matrix:
# [[17 19]
#  [12 16]]

# %% [markdown]
# ## Test on Sample Image

# %%
plt.axis('off')

test_cat = cv2.imread('.\\data\\test\\2.jpg')
# print(test_cat)
cv2.imshow('My Image', test_cat)

test_cat = cv2.resize(test_cat, (img_size, img_size), cv2.INTER_LINEAR) / 255

preview_cat = plt.imshow(test_cat.reshape(img_size, img_size, num_channels))

# %%
img_size
# Out:
# 128

# %%
test_dog = cv2.imread('.\\data\\test\\1.jpg')

cv2.imshow('My Image', test_dog)

test_dog = cv2.resize(test_dog, (img_size, img_size), cv2.INTER_LINEAR) / 255

preview_dog = plt.imshow(test_dog.reshape(img_size, img_size, num_channels))

# %%
def sample_prediction(test_im):
    
    feed_dict_test = {
        x: test_im.reshape(1, img_size_flat),
        y_true: np.array([[1, 0]])
    }

    score, test_pred = session.run([y_pred, y_pred_cls] , feed_dict=feed_dict_test)
#     return classes[test_pred[0]]
    return score


np.set_printoptions(suppress=True)

# print(score)
print("Predicted class for test_cat: {}".format(sample_prediction(test_cat)))
print("Predicted class for test_dog: {}".format(sample_prediction(test_dog)))
# Out:
# Predicted class for test_cat: [[1.         0.00000001]]
# Predicted class for test_dog: [[0.00038322 0.99961674]]

# %% [markdown]
# ## Visualization of Weights and Layers
#
# In trying to understand why the convolutional neural network can recognize images, we will now visualize the weights of the convolutional filters and the resulting output images.

# %% [markdown]
# ### Helper-function for plotting convolutional weights

# %%
def plot_conv_weights(weights, input_channel=0):
    # Assume weights are TensorFlow ops for 4-dim variables
    # e.g. weights_conv1 or weights_conv2.
    
    # Retrieve the values of the weight-variables from TensorFlow.
    # A feed-dict is not necessary because nothing is calculated.
    w = session.run(weights)

    # Get the lowest and highest values for the weights.
    # This is used to correct the colour intensity across
    # the images so they can be compared with each other.
    w_min = np.min(w)
    w_max = np.max(w)

    # Number of filters used in the conv. layer.
    num_filters = w.shape[3]

    # Number of grids to plot.
    # Rounded-up, square-root of the number of filters.
    num_grids = math.ceil(math.sqrt(num_filters))
    
    # Create figure with a grid of sub-plots.
    fig, axes = plt.subplots(num_grids, num_grids)

    # Plot all the filter-weights.
    for i, ax in enumerate(axes.flat):
        # Only plot the valid filter-weights.
        if i<num_filters:
            # Get the weights for the i'th filter of the input channel.
            # See new_conv_layer() for details on the format
            # of this 4-dim tensor.
            img = w[:, :, input_channel, i]

            # Plot image.
            ax.imshow(img, vmin=w_min, vmax=w_max,
                      interpolation='nearest', cmap='seismic')
        
        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])
    
    # Ensure the plot is shown correctly with multiple plots
    # in a single Notebook cell.
    plt.show()

# %% [markdown]
# ### Helper-function for plotting the output of a convolutional layer

# %%
def plot_conv_layer(layer, image):
    # Assume layer is a TensorFlow op that outputs a 4-dim tensor
    # which is the output of a convolutional layer,
    # e.g. layer_conv1 or layer_conv2.
    
    image = image.reshape(img_size_flat)

    # Create a feed-dict containing just one image.
    # Note that we don't need to feed y_true because it is
    # not used in this calculation.
    feed_dict = {x: [image]}

    # Calculate and retrieve the output values of the layer
    # when inputting that image.
    values = session.run(layer, feed_dict=feed_dict)

    # Number of filters used in the conv. layer.
    num_filters = values.shape[3]

    # Number of grids to plot.
    # Rounded-up, square-root of the number of filters.
    num_grids = math.ceil(math.sqrt(num_filters))
    
    # Create figure with a grid of sub-plots.
    fig, axes = plt.subplots(num_grids, num_grids)

    # Plot the output images of all the filters.
    for i, ax in enumerate(axes.flat):
        # Only plot the images for valid filters.
        if i<num_filters:
            # Get the output image of using the i'th filter.
            # See new_conv_layer() for details on the format
            # of this 4-dim tensor.
            img = values[0, :, :, i]

            # Plot image.
            ax.imshow(img, interpolation='nearest', cmap='binary')
        
        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])
    
    # Ensure the plot is shown correctly with multiple plots
    # in a single Notebook cell.
    plt.show()

# %% [markdown]
# ### Input Images

# %% [markdown]
# Helper-function for plotting an image.

# %%
def plot_image(image):
    plt.imshow(image.reshape(img_size, img_size, num_channels),
               interpolation='nearest')
    plt.show()

# %% [markdown]
# Plot an image from the test-set which will be used as an example below.

# %%
image1 = test_images[0]
plot_image(image1)

# %% [markdown]
# Plot another example image from the test-set.

# %%
image2 = test_images[13]
plot_image(image2)

# %% [markdown]
# ### Convolution Layer 1

# %% [markdown]
# Now plot the filter-weights for the first convolutional layer.
#
# Note that positive weights are red and negative weights are blue.

# %%
plot_conv_weights(weights=weights_conv1)

# %% [markdown]
# Applying each of these convolutional filters to the first input image gives the following output images, which are then used as input to the second convolutional layer. Note that these images are down-sampled to about half the resolution of the original input image.

# %%
plot_conv_layer(layer=layer_conv1, image=image1)

# %% [markdown]
# The following images are the results of applying the convolutional filters to the second image.

# %%
plot_conv_layer(layer=layer_conv1, image=image2)

# %% [markdown]
# ### Convolution Layer 2

# %% [markdown]
# Now plot the filter-weights for the second convolutional layer.
#
# There are 16 output channels from the first conv-layer, which means there are 16 input channels to the second conv-layer. The second conv-layer has a set of filter-weights for each of its input channels. We start by plotting the filter-weigths for the first channel.
#
# Note again that positive weights are red and negative weights are blue.

# %%
plot_conv_weights(weights=weights_conv2, input_channel=0)

# %% [markdown]
# There are 16 input channels to the second convolutional layer, so we can make another 15 plots of filter-weights like this. We just make one more with the filter-weights for the second channel.

# %%
plot_conv_weights(weights=weights_conv2, input_channel=1)

# %% [markdown]
# It can be difficult to understand and keep track of how these filters are applied because of the high dimensionality.
#
# Applying these convolutional filters to the images that were ouput from the first conv-layer gives the following images.
#
# Note that these are down-sampled yet again to half the resolution of the images from the first conv-layer.

# %%
plot_conv_layer(layer=layer_conv2, image=image1)

# %% [markdown]
# And these are the results of applying the filter-weights to the second image.

# %%
plot_conv_layer(layer=layer_conv2, image=image2)

# %% [markdown]
# ### Write Test Predictions to CSV

# %%
# def write_predictions(ims, ids):
#     ims = ims.reshape(ims.shape[0], img_size_flat)
#     preds = session.run(y_pred, feed_dict={x: ims})
#     result = pd.DataFrame(preds, columns=classes)
#     result.loc[:, 'id'] = pd.Series(ids, index=result.index)
#     pred_file = 'predictions.csv'
#     result.to_csv(pred_file, index=False)

# write_predictions(test_images, test_ids)

# %% [markdown]
# ### Close TensorFlow Session

# %% [markdown]
# We are now done using TensorFlow, so we close the session to release its resources.

# %%
session.close()
