# %% [markdown]
# # TensorFlow Convolutional Neural Network for Image Classification

# %%
import time
import math
import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import dataset
import cv2

from sklearn.metrics import confusion_matrix
from datetime import timedelta
from glob import glob

# %matplotlib inline

# %% [markdown]
# ## Configuration and Hyperparameters

# %%
# Convolutional Layer 1.
filter_size1 = 3 
num_filters1 = 32

# Convolutional Layer 2.
filter_size2 = 3
num_filters2 = 32

# Convolutional Layer 3.
filter_size3 = 3
num_filters3 = 64

# Fully-connected layer.
fc_size = 128             # Number of neurons in fully-connected layer.

# Number of color channels for the images: 1 channel for gray-scale.
num_channels = 3

# image dimensions (only squares for now)
img_size = 128

# Size of image when flattened to a single dimension
img_size_flat = img_size * img_size * num_channels

# Tuple with height and width of images used to reshape arrays.
img_shape = (img_size, img_size)

# class info
classes = ['dogs', 'cats']
num_classes = len(classes)

# batch size
batch_size = 32

# validation split
validation_size = .16

# how long to wait after validation loss stops improving before terminating training
early_stopping = None  # use None if you don't want to implement early stoping

train_path = 'data/train/'
test_path = 'data/test/'
checkpoint_dir = "models/"

# %% [markdown]
# ## Load Data

# %%
data = dataset.read_train_sets(train_path, img_size, classes, validation_size=validation_size)
test_images, test_ids = dataset.read_test_set(test_path, img_size)
# Out:
# Reading training images
# Loading dogs files (Index: 0)
# Loading cats files (Index: 1)
# Reading test images

# %%
print("Size of:")
print("- Training-set:\t\t{}".format(len(data.train.labels)))
print("- Test-set:\t\t{}".format(len(test_images)))
print("- Validation-set:\t{}".format(len(data.valid.labels)))
# Out:
# Size of:
# - Training-set:		336
# - Test-set:		2
# - Validation-set:	64

# %% [markdown]
# ### Helper-function for plotting images

# %%
def plot_images(images, cls_true, cls_pred=None):
    
    if len(images) == 0:
        print("no images to show")
        return 
    else:
        random_indices = random.sample(range(len(images)), min(len(images), 9))
        
    if cls_pred is not None:
        images, cls_true, cls_pred  = zip(*[(images[i], cls_true[i], cls_pred[i]) for i in random_indices])
    else:
        images, cls_true  = zip(*[(images[i], cls_true[i]) for i in random_indices])
    
    # Create figure with 3x3 sub-plots.
    fig, axes = plt.subplots(3, 3)
    fig.subplots_adjust(hspace=0.3, wspace=0.3)

    for i, ax in enumerate(axes.flat):
        # Plot image.
        ax.imshow(images[i].reshape(img_size, img_size, num_channels))

        # Show true and predicted classes.
        if cls_pred is None:
            xlabel = "True: {0}".format(cls_true[i])
        else:
            xlabel = "True: {0}, Pred: {1}".format(cls_true[i], cls_pred[i])

        # Show the classes as the label on the x-axis.
        ax.set_xlabel(xlabel)
        
        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])
    
    # Ensure the plot is shown correctly with multiple plots
    # in a single Notebook cell.
    plt.show()

# %% [markdown]
# Function used to plot 9 images in a 3x3 grid (or fewer, depending on how many images are passed), and writing the true and predicted classes below each image.

# %% [markdown]
# ### Plot a few images to see if data is correct

# %%
# Get some random images and their labels from the train set.

images, cls_true  = data.train.images, data.train.cls

# Plot the images and labels using our helper-function above.
plot_images(images=images, cls_true=cls_true)

# %% [markdown]
# ## TensorFlow Graph
#
# The entire purpose of TensorFlow is to have a so-called computational graph that can be executed much more efficiently than if the same calculations were to be performed directly in Python. TensorFlow can be more efficient than NumPy because TensorFlow knows the entire computation graph that must be executed, while NumPy only knows the computation of a single mathematical operation at a time.
#
# TensorFlow can also automatically calculate the gradients that are needed to optimize the variables of the graph so as to make the model perform better. This is because the graph is a combination of simple mathematical expressions so the gradient of the entire graph can be calculated using the chain-rule for derivatives.
#
# A TensorFlow graph consists of the following parts which will be detailed below:
#
# * Placeholder variables used for inputting data to the graph.
# * Variables that are going to be optimized so as to make the convolutional network perform better.
# * The mathematical formulas for the convolutional network.
# * A cost measure that can be used to guide the optimization of the variables.
# * An optimization method which updates the variables.

# %% [markdown]
# ### Helper-functions for creating new variables

# %% [markdown]
# Functions for creating new TensorFlow variables in the given shape and initializing them with random values. Note that the initialization is not actually done at this point, it is merely being defined in the TensorFlow graph.

# %%
def new_weights(shape):
    return tf.Variable(tf.truncated_normal(shape, stddev=0.05))

# %%
def new_biases(length):
    return tf.Variable(tf.constant(0.05, shape=[length]))

# %% [markdown]
# ### Helper-function for creating a new Convolutional Layer

# %% [markdown]
# This function creates a new convolutional layer in the computational graph for TensorFlow. Nothing is actually calculated here, we are just adding the mathematical formulas to the TensorFlow graph.
#
# It is assumed that the input is a 4-dim tensor with the following dimensions:
#
# 1. Image number.
# 2. Y-axis of each image.
# 3. X-axis of each image.
# 4. Channels of each image.
#
# Note that the input channels may either be colour-channels, or it may be filter-channels if the input is produced from a previous convolutional layer.
#
# The output is another 4-dim tensor with the following dimensions:
#
# 1. Image number, same as input.
# 2. Y-axis of each image. If 2x2 pooling is used, then the height and width of the input images is divided by 2.
# 3. X-axis of each image. Ditto.
# 4. Channels produced by the convolutional filters.

# %%
def new_conv_layer(input,              # The previous layer.
                   num_input_channels, # Num. channels in prev. layer.
                   filter_size,        # Width and height of each filter.
                   num_filters,        # Number of filters.
                   use_pooling=True):  # Use 2x2 max-pooling.

    # Shape of the filter-weights for the convolution.
    # This format is determined by the TensorFlow API.
    shape = [filter_size, filter_size, num_input_channels, num_filters]

    # Create new weights aka. filters with the given shape.
    weights = new_weights(shape=shape)

    # Create new biases, one for each filter.
    biases = new_biases(length=num_filters)

    # Create the TensorFlow operation for convolution.
    # Note the strides are set to 1 in all dimensions.
    # The first and last stride must always be 1,
    # because the first is for the image-number and
    # the last is for the input-channel.
    # But e.g. strides=[1, 2, 2, 1] would mean that the filter
    # is moved 2 pixels across the x- and y-axis of the image.
    # The padding is set to 'SAME' which means the input image
    # is padded with zeroes so the size of the output is the same.
    layer = tf.nn.conv2d(input=input,
                         filter=weights,
                         strides=[1, 1, 1, 1],
                         padding='SAME')

    # Add the biases to the results of the convolution.
    # A bias-value is added to each filter-channel.
    layer += biases

    # Use pooling to down-sample the image resolution?
    if use_pooling:
        # This is 2x2 max-pooling, which means that we
        # consider 2x2 windows and select the largest value
        # in each window. Then we move 2 pixels to the next window.
        layer = tf.nn.max_pool(value=layer,
                               ksize=[1, 2, 2, 1],
                               strides=[1, 2, 2, 1],
                               padding='SAME')

    # Rectified Linear Unit (ReLU).
    # It calculates max(x, 0) for each input pixel x.
    # This adds some non-linearity to the formula and allows us
    # to learn more complicated functions.
    layer = tf.nn.relu(layer)

    # Note that ReLU is normally executed before the pooling,
    # but since relu(max_pool(x)) == max_pool(relu(x)) we can
    # save 75% of the relu-operations by max-pooling first.

    # We return both the resulting layer and the filter-weights
    # because we will plot the weights later.
    return layer, weights

# %% [markdown]
# ### Helper-function for flattening a layer
#
# A convolutional layer produces an output tensor with 4 dimensions. We will add fully-connected layers after the convolution layers, so we need to reduce the 4-dim tensor to 2-dim which can be used as input to the fully-connected layer.

# %%
def flatten_layer(layer):
    # Get the shape of the input layer.
    layer_shape = layer.get_shape()

    # The shape of the input layer is assumed to be:
    # layer_shape == [num_images, img_height, img_width, num_channels]

    # The number of features is: img_height * img_width * num_channels
    # We can use a function from TensorFlow to calculate this.
    num_features = layer_shape[1:4].num_elements()
    
    # Reshape the layer to [num_images, num_features].
    # Note that we just set the size of the second dimension
    # to num_features and the size of the first dimension to -1
    # which means the size in that dimension is calculated
    # so the total size of the tensor is unchanged from the reshaping.
    layer_flat = tf.reshape(layer, [-1, num_features])

    # The shape of the flattened layer is now:
    # [num_images, img_height * img_width * num_channels]

    # Return both the flattened layer and the number of features.
    return layer_flat, num_features

# %% [markdown]
# ### Helper-function for creating a new Fully-Connected Layer

# %% [markdown]
# This function creates a new fully-connected layer in the computational graph for TensorFlow. Nothing is actually calculated here, we are just adding the mathematical formulas to the TensorFlow graph.
#
# It is assumed that the input is a 2-dim tensor of shape `[num_images, num_inputs]`. The output is a 2-dim tensor of shape `[num_images, num_outputs]`.

# %%
def new_fc_layer(input,          # The previous layer.
                 num_inputs,     # Num. inputs from prev. layer.
                 num_outputs,    # Num. outputs.
                 use_relu=True): # Use Rectified Linear Unit (ReLU)?

    # Create new weights and biases.
    weights = new_weights(shape=[num_inputs, num_outputs])
    biases = new_biases(length=num_outputs)

    # Calculate the layer as the matrix multiplication of
    # the input and weights, and then add the bias-values.
    layer = tf.matmul(input, weights) + biases

    # Use ReLU?
    if use_relu:
        layer = tf.nn.relu(layer)

    return layer

# %% [markdown]
# ### Placeholder variables

# %% [markdown]
# Placeholder variables serve as the input to the TensorFlow computational graph that we may change each time we execute the graph. We call this feeding the placeholder variables and it is demonstrated further below.
#
# First we define the placeholder variable for the input images. This allows us to change the images that are input to the TensorFlow graph. This is a so-called tensor, which just means that it is a multi-dimensional vector or matrix. The data-type is set to `float32` and the shape is set to `[None, img_size_flat]`, where `None` means that the tensor may hold an arbitrary number of images with each image being a vector of length `img_size_flat`.

# %%
x = tf.placeholder(tf.float32, shape=[None, img_size_flat], name='x')

# %% [markdown]
# The convolutional layers expect `x` to be encoded as a 4-dim tensor so we have to reshape it so its shape is instead `[num_images, img_height, img_width, num_channels]`. Note that `img_height == img_width == img_size` and `num_images` can be inferred automatically by using -1 for the size of the first dimension. So the reshape operation is:

# %%
x_image = tf.reshape(x, [-1, img_size, img_size, num_channels])

# %% [markdown]
# Next we have the placeholder variable for the true labels associated with the images that were input in the placeholder variable `x`. The shape of this placeholder variable is `[None, num_classes]` which means it may hold an arbitrary number of labels and each label is a vector of length `num_classes`.

# %%
y_true = tf.placeholder(tf.float32, shape=[None, num_classes], name='y_true')

# %% [markdown]
# We could also have a placeholder variable for the class-number, but we will instead calculate it using argmax. Note that this is a TensorFlow operator so nothing is calculated at this point.

# %%
y_true_cls = tf.argmax(y_true, axis=1)

# %% [markdown]
# ### Convolutional Layer 1
#
# Create the first convolutional layer. It takes `x_image` as input and creates `num_filters1` different filters, each having width and height equal to `filter_size1`. Finally we wish to down-sample the image so it is half the size by using 2x2 max-pooling.

# %%
layer_conv1, weights_conv1 = \
    new_conv_layer(input=x_image,
                   num_input_channels=num_channels,
                   filter_size=filter_size1,
                   num_filters=num_filters1,
                   use_pooling=True)

# %%
layer_conv1
# Out:
# <tf.Tensor 'Relu:0' shape=(?, 64, 64, 32) dtype=float32>

# %% [markdown]
# ### Convolutional Layers 2 and 3
#
# Create the second and third convolutional layers, which take as input the output from the first and second convolutional layer respectively. The number of input channels corresponds to the number of filters in the previous convolutional layer.

# %%
layer_conv2, weights_conv2 = \
    new_conv_layer(input=layer_conv1,
                   num_input_channels=num_filters1,
                   filter_size=filter_size2,
                   num_filters=num_filters2,
                   use_pooling=True)

# %%
layer_conv2
# Out:
# <tf.Tensor 'Relu_1:0' shape=(?, 32, 32, 32) dtype=float32>

# %%
layer_conv3, weights_conv3 = \
    new_conv_layer(input=layer_conv2,
                   num_input_channels=num_filters2,
                   filter_size=filter_size3,
                   num_filters=num_filters3,
                   use_pooling=True)

# %%
layer_conv3
# Out:
# <tf.Tensor 'Relu_2:0' shape=(?, 16, 16, 64) dtype=float32>

# %% [markdown]
# ### Flatten Layer
#
# The convolutional layers output 4-dim tensors. We now wish to use these as input in a fully-connected network, which requires for the tensors to be reshaped or flattened to 2-dim tensors.

# %%
layer_flat, num_features = flatten_layer(layer_conv3)

# %%
layer_flat
# Out:
# <tf.Tensor 'Reshape_1:0' shape=(?, 16384) dtype=float32>

# %%
num_features
# Out:
# 16384

# %% [markdown]
# ### Fully-Connected Layer 1
#
# Add a fully-connected layer to the network. The input is the flattened layer from the previous convolution. The number of neurons or nodes in the fully-connected layer is `fc_size`. ReLU is used so we can learn non-linear relations.

# %%
layer_fc1 = new_fc_layer(input=layer_flat,
                         num_inputs=num_features,
                         num_outputs=fc_size,
                         use_relu=True)

# %% [markdown]
# Check that the output of the fully-connected layer is a tensor with shape (?, 128) where the ? means there is an arbitrary number of images and `fc_size` == 128.

# %%
layer_fc1
# Out:
# <tf.Tensor 'Relu_3:0' shape=(?, 128) dtype=float32>

# %% [markdown]
# ### Fully-Connected Layer 2
#
# Add another fully-connected layer that outputs vectors of length num_classes for determining which of the classes the input image belongs to. Note that ReLU is not used in this layer.

# %%
layer_fc2 = new_fc_layer(input=layer_fc1,
                         num_inputs=fc_size,
                         num_outputs=num_classes,
                         use_relu=False)

# %%
layer_fc2
# Out:
# <tf.Tensor 'add_4:0' shape=(?, 2) dtype=float32>

# %% [markdown]
# ### Predicted Class

# %% [markdown]
# The second fully-connected layer estimates how likely it is that the input image belongs to each of the 2 classes. However, these estimates are a bit rough and difficult to interpret because the numbers may be very small or large, so we want to normalize them so that each element is limited between zero and one and the all the elements sum to one. This is calculated using the so-called softmax function and the result is stored in `y_pred`.

# %%
y_pred = tf.nn.softmax(layer_fc2)

# %% [markdown]
# The class-number is the index of the largest element.

# %%
y_pred_cls = tf.argmax(y_pred, axis=1)

# %% [markdown]
# ### Cost-function to be optimized

# %% [markdown]
# To make the model better at classifying the input images, we must somehow change the variables for all the network layers. To do this we first need to know how well the model currently performs by comparing the predicted output of the model `y_pred` to the desired output `y_true`.
#
# The cross-entropy is a performance measure used in classification. The cross-entropy is a continuous function that is always positive and if the predicted output of the model exactly matches the desired output then the cross-entropy equals zero. The goal of optimization is therefore to minimize the cross-entropy so it gets as close to zero as possible by changing the variables of the network layers.
#
# TensorFlow has a built-in function for calculating the cross-entropy. Note that the function calculates the softmax internally so we must use the output of `layer_fc2` directly rather than `y_pred` which has already had the softmax applied.

# %%
cross_entropy = tf.nn.softmax_cross_entropy_with_logits_v2(logits=layer_fc2, labels=y_true)

# %% [markdown]
# We have now calculated the cross-entropy for each of the image classifications so we have a measure of how well the model performs on each image individually. But in order to use the cross-entropy to guide the optimization of the model's variables we need a single scalar value, so we simply take the average of the cross-entropy for all the image classifications.

# %%
cost = tf.reduce_mean(cross_entropy)

# %% [markdown]
# ### Optimization Method

# %% [markdown]
# Now that we have a cost measure that must be minimized, we can then create an optimizer. In this case it is the `AdamOptimizer` which is an advanced form of Gradient Descent.
#
# Note that optimization is not performed at this point. In fact, nothing is calculated at all, we just add the optimizer-object to the TensorFlow graph for later execution.

# %%
optimizer = tf.train.AdamOptimizer(learning_rate=1e-4).minimize(cost)

# %% [markdown]
# ### Performance Measures

# %% [markdown]
# We need a few more performance measures to display the progress to the user.
#
# This is a vector of booleans whether the predicted class equals the true class of each image.

# %%
correct_prediction = tf.equal(y_pred_cls, y_true_cls)

# %% [markdown]
# This calculates the classification accuracy by first type-casting the vector of booleans to floats, so that False becomes 0 and True becomes 1, and then calculating the average of these numbers.

# %%
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %% [markdown]
# ## TensorFlow Run

# %% [markdown]
# ### Create TensorFlow session
#
# Once the TensorFlow graph has been created, we have to create a TensorFlow session which is used to execute the graph.

# %%
session = tf.Session()

# %% [markdown]
# ### Initialize variables
#
# The variables for `weights` and `biases` must be initialized before we start optimizing them.

# %%
session.run(tf.global_variables_initializer())

# %% [markdown]
# ### Helper-function to perform optimization iterations

# %% [markdown]
# It takes a long time to calculate the gradient of the model using the entirety of a large dataset
# . We therefore only use a small batch of images in each iteration of the optimizer.
#
# If your computer crashes or becomes very slow because you run out of RAM, then you may try and lower this number, but you may then need to perform more optimization iterations.

# %%
train_batch_size = batch_size

# %%
def print_progress(epoch, feed_dict_train, feed_dict_validate, val_loss):
    # Calculate the accuracy on the training-set.
    acc = session.run(accuracy, feed_dict=feed_dict_train)
    val_acc = session.run(accuracy, feed_dict=feed_dict_validate)
    msg = "Epoch {0} --- Training Accuracy: {1:>6.1%}, Validation Accuracy: {2:>6.1%}, Validation Loss: {3:.3f}"
    print(msg.format(epoch + 1, acc, val_acc, val_loss))

# %% [markdown]
# Function for performing a number of optimization iterations so as to gradually improve the variables of the network layers. In each iteration, a new batch of data is selected from the training-set and then TensorFlow executes the optimizer using those training samples.  The progress is printed every 100 iterations.

# %%
# Counter for total number of iterations performed so far.
total_iterations = 0

def optimize(num_iterations):
    # Ensure we update the global variable rather than a local copy.
    global total_iterations

    # Start-time used for printing time-usage below.
    start_time = time.time()
    
    best_val_loss = float("inf")
    patience = 0

    for i in range(total_iterations,
                   total_iterations + num_iterations):

        # Get a batch of training examples.
        # x_batch now holds a batch of images and
        # y_true_batch are the true labels for those images.
        x_batch, y_true_batch, _, cls_batch = data.train.next_batch(train_batch_size)
        x_valid_batch, y_valid_batch, _, valid_cls_batch = data.valid.next_batch(train_batch_size)

        # Convert shape from [num examples, rows, columns, depth]
        # to [num examples, flattened image shape]

        x_batch = x_batch.reshape(train_batch_size, img_size_flat)
        x_valid_batch = x_valid_batch.reshape(train_batch_size, img_size_flat)

        # Put the batch into a dict with the proper names
        # for placeholder variables in the TensorFlow graph.
        feed_dict_train = {x: x_batch,
                           y_true: y_true_batch}
        
        feed_dict_validate = {x: x_valid_batch,
                              y_true: y_valid_batch}

        # Run the optimizer using this batch of training data.
        # TensorFlow assigns the variables in feed_dict_train
        # to the placeholder variables and then runs the optimizer.
        session.run(optimizer, feed_dict=feed_dict_train)
        

        # Print status at end of each epoch (defined as full pass through training dataset).
        if i % int(data.train.num_examples/batch_size) == 0: 
            val_loss = session.run(cost, feed_dict=feed_dict_validate)
            epoch = int(i / int(data.train.num_examples/batch_size))
            
            print_progress(epoch, feed_dict_train, feed_dict_validate, val_loss)
            
            if early_stopping:    
                if val_loss < best_val_loss:
                    best_val_loss = val_loss
                    patience = 0
                else:
                    patience += 1

                if patience == early_stopping:
                    break

    # Update the total number of iterations performed.
    total_iterations += num_iterations

    # Ending time.
    end_time = time.time()

    # Difference between start and end-times.
    time_dif = end_time - start_time

    # Print the time-usage.
    print("Time elapsed: " + str(timedelta(seconds=int(round(time_dif)))))

# %% [markdown]
# ### Helper-function to plot example errors

# %% [markdown]
# Function for plotting examples of images from the test-set that have been mis-classified.

# %%
def plot_example_errors(cls_pred, correct):
    # cls_pred is an array of the predicted class-number for
    # all images in the test-set.

    # correct is a boolean array whether the predicted class
    # is equal to the true class for each image in the test-set.

    # Negate the boolean array.
    incorrect = (correct == False)
    
    # Get the images from the test-set that have been
    # incorrectly classified.
    images = data.valid.images[incorrect]
    
    # Get the predicted classes for those images.
    cls_pred = cls_pred[incorrect]

    # Get the true classes for those images.
    cls_true = data.valid.cls[incorrect]

    # Plot the first 9 images.
    plot_images(images=images, cls_true=cls_true, cls_pred=cls_pred)

# %% [markdown]
# ### Helper-function to plot confusion matrix

# %%
def plot_confusion_matrix(cls_pred):
    # cls_pred is an array of the predicted class-number for
    # all images in the test-set.

    # Get the true classifications for the test-set.
    cls_true = data.valid.cls
    
    # Get the confusion matrix using sklearn.
    cm = confusion_matrix(y_true=cls_true,
                          y_pred=cls_pred)

    # Print the confusion matrix as text.
    print(cm)

    # Plot the confusion matrix as an image.
    plt.matshow(cm)

    # Make various adjustments to the plot.
    plt.colorbar()
    tick_marks = np.arange(num_classes)
    plt.xticks(tick_marks, range(num_classes))
    plt.yticks(tick_marks, range(num_classes))
    plt.xlabel('Predicted')
    plt.ylabel('True')

    # Ensure the plot is shown correctly with multiple plots
    # in a single Notebook cell.
    plt.show()

# %% [markdown]
# ### Helper-function for showing the performance

# %% [markdown]
# Function for printing the classification accuracy on the test-set.
#
# It takes a while to compute the classification for all the images in the test-set, that's why the results are re-used by calling the above functions directly from this function, so the classifications don't have to be recalculated by each function.
#
# Note that this function can use a lot of computer memory, which is why the test-set is split into smaller batches. If you have little RAM in your computer and it crashes, then you can try and lower the batch-size.

# %%
def print_validation_accuracy(show_example_errors=False, show_confusion_matrix=False):

    # Number of images in the test-set.
    num_test = len(data.valid.images)

    # Allocate an array for the predicted classes which
    # will be calculated in batches and filled into this array.
    cls_pred = np.zeros(shape=num_test, dtype=np.int)

    # Now calculate the predicted classes for the batches.
    # We will just iterate through all the batches.
    # There might be a more clever and Pythonic way of doing this.

    # The starting index for the next batch is denoted i.
    i = 0

    while i < num_test:
        # The ending index for the next batch is denoted j.
        j = min(i + batch_size, num_test)

        # Get the images from the test-set between index i and j.
        images = data.valid.images[i:j, :].reshape(batch_size, img_size_flat)
        

        # Get the associated labels.
        labels = data.valid.labels[i:j, :]

        # Create a feed-dict with these images and labels.
        feed_dict = {x: images,
                     y_true: labels}

        # Calculate the predicted class using TensorFlow.
        cls_pred[i:j] = session.run(y_pred_cls, feed_dict=feed_dict)

        # Set the start-index for the next batch to the
        # end-index of the current batch.
        i = j

    cls_true = np.array(data.valid.cls)
    cls_pred = np.array([classes[x] for x in cls_pred]) 

    # Create a boolean array whether each image is correctly classified.
    correct = (cls_true == cls_pred)

    # Calculate the number of correctly classified images.
    # When summing a boolean array, False means 0 and True means 1.
    correct_sum = correct.sum()

    # Classification accuracy is the number of correctly classified
    # images divided by the total number of images in the test-set.
    acc = float(correct_sum) / num_test

    # Print the accuracy.
    msg = "Accuracy on Test-Set: {0:.1%} ({1} / {2})"
    print(msg.format(acc, correct_sum, num_test))

    # Plot some examples of mis-classifications, if desired.
    if show_example_errors:
        print("Example errors:")
        plot_example_errors(cls_pred=cls_pred, correct=correct)

    # Plot the confusion matrix, if desired.
    if show_confusion_matrix:
        print("Confusion Matrix:")
        plot_confusion_matrix(cls_pred=cls_pred)

# %% [markdown]
# ## Performance after 1 optimization iteration

# %%
# !pip install --upgrade tensorflow-gpu==1.

# %%
optimize(num_iterations=1)
print_validation_accuracy()
# Out:
# Epoch 1 --- Training Accuracy:  56.2%, Validation Accuracy:  50.0%, Validation Loss: 0.707
# Time elapsed: 0:00:02
# Accuracy on Test-Set: 45.3% (29 / 64)

# %% [markdown]
# ## Performance after 100 optimization iterations
#
# After 100 optimization iterations, the model should have significantly improved its classification accuracy.

# %%
optimize(num_iterations=99)  # We already performed 1 iteration above.
# Out:
# Epoch 2 --- Training Accuracy:  43.8%, Validation Accuracy:  50.0%, Validation Loss: 0.702
# Epoch 3 --- Training Accuracy:  56.2%, Validation Accuracy:  50.0%, Validation Loss: 0.698
# Epoch 4 --- Training Accuracy:  59.4%, Validation Accuracy:  37.5%, Validation Loss: 0.695
# Epoch 5 --- Training Accuracy:  59.4%, Validation Accuracy:  53.1%, Validation Loss: 0.696
# Epoch 6 --- Training Accuracy:  71.9%, Validation Accuracy:  43.8%, Validation Loss: 0.696
# Epoch 7 --- Training Accuracy:  75.0%, Validation Accuracy:  50.0%, Validation Loss: 0.696
# Epoch 8 --- Training Accuracy:  75.0%, Validation Accuracy:  46.9%, Validation Loss: 0.695
# Epoch 9 --- Training Accuracy:  78.1%, Validation Accuracy:  56.2%, Validation Loss: 0.695
# Epoch 10 --- Training Accuracy:  78.1%, Validation Accuracy:  59.4%, Validation Loss: 0.694
# Time elapsed: 0:00:02

# %%
print_validation_accuracy(show_example_errors=True)
# Out:
# Accuracy on Test-Set: 57.8% (37 / 64)
# Example errors:

# %% [markdown]
# ## Performance after 1000 optimization iterations

# %%
optimize(num_iterations=900)  # We performed 100 iterations above.
# Out:
# Epoch 11 --- Training Accuracy:  75.0%, Validation Accuracy:  56.2%, Validation Loss: 0.693
# Epoch 12 --- Training Accuracy:  78.1%, Validation Accuracy:  59.4%, Validation Loss: 0.692
# Epoch 13 --- Training Accuracy:  78.1%, Validation Accuracy:  56.2%, Validation Loss: 0.690
# Epoch 14 --- Training Accuracy:  78.1%, Validation Accuracy:  59.4%, Validation Loss: 0.688
# Epoch 15 --- Training Accuracy:  81.2%, Validation Accuracy:  65.6%, Validation Loss: 0.685
# Epoch 16 --- Training Accuracy:  81.2%, Validation Accuracy:  62.5%, Validation Loss: 0.685
# Epoch 17 --- Training Accuracy:  81.2%, Validation Accuracy:  62.5%, Validation Loss: 0.682
# Epoch 18 --- Training Accuracy:  81.2%, Validation Accuracy:  62.5%, Validation Loss: 0.676
# Epoch 19 --- Training Accuracy:  78.1%, Validation Accuracy:  59.4%, Validation Loss: 0.674
# Epoch 20 --- Training Accuracy:  81.2%, Validation Accuracy:  59.4%, Validation Loss: 0.671
# Epoch 21 --- Training Accuracy:  81.2%, Validation Accuracy:  59.4%, Validation Loss: 0.668
# Epoch 22 --- Training Accuracy:  81.2%, Validation Accuracy:  62.5%, Validation Loss: 0.673
# Epoch 23 --- Training Accuracy:  84.4%, Validation Accuracy:  62.5%, Validation Loss: 0.676
# Epoch 24 --- Training Accuracy:  84.4%, Validation Accuracy:  62.5%, Validation Loss: 0.680
# Epoch 25 --- Training Accuracy:  87.5%, Validation Accuracy:  62.5%, Validation Loss: 0.686
# Epoch 26 --- Training Accuracy:  87.5%, Validation Accuracy:  62.5%, Validation Loss: 0.692
# Epoch 27 --- Training Accuracy:  87.5%, Validation Accuracy:  62.5%, Validation Loss: 0.695
# Epoch 28 --- Training Accuracy:  87.5%, Validation Accuracy:  62.5%, Validation Loss: 0.703
# Epoch 29 --- Training Accuracy:  87.5%, Validation Accuracy:  62.5%, Validation Loss: 0.708
# Epoch 30 --- Training Accuracy:  87.5%, Validation Accuracy:  62.5%, Validation Loss: 0.713
# Epoch 31 --- Training Accuracy:  87.5%, Validation Accuracy:  56.2%, Validation Loss: 0.718
# Epoch 32 --- Training Accuracy:  87.5%, Validation Accuracy:  53.1%, Validation Loss: 0.729
# Epoch 33 --- Training Accuracy:  87.5%, Validation Accuracy:  53.1%, Validation Loss: 0.735
# Epoch 34 --- Training Accuracy:  87.5%, Validation Accuracy:  53.1%, Validation Loss: 0.739
# Epoch 35 --- Training Accuracy:  90.6%, Validation Accuracy:  53.1%, Validation Loss: 0.746
# Epoch 36 --- Training Accuracy:  90.6%, Validation Accuracy:  56.2%, Validation Loss: 0.749
# Epoch 37 --- Training Accuracy:  90.6%, Validation Accuracy:  56.2%, Validation Loss: 0.757
# Epoch 38 --- Training Accuracy:  90.6%, Validation Accuracy:  56.2%, Validation Loss: 0.761
# Epoch 39 --- Training Accuracy:  90.6%, Validation Accuracy:  56.2%, Validation Loss: 0.770
# Epoch 40 --- Training Accuracy:  93.8%, Validation Accuracy:  56.2%, Validation Loss: 0.778
# Epoch 41 --- Training Accuracy:  93.8%, Validation Accuracy:  59.4%, Validation Loss: 0.786
# Epoch 42 --- Training Accuracy:  93.8%, Validation Accuracy:  59.4%, Validation Loss: 0.797
# Epoch 43 --- Training Accuracy:  93.8%, Validation Accuracy:  59.4%, Validation Loss: 0.804
# Epoch 44 --- Training Accuracy:  93.8%, Validation Accuracy:  59.4%, Validation Loss: 0.813
# Epoch 45 --- Training Accuracy:  93.8%, Validation Accuracy:  59.4%, Validation Loss: 0.823
# Epoch 46 --- Training Accuracy:  93.8%, Validation Accuracy:  59.4%, Validation Loss: 0.837
# Epoch 47 --- Training Accuracy:  93.8%, Validation Accuracy:  59.4%, Validation Loss: 0.849
# Epoch 48 --- Training Accuracy:  93.8%, Validation Accuracy:  59.4%, Validation Loss: 0.865
# Epoch 49 --- Training Accuracy:  93.8%, Validation Accuracy:  56.2%, Validation Loss: 0.878
# Epoch 50 --- Training Accuracy:  93.8%, Validation Accuracy:  56.2%, Validation Loss: 0.902
# Epoch 51 --- Training Accuracy:  96.9%, Validation Accuracy:  56.2%, Validation Loss: 0.916
# Epoch 52 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 0.947
# Epoch 53 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 0.972
# Epoch 54 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 1.007
# Epoch 55 --- Training Accuracy: 100.0%, Validation Accuracy:  65.6%, Validation Loss: 1.056
# Epoch 56 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 1.125
# Epoch 57 --- Training Accuracy: 100.0%, Validation Accuracy:  65.6%, Validation Loss: 1.212
# Epoch 58 --- Training Accuracy:  96.9%, Validation Accuracy:  65.6%, Validation Loss: 1.362
# Epoch 59 --- Training Accuracy:  96.9%, Validation Accuracy:  59.4%, Validation Loss: 1.490
# Epoch 60 --- Training Accuracy:  96.9%, Validation Accuracy:  59.4%, Validation Loss: 1.445
# Epoch 61 --- Training Accuracy: 100.0%, Validation Accuracy:  65.6%, Validation Loss: 1.084
# Epoch 62 --- Training Accuracy:  87.5%, Validation Accuracy:  62.5%, Validation Loss: 1.144
# Epoch 63 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.022
# Epoch 64 --- Training Accuracy: 100.0%, Validation Accuracy:  68.8%, Validation Loss: 1.156
# Epoch 65 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 1.055
# Epoch 66 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.081
# Epoch 67 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 1.139
# Epoch 68 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.114
# Epoch 69 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.136
# Epoch 70 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 1.164
# Epoch 71 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 1.170
# Epoch 72 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 1.186
# Epoch 73 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 1.203
# Epoch 74 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 1.215
# Epoch 75 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 1.229
# Epoch 76 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 1.243
# Epoch 77 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 1.257
# Epoch 78 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 1.270
# Epoch 79 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 1.284
# Epoch 80 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 1.298
# Epoch 81 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 1.310
# Epoch 82 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 1.324
# Epoch 83 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 1.336
# Epoch 84 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.348
# Epoch 85 --- Training Accuracy: 100.0%, Validation Accuracy:  56.2%, Validation Loss: 1.363
# Epoch 86 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.375
# Epoch 87 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.390
# Epoch 88 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.401
# Epoch 89 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.415
# Epoch 90 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.429
# Epoch 91 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.436
# Epoch 92 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.451
# Epoch 93 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.457
# Epoch 94 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.473
# Epoch 95 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.478
# Epoch 96 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.491
# Epoch 97 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.506
# Epoch 98 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.509
# Epoch 99 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.524
# Epoch 100 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.533
# Time elapsed: 0:00:14

# %%
print_validation_accuracy(show_example_errors=True)
# Out:
# Accuracy on Test-Set: 57.8% (37 / 64)
# Example errors:

# %% [markdown]
# ## Performance after 10,000 optimization iterations

# %%
optimize(num_iterations=9000) # We performed 1000 iterations above.
# Out:
# Epoch 101 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.541
# Epoch 102 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.552
# Epoch 103 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.562
# Epoch 104 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.569
# Epoch 105 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.582
# Epoch 106 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.593
# Epoch 107 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.599
# Epoch 108 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.608
# Epoch 109 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.617
# Epoch 110 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.629
# Epoch 111 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.630
# Epoch 112 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.643
# Epoch 113 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.652
# Epoch 114 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.663
# Epoch 115 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.668
# Epoch 116 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.682
# Epoch 117 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.682
# Epoch 118 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.695
# Epoch 119 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.703
# Epoch 120 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.707
# Epoch 121 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.716
# Epoch 122 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.721
# Epoch 123 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.730
# Epoch 124 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.736
# Epoch 125 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.745
# Epoch 126 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.752
# Epoch 127 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.757
# Epoch 128 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.766
# Epoch 129 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.772
# Epoch 130 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.776
# Epoch 131 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.788
# Epoch 132 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.791
# Epoch 133 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.797
# Epoch 134 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.803
# Epoch 135 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.813
# Epoch 136 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.815
# Epoch 137 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.825
# Epoch 138 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.830
# Epoch 139 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.834
# Epoch 140 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.839
# Epoch 141 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.848
# Epoch 142 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.854
# Epoch 143 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.858
# Epoch 144 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.864
# Epoch 145 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.871
# Epoch 146 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.876
# Epoch 147 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.882
# Epoch 148 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.889
# Epoch 149 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.895
# Epoch 150 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.898
# Epoch 151 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.905
# Epoch 152 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.908
# Epoch 153 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.913
# Epoch 154 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.920
# Epoch 155 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.923
# Epoch 156 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.931
# Epoch 157 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.935
# Epoch 158 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.938
# Epoch 159 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.944
# Epoch 160 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.949
# Epoch 161 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.954
# Epoch 162 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.959
# Epoch 163 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.963
# Epoch 164 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.969
# Epoch 165 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.974
# Epoch 166 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.978
# Epoch 167 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.982
# Epoch 168 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.987
# Epoch 169 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.990
# Epoch 170 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 1.998
# Epoch 171 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.002
# Epoch 172 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.004
# Epoch 173 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.010
# Epoch 174 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.014
# Epoch 175 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.019
# Epoch 176 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.022
# Epoch 177 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.027
# Epoch 178 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.033
# Epoch 179 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.034
# Epoch 180 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.040
# Epoch 181 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.043
# Epoch 182 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.049
# Epoch 183 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.055
# Epoch 184 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.057
# Epoch 185 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.060
# Epoch 186 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.063
# Epoch 187 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.069
# Epoch 188 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.071
# Epoch 189 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.078
# Epoch 190 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.083
# Epoch 191 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.085
# Epoch 192 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.088
# Epoch 193 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.091
# Epoch 194 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.097
# Epoch 195 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.098
# Epoch 196 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.103
# Epoch 197 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.105
# Epoch 198 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.111
# Epoch 199 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.113
# Epoch 200 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.118
# Epoch 201 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.120
# Epoch 202 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.125
# Epoch 203 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.126
# Epoch 204 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.131
# Epoch 205 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.133
# Epoch 206 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.139
# Epoch 207 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.141
# Epoch 208 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.146
# Epoch 209 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.147
# Epoch 210 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.151
# Epoch 211 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.153
# Epoch 212 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.158
# Epoch 213 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.163
# Epoch 214 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.164
# Epoch 215 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.167
# Epoch 216 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.171
# Epoch 217 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.176
# Epoch 218 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.178
# Epoch 219 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.181
# Epoch 220 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.183
# Epoch 221 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.187
# Epoch 222 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.191
# Epoch 223 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.193
# Epoch 224 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.197
# Epoch 225 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.199
# Epoch 226 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.202
# Epoch 227 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.207
# Epoch 228 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.209
# Epoch 229 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.212
# Epoch 230 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.215
# Epoch 231 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.218
# Epoch 232 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.220
# Epoch 233 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.224
# Epoch 234 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.229
# Epoch 235 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.230
# Epoch 236 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.231
# Epoch 237 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.234
# Epoch 238 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.240
# Epoch 239 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.243
# Epoch 240 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.244
# Epoch 241 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.248
# Epoch 242 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.250
# Epoch 243 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.254
# Epoch 244 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.256
# Epoch 245 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.259
# Epoch 246 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.262
# Epoch 247 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.265
# Epoch 248 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.268
# Epoch 249 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.269
# Epoch 250 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.271
# Epoch 251 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.277
# Epoch 252 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.277
# Epoch 253 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.279
# Epoch 254 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.283
# Epoch 255 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.285
# Epoch 256 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.287
# Epoch 257 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.290
# Epoch 258 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.295
# Epoch 259 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.297
# Epoch 260 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.299
# Epoch 261 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.301
# Epoch 262 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.304
# Epoch 263 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.307
# Epoch 264 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.309
# Epoch 265 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.311
# Epoch 266 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.313
# Epoch 267 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.315
# Epoch 268 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.319
# Epoch 269 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.321
# Epoch 270 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.323
# Epoch 271 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.328
# Epoch 272 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.328
# Epoch 273 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.330
# Epoch 274 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.334
# Epoch 275 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.337
# Epoch 276 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.337
# Epoch 277 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.341
# Epoch 278 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.343
# Epoch 279 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.346
# Epoch 280 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.348
# Epoch 281 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.350
# Epoch 282 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.353
# Epoch 283 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.355
# Epoch 284 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.358
# Epoch 285 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.360
# Epoch 286 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.363
# Epoch 287 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.366
# Epoch 288 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.368
# Epoch 289 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.371
# Epoch 290 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.372
# Epoch 291 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.375
# Epoch 292 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.378
# Epoch 293 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.379
# Epoch 294 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.383
# Epoch 295 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.386
# Epoch 296 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.385
# Epoch 297 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.388
# Epoch 298 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.390
# Epoch 299 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.394
# Epoch 300 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.395
# Epoch 301 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.398
# Epoch 302 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.399
# Epoch 303 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.400
# Epoch 304 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.406
# Epoch 305 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.406
# Epoch 306 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.409
# Epoch 307 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.410
# Epoch 308 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.413
# Epoch 309 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.416
# Epoch 310 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.418
# Epoch 311 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.421
# Epoch 312 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.423
# Epoch 313 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.424
# Epoch 314 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.428
# Epoch 315 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.430
# Epoch 316 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.431
# Epoch 317 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.434
# Epoch 318 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.436
# Epoch 319 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.437
# Epoch 320 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.439
# Epoch 321 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.442
# Epoch 322 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.443
# Epoch 323 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.446
# Epoch 324 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.447
# Epoch 325 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.450
# Epoch 326 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.453
# Epoch 327 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.454
# Epoch 328 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.456
# Epoch 329 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.457
# Epoch 330 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.460
# Epoch 331 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.464
# Epoch 332 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.465
# Epoch 333 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.467
# Epoch 334 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.469
# Epoch 335 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.473
# Epoch 336 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.473
# Epoch 337 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.476
# Epoch 338 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.478
# Epoch 339 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.479
# Epoch 340 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.481
# Epoch 341 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.483
# Epoch 342 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.485
# Epoch 343 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.488
# Epoch 344 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.489
# Epoch 345 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.491
# Epoch 346 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.494
# Epoch 347 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.495
# Epoch 348 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.496
# Epoch 349 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.499
# Epoch 350 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.502
# Epoch 351 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.505
# Epoch 352 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.504
# Epoch 353 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.506
# Epoch 354 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.509
# Epoch 355 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.512
# Epoch 356 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.513
# Epoch 357 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.515
# Epoch 358 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.518
# Epoch 359 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.520
# Epoch 360 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.521
# Epoch 361 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.523
# Epoch 362 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.525
# Epoch 363 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.528
# Epoch 364 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.527
# Epoch 365 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.529
# Epoch 366 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.533
# Epoch 367 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.534
# Epoch 368 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.536
# Epoch 369 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.539
# Epoch 370 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.541
# Epoch 371 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.543
# Epoch 372 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.545
# Epoch 373 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.547
# Epoch 374 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.550
# Epoch 375 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.549
# Epoch 376 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.551
# Epoch 377 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.556
# Epoch 378 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.557
# Epoch 379 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.560
# Epoch 380 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.560
# Epoch 381 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.562
# Epoch 382 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.564
# Epoch 383 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.566
# Epoch 384 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.568
# Epoch 385 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.570
# Epoch 386 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.571
# Epoch 387 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.572
# Epoch 388 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.575
# Epoch 389 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.578
# Epoch 390 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.580
# Epoch 391 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.581
# Epoch 392 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.583
# Epoch 393 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.584
# Epoch 394 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.586
# Epoch 395 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.589
# Epoch 396 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.592
# Epoch 397 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.592
# Epoch 398 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.594
# Epoch 399 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.595
# Epoch 400 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.598
# Epoch 401 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.599
# Epoch 402 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.602
# Epoch 403 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.603
# Epoch 404 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.606
# Epoch 405 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.608
# Epoch 406 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.608
# Epoch 407 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.611
# Epoch 408 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.611
# Epoch 409 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.614
# Epoch 410 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.616
# Epoch 411 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.617
# Epoch 412 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.619
# Epoch 413 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.620
# Epoch 414 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.623
# Epoch 415 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.625
# Epoch 416 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.627
# Epoch 417 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.628
# Epoch 418 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.631
# Epoch 419 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.634
# Epoch 420 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.633
# Epoch 421 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.637
# Epoch 422 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.637
# Epoch 423 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.638
# Epoch 424 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.641
# Epoch 425 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.643
# Epoch 426 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.646
# Epoch 427 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.648
# Epoch 428 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.649
# Epoch 429 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.651
# Epoch 430 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.652
# Epoch 431 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.655
# Epoch 432 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.656
# Epoch 433 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.658
# Epoch 434 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.658
# Epoch 435 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.660
# Epoch 436 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.664
# Epoch 437 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.665
# Epoch 438 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.666
# Epoch 439 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.669
# Epoch 440 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.671
# Epoch 441 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.670
# Epoch 442 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.676
# Epoch 443 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.678
# Epoch 444 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.677
# Epoch 445 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.681
# Epoch 446 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.681
# Epoch 447 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.684
# Epoch 448 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.684
# Epoch 449 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.687
# Epoch 450 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.688
# Epoch 451 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.692
# Epoch 452 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.692
# Epoch 453 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.694
# Epoch 454 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.696
# Epoch 455 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.696
# Epoch 456 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.699
# Epoch 457 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.701
# Epoch 458 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.702
# Epoch 459 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.703
# Epoch 460 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.707
# Epoch 461 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.707
# Epoch 462 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.710
# Epoch 463 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.711
# Epoch 464 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.714
# Epoch 465 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.716
# Epoch 466 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.716
# Epoch 467 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.718
# Epoch 468 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.721
# Epoch 469 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.721
# Epoch 470 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.723
# Epoch 471 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.727
# Epoch 472 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.727
# Epoch 473 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.730
# Epoch 474 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.731
# Epoch 475 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.733
# Epoch 476 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.733
# Epoch 477 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.735
# Epoch 478 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.738
# Epoch 479 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.739
# Epoch 480 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.741
# Epoch 481 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.743
# Epoch 482 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.745
# Epoch 483 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.745
# Epoch 484 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.748
# Epoch 485 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.749
# Epoch 486 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.751
# Epoch 487 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.754
# Epoch 488 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.753
# Epoch 489 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.756
# Epoch 490 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.759
# Epoch 491 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.759
# Epoch 492 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.762
# Epoch 493 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.762
# Epoch 494 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.767
# Epoch 495 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.766
# Epoch 496 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.768
# Epoch 497 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.770
# Epoch 498 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.771
# Epoch 499 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.773
# Epoch 500 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.775
# Epoch 501 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.777
# Epoch 502 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.779
# Epoch 503 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.781
# Epoch 504 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.782
# Epoch 505 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.786
# Epoch 506 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.785
# Epoch 507 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.786
# Epoch 508 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.787
# Epoch 509 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.788
# Epoch 510 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.792
# Epoch 511 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.792
# Epoch 512 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.794
# Epoch 513 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.797
# Epoch 514 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.797
# Epoch 515 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.799
# Epoch 516 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.801
# Epoch 517 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.804
# Epoch 518 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.804
# Epoch 519 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.806
# Epoch 520 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.808
# Epoch 521 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.808
# Epoch 522 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.810
# Epoch 523 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.812
# Epoch 524 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.813
# Epoch 525 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.815
# Epoch 526 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.816
# Epoch 527 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.818
# Epoch 528 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.821
# Epoch 529 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.821
# Epoch 530 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.822
# Epoch 531 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.824
# Epoch 532 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.828
# Epoch 533 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.828
# Epoch 534 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.832
# Epoch 535 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.831
# Epoch 536 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.832
# Epoch 537 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.835
# Epoch 538 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.835
# Epoch 539 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.839
# Epoch 540 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.838
# Epoch 541 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.838
# Epoch 542 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.842
# Epoch 543 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.843
# Epoch 544 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.846
# Epoch 545 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.847
# Epoch 546 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.847
# Epoch 547 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.849
# Epoch 548 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.849
# Epoch 549 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.851
# Epoch 550 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.855
# Epoch 551 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.857
# Epoch 552 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.858
# Epoch 553 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.859
# Epoch 554 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.860
# Epoch 555 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.861
# Epoch 556 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.863
# Epoch 557 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.863
# Epoch 558 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.867
# Epoch 559 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.869
# Epoch 560 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.870
# Epoch 561 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.873
# Epoch 562 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.872
# Epoch 563 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.874
# Epoch 564 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.876
# Epoch 565 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.877
# Epoch 566 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.879
# Epoch 567 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.881
# Epoch 568 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.882
# Epoch 569 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.882
# Epoch 570 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.885
# Epoch 571 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.887
# Epoch 572 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.889
# Epoch 573 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.891
# Epoch 574 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.890
# Epoch 575 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.893
# Epoch 576 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.894
# Epoch 577 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.895
# Epoch 578 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.897
# Epoch 579 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.899
# Epoch 580 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.900
# Epoch 581 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.900
# Epoch 582 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.904
# Epoch 583 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.904
# Epoch 584 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.908
# Epoch 585 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.908
# Epoch 586 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.910
# Epoch 587 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.909
# Epoch 588 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.911
# Epoch 589 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.913
# Epoch 590 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.915
# Epoch 591 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.917
# Epoch 592 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.918
# Epoch 593 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.920
# Epoch 594 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.922
# Epoch 595 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.923
# Epoch 596 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.923
# Epoch 597 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.927
# Epoch 598 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.927
# Epoch 599 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.927
# Epoch 600 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.930
# Epoch 601 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.931
# Epoch 602 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.932
# Epoch 603 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.934
# Epoch 604 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.935
# Epoch 605 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.939
# Epoch 606 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.938
# Epoch 607 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.940
# Epoch 608 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.942
# Epoch 609 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.943
# Epoch 610 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.944
# Epoch 611 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.947
# Epoch 612 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.946
# Epoch 613 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.950
# Epoch 614 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.949
# Epoch 615 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.951
# Epoch 616 --- Training Accuracy: 100.0%, Validation Accuracy:  59.4%, Validation Loss: 2.953
# ...
# Epoch 830 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.254
# Epoch 831 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.256
# Epoch 832 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.258
# Epoch 833 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.260
# Epoch 834 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.261
# Epoch 835 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.261
# Epoch 836 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.265
# Epoch 837 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.266
# Epoch 838 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.268
# Epoch 839 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.267
# Epoch 840 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.269
# Epoch 841 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.268
# Epoch 842 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.271
# Epoch 843 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.274
# Epoch 844 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.275
# Epoch 845 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.275
# Epoch 846 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.276
# Epoch 847 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.280
# Epoch 848 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.279
# Epoch 849 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.282
# Epoch 850 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.282
# Epoch 851 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.285
# Epoch 852 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.287
# Epoch 853 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.287
# Epoch 854 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.287
# Epoch 855 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.291
# Epoch 856 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.291
# Epoch 857 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.293
# Epoch 858 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.293
# Epoch 859 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.296
# Epoch 860 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.297
# Epoch 861 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.297
# Epoch 862 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.300
# Epoch 863 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.302
# Epoch 864 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.301
# Epoch 865 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.302
# Epoch 866 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.305
# Epoch 867 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.305
# Epoch 868 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.306
# Epoch 869 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.309
# Epoch 870 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.309
# Epoch 871 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.312
# Epoch 872 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.311
# Epoch 873 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.314
# Epoch 874 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.315
# Epoch 875 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.318
# Epoch 876 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.318
# Epoch 877 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.320
# Epoch 878 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.323
# Epoch 879 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.323
# Epoch 880 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.323
# Epoch 881 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.326
# Epoch 882 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.325
# Epoch 883 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.328
# Epoch 884 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.328
# Epoch 885 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.333
# Epoch 886 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.332
# Epoch 887 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.333
# Epoch 888 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.333
# Epoch 889 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.335
# Epoch 890 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.338
# Epoch 891 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.339
# Epoch 892 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.339
# Epoch 893 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.341
# Epoch 894 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.344
# Epoch 895 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.342
# Epoch 896 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.346
# Epoch 897 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.346
# Epoch 898 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.348
# Epoch 899 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.348
# Epoch 900 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.350
# Epoch 901 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.354
# Epoch 902 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.352
# Epoch 903 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.354
# Epoch 904 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.357
# Epoch 905 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.358
# Epoch 906 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.356
# Epoch 907 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.360
# Epoch 908 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.357
# Epoch 909 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.361
# Epoch 910 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.359
# Epoch 911 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.362
# Epoch 912 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.364
# Epoch 913 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.366
# Epoch 914 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.367
# Epoch 915 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.368
# Epoch 916 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.369
# Epoch 917 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.369
# Epoch 918 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.372
# Epoch 919 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.374
# Epoch 920 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.374
# Epoch 921 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.373
# Epoch 922 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.376
# Epoch 923 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.378
# Epoch 924 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.377
# Epoch 925 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.379
# Epoch 926 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.381
# Epoch 927 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.380
# Epoch 928 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.382
# Epoch 929 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.384
# Epoch 930 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.387
# Epoch 931 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.388
# Epoch 932 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.388
# Epoch 933 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.388
# Epoch 934 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.388
# Epoch 935 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.389
# Epoch 936 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.393
# Epoch 937 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.394
# Epoch 938 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.393
# Epoch 939 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.393
# Epoch 940 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.397
# Epoch 941 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.396
# Epoch 942 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.399
# Epoch 943 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.398
# Epoch 944 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.403
# Epoch 945 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.402
# Epoch 946 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.403
# Epoch 947 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.406
# Epoch 948 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.404
# Epoch 949 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.406
# Epoch 950 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.406
# Epoch 951 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.410
# Epoch 952 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.409
# Epoch 953 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.411
# Epoch 954 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.413
# Epoch 955 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.414
# Epoch 956 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.413
# Epoch 957 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.415
# Epoch 958 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.418
# Epoch 959 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.417
# Epoch 960 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.418
# Epoch 961 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.423
# Epoch 962 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.421
# Epoch 963 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.422
# Epoch 964 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.425
# Epoch 965 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.425
# Epoch 966 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.427
# Epoch 967 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.427
# Epoch 968 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.428
# Epoch 969 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.433
# Epoch 970 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.431
# Epoch 971 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.432
# Epoch 972 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.435
# Epoch 973 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.434
# Epoch 974 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.436
# Epoch 975 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.438
# Epoch 976 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.437
# Epoch 977 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.441
# Epoch 978 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.439
# Epoch 979 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.442
# Epoch 980 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.442
# Epoch 981 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.442
# Epoch 982 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.446
# Epoch 983 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.445
# Epoch 984 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.448
# Epoch 985 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.449
# Epoch 986 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.449
# Epoch 987 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.451
# Epoch 988 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.451
# Epoch 989 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.456
# Epoch 990 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.453
# Epoch 991 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.457
# Epoch 992 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.457
# Epoch 993 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.457
# Epoch 994 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.460
# Epoch 995 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.462
# Epoch 996 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.462
# Epoch 997 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.461
# Epoch 998 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.464
# Epoch 999 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.464
# Epoch 1000 --- Training Accuracy: 100.0%, Validation Accuracy:  62.5%, Validation Loss: 3.467
# Time elapsed: 0:02:20

# %%
print_validation_accuracy(show_example_errors=True, show_confusion_matrix=True)
# Out:
# Accuracy on Test-Set: 60.9% (39 / 64)
# Example errors:
# Confusion Matrix:
# [[23 12]
#  [13 16]]

# %% [markdown]
# ## Test on Sample Image

# %%
# prepare testing data
test_dataset_A = glob('.\\data\\test\\{}\\*.jpg'.format(classes[0]))
test_dataset_B = glob('.\\data\\test\\{}\\*.jpg'.format(classes[1]))

# test_data_A_list = []
# test_data_B_list = []

# test_dataset_A


# for sample_index in range(min(len(test_dataset_A), len(test_dataset_B))):
#     test_batch_files = list(zip(test_dataset_A[sample_index : (sample_index + 1)],
#                                 test_dataset_B[sample_index : (sample_index + 1)]))
#     test_batch_images = [load_train_data(test_batch_file, 286, 256) for test_batch_file in test_batch_files]
#     test_batch_images = np.array(test_batch_images).astype(np.float32)

#     test_data_A_list.append(test_batch_images[:, :, :, : 3])
#     test_data_B_list.append(test_batch_images[:, :, :, 3:6])

# %%
plt.axis('off')

print(test_dataset_A[0])

test_cat = cv2.imread(test_dataset_A[0])

# plt.imshow(test_cat)
# plt.imshow(test_cat)
# plt.imshow(test_cat)

for sample_index in test_dataset_A:
    
#     print(sample_index)
    test_cat = cv2.imread(sample_index)
    # print(test_cat)
#     cv2.imshow('My Image', test_cat)

    test_cat = cv2.resize(test_cat, (img_size, img_size), cv2.INTER_LINEAR) / 255

    preview_cat = plt.imshow(test_cat.reshape(img_size, img_size, num_channels))
# Out:
# .\data\test\dogs\dog.12400.jpg

# %%
img_size
# Out:
# 128

# %%
test_dog = cv2.imread('.\\data\\test\\1.jpg')

cv2.imshow('My Image', test_dog)

test_dog = cv2.resize(test_dog, (img_size, img_size), cv2.INTER_LINEAR) / 255

preview_dog = plt.imshow(test_dog.reshape(img_size, img_size, num_channels))

# %%
def sample_prediction(test_im):
    
    feed_dict_test = {
        x: test_im.reshape(1, img_size_flat),
        y_true: np.array([[1, 0]])
    }

    score, test_pred = session.run([y_pred, y_pred_cls] , feed_dict=feed_dict_test)
#     return classes[test_pred[0]]
    return classes[test_pred[0]], score


np.set_printoptions(suppress=True)

# print(score)

results = sample_prediction(test_cat)
print("Predicted class for test_cat: {}, score: {}".format(results[0], results[1]))

results = sample_prediction(test_dog)
print("Predicted class for test_dog: {}, score: {}".format(results[0], results[1]))
# Out:
# Predicted class for test_cat: dogs, score: [[1. 0.]]
# Predicted class for test_dog: cats, score: [[0.08277091 0.9172291 ]]

# %%
totalscore = []

for sample_index in test_dataset_A: # A: dogs
    
#     print(sample_index)
    test_img = cv2.imread(sample_index)
    # print(test_cat)
#     cv2.imshow('My Image', test_cat)

    test_img = cv2.resize(test_img, (img_size, img_size), cv2.INTER_LINEAR) / 255

#     preview_cat = plt.imshow(test_cat.reshape(img_size, img_size, num_channels))

    np.set_printoptions(suppress=True)

    results = sample_prediction(test_img)
    print("Predicted class for test_cat: {}, score: {}".format(results[0], results[1]))
    
#     print(len(results[1][0]))
#     print(results[1][0][0])
    totalscore.append(results[1][0][0])

print(len(totalscore))
# print(totalscore)
print(sum(totalscore)/100)
# Out:
# Predicted class for test_cat: cats, score: [[0.0014768 0.9985232]]
# Predicted class for test_cat: dogs, score: [[0.9998286  0.00017144]]
# Predicted class for test_cat: cats, score: [[0.00887794 0.991122  ]]
# Predicted class for test_cat: dogs, score: [[0.99999964 0.00000035]]
# Predicted class for test_cat: dogs, score: [[0.9999869  0.00001309]]
# Predicted class for test_cat: cats, score: [[0.00031727 0.9996828 ]]
# Predicted class for test_cat: dogs, score: [[0.9529739  0.04702611]]
# Predicted class for test_cat: dogs, score: [[0.84325117 0.15674882]]
# Predicted class for test_cat: dogs, score: [[0.7971125  0.20288745]]
# Predicted class for test_cat: cats, score: [[0. 1.]]
# Predicted class for test_cat: cats, score: [[0.00000021 0.99999976]]
# Predicted class for test_cat: dogs, score: [[0.9997396  0.00026041]]
# Predicted class for test_cat: dogs, score: [[1.         0.00000002]]
# Predicted class for test_cat: dogs, score: [[0.9999846 0.0000154]]
# Predicted class for test_cat: dogs, score: [[0.924735   0.07526496]]
# Predicted class for test_cat: dogs, score: [[0.5263222 0.4736778]]
# Predicted class for test_cat: cats, score: [[0.00000061 0.9999994 ]]
# Predicted class for test_cat: cats, score: [[0.2391176 0.7608824]]
# Predicted class for test_cat: dogs, score: [[0.99999964 0.00000037]]
# Predicted class for test_cat: cats, score: [[0.03787752 0.96212244]]
# Predicted class for test_cat: dogs, score: [[1. 0.]]
# Predicted class for test_cat: dogs, score: [[0.9995782  0.00042188]]
# Predicted class for test_cat: cats, score: [[0.01201192 0.9879881 ]]
# Predicted class for test_cat: dogs, score: [[0.9999627 0.0000373]]
# Predicted class for test_cat: cats, score: [[0.00000045 0.9999995 ]]
# Predicted class for test_cat: dogs, score: [[0.73922396 0.26077604]]
# Predicted class for test_cat: dogs, score: [[0.9970542  0.00294575]]
# Predicted class for test_cat: cats, score: [[0.00061507 0.9993849 ]]
# Predicted class for test_cat: dogs, score: [[0.9999815  0.00001853]]
# Predicted class for test_cat: dogs, score: [[0.9999999  0.00000011]]
# Predicted class for test_cat: cats, score: [[0.02395334 0.9760467 ]]
# Predicted class for test_cat: dogs, score: [[0.73780996 0.26219   ]]
# Predicted class for test_cat: cats, score: [[0.00268951 0.9973105 ]]
# Predicted class for test_cat: dogs, score: [[0.9998523  0.00014768]]
# Predicted class for test_cat: dogs, score: [[1. 0.]]
# Predicted class for test_cat: dogs, score: [[0.99999595 0.000004  ]]
# Predicted class for test_cat: cats, score: [[0.00006219 0.9999378 ]]
# Predicted class for test_cat: dogs, score: [[0.85591435 0.14408557]]
# Predicted class for test_cat: cats, score: [[0.00799692 0.9920031 ]]
# Predicted class for test_cat: dogs, score: [[0.9806666  0.01933345]]
# Predicted class for test_cat: cats, score: [[0. 1.]]
# Predicted class for test_cat: cats, score: [[0.04106228 0.95893776]]
# Predicted class for test_cat: dogs, score: [[1.         0.00000002]]
# Predicted class for test_cat: cats, score: [[0.00000115 0.9999988 ]]
# Predicted class for test_cat: cats, score: [[0.06805391 0.9319461 ]]
# Predicted class for test_cat: cats, score: [[0.00014152 0.9998585 ]]
# Predicted class for test_cat: cats, score: [[0.4687428  0.53125715]]
# Predicted class for test_cat: dogs, score: [[0.8204762  0.17952384]]
# Predicted class for test_cat: dogs, score: [[0.99997973 0.0000203 ]]
# Predicted class for test_cat: dogs, score: [[0.66025347 0.33974653]]
# Predicted class for test_cat: dogs, score: [[0.9999999 0.0000001]]
# Predicted class for test_cat: dogs, score: [[0.94576466 0.05423538]]
# Predicted class for test_cat: dogs, score: [[0.9999968  0.00000327]]
# Predicted class for test_cat: dogs, score: [[1.         0.00000001]]
# Predicted class for test_cat: cats, score: [[0.31215394 0.68784606]]
# Predicted class for test_cat: dogs, score: [[0.91128945 0.08871057]]
# Predicted class for test_cat: cats, score: [[0.00054753 0.9994524 ]]
# Predicted class for test_cat: dogs, score: [[0.99998605 0.00001401]]
# Predicted class for test_cat: dogs, score: [[0.9998604  0.00013963]]
# Predicted class for test_cat: dogs, score: [[0.9380773  0.06192274]]
# Predicted class for test_cat: cats, score: [[0. 1.]]
# Predicted class for test_cat: dogs, score: [[0.9999988 0.0000012]]
# Predicted class for test_cat: cats, score: [[0.00043388 0.99956614]]
# Predicted class for test_cat: dogs, score: [[1. 0.]]
# Predicted class for test_cat: dogs, score: [[0.9997918  0.00020824]]
# Predicted class for test_cat: cats, score: [[0.03976214 0.96023786]]
# Predicted class for test_cat: dogs, score: [[0.99848145 0.0015185 ]]
# Predicted class for test_cat: dogs, score: [[0.9535835  0.04641652]]
# Predicted class for test_cat: cats, score: [[0.09949242 0.90050757]]
# Predicted class for test_cat: cats, score: [[0.24277739 0.7572226 ]]
# Predicted class for test_cat: dogs, score: [[0.98634386 0.0136561 ]]
# Predicted class for test_cat: dogs, score: [[0.99999654 0.00000342]]
# Predicted class for test_cat: dogs, score: [[0.99999547 0.00000456]]
# Predicted class for test_cat: cats, score: [[0.03896991 0.9610301 ]]
# Predicted class for test_cat: dogs, score: [[0.99984777 0.00015215]]
# Predicted class for test_cat: cats, score: [[0.01369244 0.98630756]]
# Predicted class for test_cat: dogs, score: [[0.9999999  0.00000017]]
# Predicted class for test_cat: dogs, score: [[0.9999347  0.00006536]]
# Predicted class for test_cat: dogs, score: [[0.9995245  0.00047549]]
# Predicted class for test_cat: dogs, score: [[0.99664754 0.00335248]]
# Predicted class for test_cat: cats, score: [[0.00000541 0.99999464]]
# Predicted class for test_cat: cats, score: [[0.33656773 0.6634323 ]]
# Predicted class for test_cat: cats, score: [[0.21664211 0.78335786]]
# Predicted class for test_cat: dogs, score: [[0.5140628  0.48593718]]
# Predicted class for test_cat: dogs, score: [[0.7861882  0.21381184]]
# Predicted class for test_cat: dogs, score: [[0.9999945 0.0000055]]
# Predicted class for test_cat: cats, score: [[0.00000027 0.99999976]]
# Predicted class for test_cat: dogs, score: [[0.62682945 0.3731705 ]]
# Predicted class for test_cat: cats, score: [[0.00544436 0.9945556 ]]
# Predicted class for test_cat: dogs, score: [[0.9870667  0.01293332]]
# Predicted class for test_cat: dogs, score: [[0.9999989  0.00000104]]
# Predicted class for test_cat: dogs, score: [[0.9999099  0.00009012]]
# Predicted class for test_cat: dogs, score: [[0.72762877 0.2723712 ]]
# Predicted class for test_cat: dogs, score: [[1. 0.]]
# Predicted class for test_cat: cats, score: [[0.00000003 1.        ]]
# Predicted class for test_cat: dogs, score: [[0.6670354  0.33296463]]
# Predicted class for test_cat: cats, score: [[0.38999045 0.6100096 ]]
# Predicted class for test_cat: cats, score: [[0.26444736 0.73555267]]
# Predicted class for test_cat: cats, score: [[0.08812509 0.9118749 ]]
# Predicted class for test_cat: dogs, score: [[0.98775685 0.0122431 ]]

# %%
totalscore = []

for sample_index in test_dataset_B: # A: dogs, B: cats
       
#     print(sample_index)
    test_img = cv2.imread(sample_index)
    # print(test_cat)
#     cv2.imshow('My Image', test_cat)

    test_img = cv2.resize(test_img, (img_size, img_size), cv2.INTER_LINEAR) / 255

#     preview_cat = plt.imshow(test_cat.reshape(img_size, img_size, num_channels))

    np.set_printoptions(suppress=True)

    results = sample_prediction(test_img)
    print("Predicted class for test_cat: {}, score: {}".format(results[0], results[1]))
    
#     print(len(results[1][0]))
#     print(results[1][0][1])
    totalscore.append(results[1][0][1])

print(len(totalscore))
# print(totalscore)
print(sum(totalscore)/100)
# Out:
# Predicted class for test_cat: cats, score: [[0.00003288 0.9999671 ]]
# Predicted class for test_cat: cats, score: [[0.0000642  0.99993575]]
# Predicted class for test_cat: cats, score: [[0.26770052 0.7322995 ]]
# Predicted class for test_cat: dogs, score: [[0.896364   0.10363597]]
# Predicted class for test_cat: cats, score: [[0.00098239 0.9990176 ]]
# Predicted class for test_cat: cats, score: [[0.00409328 0.9959067 ]]
# Predicted class for test_cat: dogs, score: [[1. 0.]]
# Predicted class for test_cat: cats, score: [[0.00406507 0.99593496]]
# Predicted class for test_cat: cats, score: [[0.00084826 0.9991517 ]]
# Predicted class for test_cat: cats, score: [[0.3453904 0.6546097]]
# Predicted class for test_cat: cats, score: [[0.00002411 0.9999759 ]]
# Predicted class for test_cat: cats, score: [[0.008443 0.991557]]
# Predicted class for test_cat: cats, score: [[0.00005637 0.9999436 ]]
# Predicted class for test_cat: dogs, score: [[0.9955373  0.00446276]]
# Predicted class for test_cat: cats, score: [[0. 1.]]
# Predicted class for test_cat: cats, score: [[0.0282329  0.97176707]]
# Predicted class for test_cat: cats, score: [[0.01268944 0.9873105 ]]
# Predicted class for test_cat: dogs, score: [[0.9983157  0.00168438]]
# Predicted class for test_cat: cats, score: [[0.00814427 0.99185574]]
# Predicted class for test_cat: cats, score: [[0.00066581 0.99933416]]
# Predicted class for test_cat: cats, score: [[0.00002417 0.9999758 ]]
# Predicted class for test_cat: cats, score: [[0. 1.]]
# Predicted class for test_cat: dogs, score: [[0.9999999  0.00000015]]
# Predicted class for test_cat: dogs, score: [[0.9999995  0.00000048]]
# Predicted class for test_cat: cats, score: [[0. 1.]]
# Predicted class for test_cat: cats, score: [[0.00000024 0.99999976]]
# Predicted class for test_cat: dogs, score: [[0.94345677 0.05654321]]
# Predicted class for test_cat: cats, score: [[0.00000003 1.        ]]
# Predicted class for test_cat: cats, score: [[0.00600484 0.99399513]]
# Predicted class for test_cat: cats, score: [[0.00000384 0.9999962 ]]
# Predicted class for test_cat: dogs, score: [[0.9991373  0.00086268]]
# Predicted class for test_cat: cats, score: [[0.0027322  0.99726784]]
# Predicted class for test_cat: dogs, score: [[0.96181047 0.03818957]]
# Predicted class for test_cat: cats, score: [[0.00564228 0.99435776]]
# Predicted class for test_cat: cats, score: [[0. 1.]]
# Predicted class for test_cat: dogs, score: [[0.99946374 0.00053621]]
# Predicted class for test_cat: cats, score: [[0.07220463 0.92779535]]
# Predicted class for test_cat: cats, score: [[0.00000302 0.999997  ]]
# Predicted class for test_cat: dogs, score: [[0.99897873 0.00102127]]
# Predicted class for test_cat: dogs, score: [[0.99999964 0.00000034]]
# Predicted class for test_cat: cats, score: [[0.02217072 0.97782934]]
# Predicted class for test_cat: cats, score: [[0.0728666 0.9271334]]
# Predicted class for test_cat: cats, score: [[0.22484633 0.7751537 ]]
# Predicted class for test_cat: cats, score: [[0. 1.]]
# Predicted class for test_cat: dogs, score: [[0.9999906  0.00000943]]
# Predicted class for test_cat: cats, score: [[0.00000002 1.        ]]
# Predicted class for test_cat: cats, score: [[0.00007743 0.9999225 ]]
# Predicted class for test_cat: cats, score: [[0.00000015 0.9999999 ]]
# Predicted class for test_cat: cats, score: [[0.00050184 0.9994981 ]]
# Predicted class for test_cat: cats, score: [[0.00137425 0.99862576]]
# Predicted class for test_cat: dogs, score: [[0.99999547 0.00000458]]
# Predicted class for test_cat: cats, score: [[0.00031031 0.9996897 ]]
# Predicted class for test_cat: dogs, score: [[0.99999905 0.00000098]]
# Predicted class for test_cat: cats, score: [[0.00016393 0.9998361 ]]
# Predicted class for test_cat: cats, score: [[0. 1.]]
# Predicted class for test_cat: cats, score: [[0. 1.]]
# Predicted class for test_cat: cats, score: [[0.02307322 0.97692674]]
# Predicted class for test_cat: dogs, score: [[0.99988353 0.0001164 ]]
# Predicted class for test_cat: dogs, score: [[1. 0.]]
# Predicted class for test_cat: cats, score: [[0.48494846 0.5150516 ]]
# Predicted class for test_cat: cats, score: [[0.00000143 0.99999857]]
# Predicted class for test_cat: cats, score: [[0.00000012 0.9999999 ]]
# Predicted class for test_cat: cats, score: [[0.04836845 0.9516315 ]]
# Predicted class for test_cat: cats, score: [[0.19045106 0.809549  ]]
# Predicted class for test_cat: cats, score: [[0.05694495 0.9430551 ]]
# Predicted class for test_cat: cats, score: [[0.00000005 1.        ]]
# Predicted class for test_cat: dogs, score: [[0.9999914  0.00000861]]
# Predicted class for test_cat: cats, score: [[0. 1.]]
# Predicted class for test_cat: cats, score: [[0.00000333 0.99999666]]
# Predicted class for test_cat: cats, score: [[0.00016091 0.99983907]]
# Predicted class for test_cat: cats, score: [[0.00000028 0.99999976]]
# Predicted class for test_cat: dogs, score: [[0.99578387 0.00421612]]
# Predicted class for test_cat: dogs, score: [[0.9918771  0.00812294]]
# Predicted class for test_cat: cats, score: [[0.00001791 0.9999821 ]]
# Predicted class for test_cat: dogs, score: [[0.8270102  0.17298971]]
# Predicted class for test_cat: dogs, score: [[1. 0.]]
# Predicted class for test_cat: cats, score: [[0.00002296 0.999977  ]]
# Predicted class for test_cat: cats, score: [[0.00112993 0.9988701 ]]
# Predicted class for test_cat: cats, score: [[0.03417243 0.9658275 ]]
# Predicted class for test_cat: cats, score: [[0.26116708 0.73883295]]
# Predicted class for test_cat: dogs, score: [[0.6237908  0.37620923]]
# Predicted class for test_cat: cats, score: [[0.00359422 0.99640584]]
# Predicted class for test_cat: cats, score: [[0.00002183 0.9999782 ]]
# Predicted class for test_cat: dogs, score: [[0.9999622  0.00003773]]
# Predicted class for test_cat: cats, score: [[0.00001454 0.99998546]]
# Predicted class for test_cat: cats, score: [[0.02391017 0.97608984]]
# Predicted class for test_cat: cats, score: [[0.00000057 0.9999994 ]]
# Predicted class for test_cat: cats, score: [[0.04519471 0.9548053 ]]
# Predicted class for test_cat: dogs, score: [[0.84328586 0.15671419]]
# Predicted class for test_cat: cats, score: [[0.000003 0.999997]]
# Predicted class for test_cat: cats, score: [[0. 1.]]
# Predicted class for test_cat: dogs, score: [[0.9718746  0.02812543]]
# Predicted class for test_cat: cats, score: [[0.00056584 0.9994342 ]]
# Predicted class for test_cat: cats, score: [[0.02446875 0.9755313 ]]
# Predicted class for test_cat: cats, score: [[0.00020565 0.9997944 ]]
# Predicted class for test_cat: cats, score: [[0.0000634 0.9999366]]
# Predicted class for test_cat: cats, score: [[0.00003252 0.99996746]]
# Predicted class for test_cat: cats, score: [[0.00000014 0.9999999 ]]
# Predicted class for test_cat: cats, score: [[0.00312946 0.9968706 ]]
# Predicted class for test_cat: dogs, score: [[0.9965899  0.00341017]]
# 100
# 0.7166487583751859
