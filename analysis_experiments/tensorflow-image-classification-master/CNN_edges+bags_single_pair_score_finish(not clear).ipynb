# %% [markdown]
# # TensorFlow Convolutional Neural Network for Image Classification

# %%
import time
import math
import random

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import dataset
import cv2

from sklearn.metrics import confusion_matrix
from datetime import timedelta
from glob import glob

# %matplotlib inline

# %% [markdown]
# ## Configuration and Hyperparameters

# %%
# Convolutional Layer 1.
filter_size1 = 3 
num_filters1 = 32

# Convolutional Layer 2.
filter_size2 = 3
num_filters2 = 32

# Convolutional Layer 3.
filter_size3 = 3
num_filters3 = 64

# Fully-connected layer.
fc_size = 128             # Number of neurons in fully-connected layer.

# Number of color channels for the images: 1 channel for gray-scale.
num_channels = 3

# image dimensions (only squares for now)
img_size = 256

# Size of image when flattened to a single dimension
img_size_flat = img_size * img_size * num_channels

# Tuple with height and width of images used to reshape arrays.
img_shape = (img_size, img_size)

# class info
classes = ['edges', 'bags']
num_classes = len(classes)

# batch size
batch_size = 32

# validation split
validation_size = .16

# how long to wait after validation loss stops improving before terminating training
early_stopping = None  # use None if you don't want to implement early stoping

train_path = 'data/train/'
test_path = 'data/test/'
checkpoint_dir = "models/"

# %% [markdown]
# ## Load Data

# %%
data = dataset.read_train_sets(train_path, img_size, classes, validation_size=validation_size)
test_images, test_ids = dataset.read_test_set(test_path, img_size)
# Out:
# Reading training images
# Loading edges files (Index: 0)
# Loading bags files (Index: 1)
# Reading test images

# %%
print("Size of:")
print("- Training-set:\t\t{}".format(len(data.train.labels)))
print("- Test-set:\t\t{}".format(len(test_images)))
print("- Validation-set:\t{}".format(len(data.valid.labels)))
# Out:
# Size of:
# - Training-set:		1344
# - Test-set:		2
# - Validation-set:	256

# %% [markdown]
# ### Helper-function for plotting images

# %%
def plot_images(images, cls_true, cls_pred=None):
    
    if len(images) == 0:
        print("no images to show")
        return 
    else:
        random_indices = random.sample(range(len(images)), min(len(images), 9))
        
    if cls_pred is not None:
        images, cls_true, cls_pred  = zip(*[(images[i], cls_true[i], cls_pred[i]) for i in random_indices])
    else:
        images, cls_true  = zip(*[(images[i], cls_true[i]) for i in random_indices])
    
    # Create figure with 3x3 sub-plots.
    fig, axes = plt.subplots(3, 3)
    fig.subplots_adjust(hspace=0.3, wspace=0.3)

    for i, ax in enumerate(axes.flat):
        # Plot image.
        ax.imshow(images[i].reshape(img_size, img_size, num_channels))

        # Show true and predicted classes.
        if cls_pred is None:
            xlabel = "True: {0}".format(cls_true[i])
        else:
            xlabel = "True: {0}, Pred: {1}".format(cls_true[i], cls_pred[i])

        # Show the classes as the label on the x-axis.
        ax.set_xlabel(xlabel)
        
        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])
    
    # Ensure the plot is shown correctly with multiple plots
    # in a single Notebook cell.
    plt.show()

# %% [markdown]
# Function used to plot 9 images in a 3x3 grid (or fewer, depending on how many images are passed), and writing the true and predicted classes below each image.

# %% [markdown]
# ### Plot a few images to see if data is correct

# %%
# Get some random images and their labels from the train set.

images, cls_true  = data.train.images, data.train.cls

# Plot the images and labels using our helper-function above.
plot_images(images=images, cls_true=cls_true)

# %% [markdown]
# ## TensorFlow Graph
#
# The entire purpose of TensorFlow is to have a so-called computational graph that can be executed much more efficiently than if the same calculations were to be performed directly in Python. TensorFlow can be more efficient than NumPy because TensorFlow knows the entire computation graph that must be executed, while NumPy only knows the computation of a single mathematical operation at a time.
#
# TensorFlow can also automatically calculate the gradients that are needed to optimize the variables of the graph so as to make the model perform better. This is because the graph is a combination of simple mathematical expressions so the gradient of the entire graph can be calculated using the chain-rule for derivatives.
#
# A TensorFlow graph consists of the following parts which will be detailed below:
#
# * Placeholder variables used for inputting data to the graph.
# * Variables that are going to be optimized so as to make the convolutional network perform better.
# * The mathematical formulas for the convolutional network.
# * A cost measure that can be used to guide the optimization of the variables.
# * An optimization method which updates the variables.

# %% [markdown]
# ### Helper-functions for creating new variables

# %% [markdown]
# Functions for creating new TensorFlow variables in the given shape and initializing them with random values. Note that the initialization is not actually done at this point, it is merely being defined in the TensorFlow graph.

# %%
def new_weights(shape):
    return tf.Variable(tf.truncated_normal(shape, stddev=0.05))

# %%
def new_biases(length):
    return tf.Variable(tf.constant(0.05, shape=[length]))

# %% [markdown]
# ### Helper-function for creating a new Convolutional Layer

# %% [markdown]
# This function creates a new convolutional layer in the computational graph for TensorFlow. Nothing is actually calculated here, we are just adding the mathematical formulas to the TensorFlow graph.
#
# It is assumed that the input is a 4-dim tensor with the following dimensions:
#
# 1. Image number.
# 2. Y-axis of each image.
# 3. X-axis of each image.
# 4. Channels of each image.
#
# Note that the input channels may either be colour-channels, or it may be filter-channels if the input is produced from a previous convolutional layer.
#
# The output is another 4-dim tensor with the following dimensions:
#
# 1. Image number, same as input.
# 2. Y-axis of each image. If 2x2 pooling is used, then the height and width of the input images is divided by 2.
# 3. X-axis of each image. Ditto.
# 4. Channels produced by the convolutional filters.

# %%
def new_conv_layer(input,              # The previous layer.
                   num_input_channels, # Num. channels in prev. layer.
                   filter_size,        # Width and height of each filter.
                   num_filters,        # Number of filters.
                   use_pooling=True):  # Use 2x2 max-pooling.

    # Shape of the filter-weights for the convolution.
    # This format is determined by the TensorFlow API.
    shape = [filter_size, filter_size, num_input_channels, num_filters]

    # Create new weights aka. filters with the given shape.
    weights = new_weights(shape=shape)

    # Create new biases, one for each filter.
    biases = new_biases(length=num_filters)

    # Create the TensorFlow operation for convolution.
    # Note the strides are set to 1 in all dimensions.
    # The first and last stride must always be 1,
    # because the first is for the image-number and
    # the last is for the input-channel.
    # But e.g. strides=[1, 2, 2, 1] would mean that the filter
    # is moved 2 pixels across the x- and y-axis of the image.
    # The padding is set to 'SAME' which means the input image
    # is padded with zeroes so the size of the output is the same.
    layer = tf.nn.conv2d(input=input,
                         filter=weights,
                         strides=[1, 1, 1, 1],
                         padding='SAME')

    # Add the biases to the results of the convolution.
    # A bias-value is added to each filter-channel.
    layer += biases

    # Use pooling to down-sample the image resolution?
    if use_pooling:
        # This is 2x2 max-pooling, which means that we
        # consider 2x2 windows and select the largest value
        # in each window. Then we move 2 pixels to the next window.
        layer = tf.nn.max_pool(value=layer,
                               ksize=[1, 2, 2, 1],
                               strides=[1, 2, 2, 1],
                               padding='SAME')

    # Rectified Linear Unit (ReLU).
    # It calculates max(x, 0) for each input pixel x.
    # This adds some non-linearity to the formula and allows us
    # to learn more complicated functions.
    layer = tf.nn.relu(layer)

    # Note that ReLU is normally executed before the pooling,
    # but since relu(max_pool(x)) == max_pool(relu(x)) we can
    # save 75% of the relu-operations by max-pooling first.

    # We return both the resulting layer and the filter-weights
    # because we will plot the weights later.
    return layer, weights

# %% [markdown]
# ### Helper-function for flattening a layer
#
# A convolutional layer produces an output tensor with 4 dimensions. We will add fully-connected layers after the convolution layers, so we need to reduce the 4-dim tensor to 2-dim which can be used as input to the fully-connected layer.

# %%
def flatten_layer(layer):
    # Get the shape of the input layer.
    layer_shape = layer.get_shape()

    # The shape of the input layer is assumed to be:
    # layer_shape == [num_images, img_height, img_width, num_channels]

    # The number of features is: img_height * img_width * num_channels
    # We can use a function from TensorFlow to calculate this.
    num_features = layer_shape[1:4].num_elements()
    
    # Reshape the layer to [num_images, num_features].
    # Note that we just set the size of the second dimension
    # to num_features and the size of the first dimension to -1
    # which means the size in that dimension is calculated
    # so the total size of the tensor is unchanged from the reshaping.
    layer_flat = tf.reshape(layer, [-1, num_features])

    # The shape of the flattened layer is now:
    # [num_images, img_height * img_width * num_channels]

    # Return both the flattened layer and the number of features.
    return layer_flat, num_features

# %% [markdown]
# ### Helper-function for creating a new Fully-Connected Layer

# %% [markdown]
# This function creates a new fully-connected layer in the computational graph for TensorFlow. Nothing is actually calculated here, we are just adding the mathematical formulas to the TensorFlow graph.
#
# It is assumed that the input is a 2-dim tensor of shape `[num_images, num_inputs]`. The output is a 2-dim tensor of shape `[num_images, num_outputs]`.

# %%
def new_fc_layer(input,          # The previous layer.
                 num_inputs,     # Num. inputs from prev. layer.
                 num_outputs,    # Num. outputs.
                 use_relu=True): # Use Rectified Linear Unit (ReLU)?

    # Create new weights and biases.
    weights = new_weights(shape=[num_inputs, num_outputs])
    biases = new_biases(length=num_outputs)

    # Calculate the layer as the matrix multiplication of
    # the input and weights, and then add the bias-values.
    layer = tf.matmul(input, weights) + biases

    # Use ReLU?
    if use_relu:
        layer = tf.nn.relu(layer)

    return layer

# %% [markdown]
# ### Placeholder variables

# %% [markdown]
# Placeholder variables serve as the input to the TensorFlow computational graph that we may change each time we execute the graph. We call this feeding the placeholder variables and it is demonstrated further below.
#
# First we define the placeholder variable for the input images. This allows us to change the images that are input to the TensorFlow graph. This is a so-called tensor, which just means that it is a multi-dimensional vector or matrix. The data-type is set to `float32` and the shape is set to `[None, img_size_flat]`, where `None` means that the tensor may hold an arbitrary number of images with each image being a vector of length `img_size_flat`.

# %%
x = tf.placeholder(tf.float32, shape=[None, img_size_flat], name='x')

# %% [markdown]
# The convolutional layers expect `x` to be encoded as a 4-dim tensor so we have to reshape it so its shape is instead `[num_images, img_height, img_width, num_channels]`. Note that `img_height == img_width == img_size` and `num_images` can be inferred automatically by using -1 for the size of the first dimension. So the reshape operation is:

# %%
x_image = tf.reshape(x, [-1, img_size, img_size, num_channels])

# %% [markdown]
# Next we have the placeholder variable for the true labels associated with the images that were input in the placeholder variable `x`. The shape of this placeholder variable is `[None, num_classes]` which means it may hold an arbitrary number of labels and each label is a vector of length `num_classes`.

# %%
y_true = tf.placeholder(tf.float32, shape=[None, num_classes], name='y_true')

# %% [markdown]
# We could also have a placeholder variable for the class-number, but we will instead calculate it using argmax. Note that this is a TensorFlow operator so nothing is calculated at this point.

# %%
y_true_cls = tf.argmax(y_true, axis=1)

# %% [markdown]
# ### Convolutional Layer 1
#
# Create the first convolutional layer. It takes `x_image` as input and creates `num_filters1` different filters, each having width and height equal to `filter_size1`. Finally we wish to down-sample the image so it is half the size by using 2x2 max-pooling.

# %%
layer_conv1, weights_conv1 = \
    new_conv_layer(input=x_image,
                   num_input_channels=num_channels,
                   filter_size=filter_size1,
                   num_filters=num_filters1,
                   use_pooling=True)

# %%
layer_conv1
# Out:
# <tf.Tensor 'Relu:0' shape=(?, 128, 128, 32) dtype=float32>

# %% [markdown]
# ### Convolutional Layers 2 and 3
#
# Create the second and third convolutional layers, which take as input the output from the first and second convolutional layer respectively. The number of input channels corresponds to the number of filters in the previous convolutional layer.

# %%
layer_conv2, weights_conv2 = \
    new_conv_layer(input=layer_conv1,
                   num_input_channels=num_filters1,
                   filter_size=filter_size2,
                   num_filters=num_filters2,
                   use_pooling=True)

# %%
layer_conv2
# Out:
# <tf.Tensor 'Relu_1:0' shape=(?, 64, 64, 32) dtype=float32>

# %%
layer_conv3, weights_conv3 = \
    new_conv_layer(input=layer_conv2,
                   num_input_channels=num_filters2,
                   filter_size=filter_size3,
                   num_filters=num_filters3,
                   use_pooling=True)

# %%
layer_conv3
# Out:
# <tf.Tensor 'Relu_2:0' shape=(?, 32, 32, 64) dtype=float32>

# %% [markdown]
# ### Flatten Layer
#
# The convolutional layers output 4-dim tensors. We now wish to use these as input in a fully-connected network, which requires for the tensors to be reshaped or flattened to 2-dim tensors.

# %%
layer_flat, num_features = flatten_layer(layer_conv3)

# %%
layer_flat
# Out:
# <tf.Tensor 'Reshape_1:0' shape=(?, 65536) dtype=float32>

# %%
num_features
# Out:
# 65536

# %% [markdown]
# ### Fully-Connected Layer 1
#
# Add a fully-connected layer to the network. The input is the flattened layer from the previous convolution. The number of neurons or nodes in the fully-connected layer is `fc_size`. ReLU is used so we can learn non-linear relations.

# %%
layer_fc1 = new_fc_layer(input=layer_flat,
                         num_inputs=num_features,
                         num_outputs=fc_size,
                         use_relu=True)

# %% [markdown]
# Check that the output of the fully-connected layer is a tensor with shape (?, 128) where the ? means there is an arbitrary number of images and `fc_size` == 128.

# %%
layer_fc1
# Out:
# <tf.Tensor 'Relu_3:0' shape=(?, 128) dtype=float32>

# %% [markdown]
# ### Fully-Connected Layer 2
#
# Add another fully-connected layer that outputs vectors of length num_classes for determining which of the classes the input image belongs to. Note that ReLU is not used in this layer.

# %%
layer_fc2 = new_fc_layer(input=layer_fc1,
                         num_inputs=fc_size,
                         num_outputs=num_classes,
                         use_relu=False)

# %%
layer_fc2
# Out:
# <tf.Tensor 'add_4:0' shape=(?, 2) dtype=float32>

# %% [markdown]
# ### Predicted Class

# %% [markdown]
# The second fully-connected layer estimates how likely it is that the input image belongs to each of the 2 classes. However, these estimates are a bit rough and difficult to interpret because the numbers may be very small or large, so we want to normalize them so that each element is limited between zero and one and the all the elements sum to one. This is calculated using the so-called softmax function and the result is stored in `y_pred`.

# %%
y_pred = tf.nn.softmax(layer_fc2)

# %% [markdown]
# The class-number is the index of the largest element.

# %%
y_pred_cls = tf.argmax(y_pred, axis=1)

# %% [markdown]
# ### Cost-function to be optimized

# %% [markdown]
# To make the model better at classifying the input images, we must somehow change the variables for all the network layers. To do this we first need to know how well the model currently performs by comparing the predicted output of the model `y_pred` to the desired output `y_true`.
#
# The cross-entropy is a performance measure used in classification. The cross-entropy is a continuous function that is always positive and if the predicted output of the model exactly matches the desired output then the cross-entropy equals zero. The goal of optimization is therefore to minimize the cross-entropy so it gets as close to zero as possible by changing the variables of the network layers.
#
# TensorFlow has a built-in function for calculating the cross-entropy. Note that the function calculates the softmax internally so we must use the output of `layer_fc2` directly rather than `y_pred` which has already had the softmax applied.

# %%
cross_entropy = tf.nn.softmax_cross_entropy_with_logits_v2(logits=layer_fc2, labels=y_true)

# %% [markdown]
# We have now calculated the cross-entropy for each of the image classifications so we have a measure of how well the model performs on each image individually. But in order to use the cross-entropy to guide the optimization of the model's variables we need a single scalar value, so we simply take the average of the cross-entropy for all the image classifications.

# %%
cost = tf.reduce_mean(cross_entropy)

# %% [markdown]
# ### Optimization Method

# %% [markdown]
# Now that we have a cost measure that must be minimized, we can then create an optimizer. In this case it is the `AdamOptimizer` which is an advanced form of Gradient Descent.
#
# Note that optimization is not performed at this point. In fact, nothing is calculated at all, we just add the optimizer-object to the TensorFlow graph for later execution.

# %%
optimizer = tf.train.AdamOptimizer(learning_rate=1e-4).minimize(cost)

# %% [markdown]
# ### Performance Measures

# %% [markdown]
# We need a few more performance measures to display the progress to the user.
#
# This is a vector of booleans whether the predicted class equals the true class of each image.

# %%
correct_prediction = tf.equal(y_pred_cls, y_true_cls)

# %% [markdown]
# This calculates the classification accuracy by first type-casting the vector of booleans to floats, so that False becomes 0 and True becomes 1, and then calculating the average of these numbers.

# %%
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %% [markdown]
# ## TensorFlow Run

# %% [markdown]
# ### Create TensorFlow session
#
# Once the TensorFlow graph has been created, we have to create a TensorFlow session which is used to execute the graph.

# %%
session = tf.Session()

# %% [markdown]
# ### Initialize variables
#
# The variables for `weights` and `biases` must be initialized before we start optimizing them.

# %%
session.run(tf.global_variables_initializer())

# %% [markdown]
# ### Helper-function to perform optimization iterations

# %% [markdown]
# It takes a long time to calculate the gradient of the model using the entirety of a large dataset
# . We therefore only use a small batch of images in each iteration of the optimizer.
#
# If your computer crashes or becomes very slow because you run out of RAM, then you may try and lower this number, but you may then need to perform more optimization iterations.

# %%
train_batch_size = batch_size

# %%
def print_progress(epoch, feed_dict_train, feed_dict_validate, val_loss):
    # Calculate the accuracy on the training-set.
    acc = session.run(accuracy, feed_dict=feed_dict_train)
    val_acc = session.run(accuracy, feed_dict=feed_dict_validate)
    msg = "Epoch {0} --- Training Accuracy: {1:>6.1%}, Validation Accuracy: {2:>6.1%}, Validation Loss: {3:.3f}"
    print(msg.format(epoch + 1, acc, val_acc, val_loss))

# %% [markdown]
# Function for performing a number of optimization iterations so as to gradually improve the variables of the network layers. In each iteration, a new batch of data is selected from the training-set and then TensorFlow executes the optimizer using those training samples.  The progress is printed every 100 iterations.

# %%
# Counter for total number of iterations performed so far.
total_iterations = 0

def optimize(num_iterations):
    # Ensure we update the global variable rather than a local copy.
    global total_iterations

    # Start-time used for printing time-usage below.
    start_time = time.time()
    
    best_val_loss = float("inf")
    patience = 0

    for i in range(total_iterations,
                   total_iterations + num_iterations):

        # Get a batch of training examples.
        # x_batch now holds a batch of images and
        # y_true_batch are the true labels for those images.
        x_batch, y_true_batch, _, cls_batch = data.train.next_batch(train_batch_size)
        x_valid_batch, y_valid_batch, _, valid_cls_batch = data.valid.next_batch(train_batch_size)

        # Convert shape from [num examples, rows, columns, depth]
        # to [num examples, flattened image shape]

        x_batch = x_batch.reshape(train_batch_size, img_size_flat)
        x_valid_batch = x_valid_batch.reshape(train_batch_size, img_size_flat)

        # Put the batch into a dict with the proper names
        # for placeholder variables in the TensorFlow graph.
        feed_dict_train = {x: x_batch,
                           y_true: y_true_batch}
        
        feed_dict_validate = {x: x_valid_batch,
                              y_true: y_valid_batch}

        # Run the optimizer using this batch of training data.
        # TensorFlow assigns the variables in feed_dict_train
        # to the placeholder variables and then runs the optimizer.
        session.run(optimizer, feed_dict=feed_dict_train)
        

        # Print status at end of each epoch (defined as full pass through training dataset).
        if i % int(data.train.num_examples/batch_size) == 0: 
            val_loss = session.run(cost, feed_dict=feed_dict_validate)
            epoch = int(i / int(data.train.num_examples/batch_size))
            
            print_progress(epoch, feed_dict_train, feed_dict_validate, val_loss)
            
            if early_stopping:    
                if val_loss < best_val_loss:
                    best_val_loss = val_loss
                    patience = 0
                else:
                    patience += 1

                if patience == early_stopping:
                    break

    # Update the total number of iterations performed.
    total_iterations += num_iterations

    # Ending time.
    end_time = time.time()

    # Difference between start and end-times.
    time_dif = end_time - start_time

    # Print the time-usage.
    print("Time elapsed: " + str(timedelta(seconds=int(round(time_dif)))))

# %% [markdown]
# ### Helper-function to plot example errors

# %% [markdown]
# Function for plotting examples of images from the test-set that have been mis-classified.

# %%
def plot_example_errors(cls_pred, correct):
    # cls_pred is an array of the predicted class-number for
    # all images in the test-set.

    # correct is a boolean array whether the predicted class
    # is equal to the true class for each image in the test-set.

    # Negate the boolean array.
    incorrect = (correct == False)
    
    # Get the images from the test-set that have been
    # incorrectly classified.
    images = data.valid.images[incorrect]
    
    # Get the predicted classes for those images.
    cls_pred = cls_pred[incorrect]

    # Get the true classes for those images.
    cls_true = data.valid.cls[incorrect]

    # Plot the first 9 images.
    plot_images(images=images, cls_true=cls_true, cls_pred=cls_pred)

# %% [markdown]
# ### Helper-function to plot confusion matrix

# %%
def plot_confusion_matrix(cls_pred):
    # cls_pred is an array of the predicted class-number for
    # all images in the test-set.

    # Get the true classifications for the test-set.
    cls_true = data.valid.cls
    
    # Get the confusion matrix using sklearn.
    cm = confusion_matrix(y_true=cls_true,
                          y_pred=cls_pred)

    # Print the confusion matrix as text.
    print(cm)

    # Plot the confusion matrix as an image.
    plt.matshow(cm)

    # Make various adjustments to the plot.
    plt.colorbar()
    tick_marks = np.arange(num_classes)
    plt.xticks(tick_marks, range(num_classes))
    plt.yticks(tick_marks, range(num_classes))
    plt.xlabel('Predicted')
    plt.ylabel('True')

    # Ensure the plot is shown correctly with multiple plots
    # in a single Notebook cell.
    plt.show()

# %% [markdown]
# ### Helper-function for showing the performance

# %% [markdown]
# Function for printing the classification accuracy on the test-set.
#
# It takes a while to compute the classification for all the images in the test-set, that's why the results are re-used by calling the above functions directly from this function, so the classifications don't have to be recalculated by each function.
#
# Note that this function can use a lot of computer memory, which is why the test-set is split into smaller batches. If you have little RAM in your computer and it crashes, then you can try and lower the batch-size.

# %%
def print_validation_accuracy(show_example_errors=False, show_confusion_matrix=False):

    # Number of images in the test-set.
    num_test = len(data.valid.images)

    # Allocate an array for the predicted classes which
    # will be calculated in batches and filled into this array.
    cls_pred = np.zeros(shape=num_test, dtype=np.int)

    # Now calculate the predicted classes for the batches.
    # We will just iterate through all the batches.
    # There might be a more clever and Pythonic way of doing this.

    # The starting index for the next batch is denoted i.
    i = 0

    while i < num_test:
        # The ending index for the next batch is denoted j.
        j = min(i + batch_size, num_test)

        # Get the images from the test-set between index i and j.
        images = data.valid.images[i:j, :].reshape(batch_size, img_size_flat)
        

        # Get the associated labels.
        labels = data.valid.labels[i:j, :]

        # Create a feed-dict with these images and labels.
        feed_dict = {x: images,
                     y_true: labels}

        # Calculate the predicted class using TensorFlow.
        cls_pred[i:j] = session.run(y_pred_cls, feed_dict=feed_dict)

        # Set the start-index for the next batch to the
        # end-index of the current batch.
        i = j

    cls_true = np.array(data.valid.cls)
    cls_pred = np.array([classes[x] for x in cls_pred]) 

    # Create a boolean array whether each image is correctly classified.
    correct = (cls_true == cls_pred)

    # Calculate the number of correctly classified images.
    # When summing a boolean array, False means 0 and True means 1.
    correct_sum = correct.sum()

    # Classification accuracy is the number of correctly classified
    # images divided by the total number of images in the test-set.
    acc = float(correct_sum) / num_test

    # Print the accuracy.
    msg = "Accuracy on Test-Set: {0:.1%} ({1} / {2})"
    print(msg.format(acc, correct_sum, num_test))

    # Plot some examples of mis-classifications, if desired.
    if show_example_errors:
        print("Example errors:")
        plot_example_errors(cls_pred=cls_pred, correct=correct)

    # Plot the confusion matrix, if desired.
    if show_confusion_matrix:
        print("Confusion Matrix:")
        plot_confusion_matrix(cls_pred=cls_pred)

# %% [markdown]
# ## Performance after 1 optimization iteration

# %%
# !pip install --upgrade tensorflow-gpu==1.

# %%
optimize(num_iterations=1)
print_validation_accuracy()
# Out:
# Epoch 1 --- Training Accuracy:  46.9%, Validation Accuracy:  59.4%, Validation Loss: 0.674
# Time elapsed: 0:00:03
# Accuracy on Test-Set: 49.2% (126 / 256)

# %% [markdown]
# ## Performance after 100 optimization iterations
#
# After 100 optimization iterations, the model should have significantly improved its classification accuracy.

# %%
optimize(num_iterations=99)  # We already performed 1 iteration above.
# Out:
# Epoch 2 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.077
# Epoch 3 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.055
# Time elapsed: 0:00:05

# %%
# print_validation_accuracy(show_example_errors=True)

# %% [markdown]
# ## Performance after 1000 optimization iterations

# %%
optimize(num_iterations=900)  # We performed 100 iterations above.
# Out:
# Epoch 4 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.013
# Epoch 5 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.006
# Epoch 6 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.003
# Epoch 7 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.013
# Epoch 8 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.013
# Epoch 9 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.006
# Epoch 10 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.001
# Epoch 11 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.023
# Epoch 12 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.003
# Epoch 13 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.001
# Epoch 14 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.001
# Epoch 15 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.032
# Epoch 16 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.001
# Epoch 17 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 18 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 19 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.041
# Epoch 20 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 21 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 22 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 23 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.059
# Epoch 24 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Time elapsed: 0:00:45

# %%
# print_validation_accuracy(show_example_errors=True)

# %% [markdown]
# ## Performance after 10,000 optimization iterations

# %%
optimize(num_iterations=9000) # We performed 1000 iterations above.
# Out:
# Epoch 25 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 26 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 27 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.065
# Epoch 28 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 29 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 30 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 31 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.065
# Epoch 32 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 33 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 34 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 35 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.071
# Epoch 36 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 37 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 38 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 39 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.080
# Epoch 40 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 41 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 42 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 43 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.089
# Epoch 44 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 45 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 46 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 47 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.098
# Epoch 48 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 49 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 50 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 51 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.106
# Epoch 52 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 53 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 54 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 55 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.114
# Epoch 56 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 57 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 58 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 59 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.122
# Epoch 60 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 61 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 62 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 63 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.129
# Epoch 64 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 65 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 66 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 67 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.136
# Epoch 68 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 69 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 70 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 71 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.143
# Epoch 72 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 73 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 74 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 75 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.150
# Epoch 76 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 77 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 78 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 79 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.156
# Epoch 80 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 81 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 82 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 83 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.162
# Epoch 84 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 85 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 86 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 87 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.166
# Epoch 88 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 89 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 90 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 91 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.171
# Epoch 92 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 93 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 94 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 95 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.175
# Epoch 96 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 97 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 98 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 99 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.179
# Epoch 100 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 101 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 102 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 103 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.182
# Epoch 104 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 105 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 106 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 107 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.186
# Epoch 108 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 109 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 110 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 111 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.189
# Epoch 112 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 113 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 114 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 115 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.192
# Epoch 116 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 117 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 118 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 119 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.195
# Epoch 120 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 121 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 122 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 123 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.199
# Epoch 124 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 125 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 126 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 127 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.202
# Epoch 128 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 129 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 130 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 131 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.205
# Epoch 132 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 133 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 134 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 135 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.208
# Epoch 136 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 137 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 138 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 139 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.210
# Epoch 140 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 141 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 142 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 143 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.213
# Epoch 144 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 145 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 146 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 147 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.216
# Epoch 148 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 149 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 150 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 151 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.219
# Epoch 152 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 153 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 154 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 155 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.221
# Epoch 156 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 157 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 158 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 159 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.224
# Epoch 160 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 161 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 162 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 163 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.227
# Epoch 164 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 165 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 166 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 167 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.230
# Epoch 168 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 169 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 170 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 171 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.232
# Epoch 172 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 173 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 174 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 175 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.235
# Epoch 176 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 177 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 178 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 179 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.238
# Epoch 180 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 181 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 182 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 183 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.240
# Epoch 184 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 185 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 186 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 187 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.243
# Epoch 188 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 189 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 190 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 191 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.245
# Epoch 192 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 193 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 194 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 195 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.248
# Epoch 196 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 197 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 198 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 199 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.250
# Epoch 200 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 201 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 202 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 203 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.252
# Epoch 204 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 205 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 206 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 207 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.255
# Epoch 208 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 209 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 210 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 211 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.257
# Epoch 212 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 213 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 214 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 215 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.259
# Epoch 216 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 217 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 218 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 219 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.262
# Epoch 220 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 221 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 222 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 223 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.264
# Epoch 224 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 225 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 226 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 227 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.266
# Epoch 228 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 229 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 230 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 231 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.269
# Epoch 232 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 233 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 234 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 235 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.271
# Epoch 236 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 237 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 238 --- Training Accuracy: 100.0%, Validation Accuracy: 100.0%, Validation Loss: 0.000
# Epoch 239 --- Training Accuracy: 100.0%, Validation Accuracy:  96.9%, Validation Loss: 0.273
# Time elapsed: 0:07:28

# %%
# print_validation_accuracy(show_example_errors=True, show_confusion_matrix=True)

# %% [markdown]
# ## Test on Sample Image

# %%
# # prepare testing data
# test_dataset_A = glob('.\\data\\test\\{}\\*.jpg'.format(classes[0]))
# test_dataset_B = glob('.\\data\\test\\{}\\*.jpg'.format(classes[1]))

# test_data_A_list = []
# test_data_B_list = []

# test_dataset_A


# for sample_index in range(min(len(test_dataset_A), len(test_dataset_B))):
#     test_batch_files = list(zip(test_dataset_A[sample_index : (sample_index + 1)],
#                                 test_dataset_B[sample_index : (sample_index + 1)]))
#     test_batch_images = [load_train_data(test_batch_file, 286, 256) for test_batch_file in test_batch_files]
#     test_batch_images = np.array(test_batch_images).astype(np.float32)

#     test_data_A_list.append(test_batch_images[:, :, :, : 3])
#     test_data_B_list.append(test_batch_images[:, :, :, 3:6])

# %%
# plt.axis('off')

# print(test_dataset_A[0])

# test_cat = cv2.imread(test_dataset_A[0])

# # plt.imshow(test_cat)
# # plt.imshow(test_cat)
# # plt.imshow(test_cat)

# for sample_index in test_dataset_A:
    
# #     print(sample_index)
#     test_cat = cv2.imread(sample_index)
#     # print(test_cat)
# #     cv2.imshow('My Image', test_cat)

#     test_cat = cv2.resize(test_cat, (img_size, img_size), cv2.INTER_LINEAR) / 255

#     preview_cat = plt.imshow(test_cat.reshape(img_size, img_size, num_channels))

# %%
img_size
# Out:
# 256

# %%
# test_dog = cv2.imread('.\\data\\test\\1.jpg')

# cv2.imshow('My Image', test_dog)

# test_dog = cv2.resize(test_dog, (img_size, img_size), cv2.INTER_LINEAR) / 255

# preview_dog = plt.imshow(test_dog.reshape(img_size, img_size, num_channels))

# %%
def sample_prediction(test_im):
    
    feed_dict_test = {
        x: test_im.reshape(1, img_size_flat),
        y_true: np.array([[1, 0]])
    }

    score, test_pred = session.run([y_pred, y_pred_cls] , feed_dict=feed_dict_test)
#     return classes[test_pred[0]]
    return classes[test_pred[0]], score


# np.set_printoptions(suppress=True)

# print(score)

# results = sample_prediction(test_cat)
# print("Predicted class for test_cat: {}, score: {}".format(results[0], results[1]))

# results = sample_prediction(test_dog)
# print("Predicted class for test_dog: {}, score: {}".format(results[0], results[1]))

# %%
# totalscore = []

# for sample_index in test_dataset_A: # A: dogs
    
# #     print(sample_index)
#     test_img = cv2.imread(sample_index)
#     # print(test_cat)
# #     cv2.imshow('My Image', test_cat)

#     test_img = cv2.resize(test_img, (img_size, img_size), cv2.INTER_LINEAR) / 255

# #     preview_cat = plt.imshow(test_cat.reshape(img_size, img_size, num_channels))

#     np.set_printoptions(suppress=True)

#     results = sample_prediction(test_img)
# #     print("Predicted class for test_cat: {}, score: {}".format(results[0], results[1]))
    
# #     print(len(results[1][0]))
# #     print(results[1][0][0])
#     totalscore.append(results[1][0])

# print(len(totalscore))
# # print(totalscore)
# print(sum(totalscore)/len(totalscore))

# %%
# totalscore = []

# for sample_index in test_dataset_B: # A: dogs, B: cats
       
# #     print(sample_index)
#     test_img = cv2.imread(sample_index)
#     # print(test_cat)
# #     cv2.imshow('My Image', test_cat)

#     test_img = cv2.resize(test_img, (img_size, img_size), cv2.INTER_LINEAR) / 255

# #     preview_cat = plt.imshow(test_cat.reshape(img_size, img_size, num_channels))

#     np.set_printoptions(suppress=True)

#     results = sample_prediction(test_img)
# #     print("Predicted class for test_cat: {}, score: {}".format(results[0], results[1]))
    
# #     print(len(results[1][0]))
# #     print(results[1][0][1])
#     totalscore.append(results[1][0])

# print(len(totalscore))
# # print(totalscore)
# print(sum(totalscore)/len(totalscore))

# %%
test_cases = ['case00','case01','case02','case03','case04',
              'case04','case05','case06','case05','case09', 'case10']

totalscore = []

for select_cases in test_cases:

    # prepare testing data
    test_dataset_C = glob('D:\\GitHub\\analysis_generated_pictures\\category\\bag_color(from_sk)\\{}\\cyclecoopnet\\*.png'.format(select_cases))
   
    for sample_index in test_dataset_C: 

    #     print(sample_index)
        test_img = cv2.imread(sample_index)
        # print(test_cat)
    #     cv2.imshow('My Image', test_cat)

        test_img = cv2.resize(test_img, (img_size, img_size), cv2.INTER_LINEAR) / 255

    #     preview_cat = plt.imshow(test_cat.reshape(img_size, img_size, num_channels))

        np.set_printoptions(suppress=True)

        results = sample_prediction(test_img)
    #     print("Predicted class for test_cat: {}, score: {}".format(results[0], results[1]))

    #     print(len(results[1][0]))
    #     print(results[1][0][1])
        totalscore.append(results[1][0])

        
        
        
        
print(len(totalscore))
# print(totalscore)
print(sum(totalscore)/len(totalscore))

# D:\GitHub\analysis_generated_pictures\category\bag_color(from_sk)\case00\cyclecoopnet

# %%
test_cases = ['case00','case01','case02','case03','case04',
              'case04','case05','case06','case05','case09', 'case10']

totalscore = []

for select_cases in test_cases:

    # prepare testing data
    test_dataset_C = glob('D:\\GitHub\\analysis_generated_pictures\\category\\bag_color(from_sk)\\{}\\cyclegan\\*.png'.format(select_cases))
   
    for sample_index in test_dataset_C: 

    #     print(sample_index)
        test_img = cv2.imread(sample_index)
        # print(test_cat)
    #     cv2.imshow('My Image', test_cat)

        test_img = cv2.resize(test_img, (img_size, img_size), cv2.INTER_LINEAR) / 255

    #     preview_cat = plt.imshow(test_cat.reshape(img_size, img_size, num_channels))

        np.set_printoptions(suppress=True)

        results = sample_prediction(test_img)
    #     print("Predicted class for test_cat: {}, score: {}".format(results[0], results[1]))

    #     print(len(results[1][0]))
    #     print(results[1][0][1])
        totalscore.append(results[1][0])

        
        
        
        
print(len(totalscore))
# print(totalscore)
print(sum(totalscore)/len(totalscore))

# D:\GitHub\analysis_generated_pictures\category\bag_color(from_sk)\case00\cyclecoopnet

# %%
test_cases = ['case00','case01','case02','case03','case04',
              'case04','case05','case06','case05','case09', 'case10']

totalscore = []

for select_cases in test_cases:

    # prepare testing data
    test_dataset_C = glob('D:\\GitHub\\analysis_generated_pictures\\category\\bag_color(from_sk)\\{}\\pix2pix\\*.png'.format(select_cases))
   
    for sample_index in test_dataset_C: 

    #     print(sample_index)
        test_img = cv2.imread(sample_index)
        # print(test_cat)
    #     cv2.imshow('My Image', test_cat)

        test_img = cv2.resize(test_img, (img_size, img_size), cv2.INTER_LINEAR) / 255

    #     preview_cat = plt.imshow(test_cat.reshape(img_size, img_size, num_channels))

        np.set_printoptions(suppress=True)

        results = sample_prediction(test_img)
    #     print("Predicted class for test_cat: {}, score: {}".format(results[0], results[1]))

    #     print(len(results[1][0]))
    #     print(results[1][0][1])
        totalscore.append(results[1][0])

        
        
        
        
print(len(totalscore))
# print(totalscore)
print(sum(totalscore)/len(totalscore))

# D:\GitHub\analysis_generated_pictures\category\bag_color(from_sk)\case00\cyclecoopnet

# %% [markdown]
# # bag_color(from_sk)

# %%
test_cases = ['case00','case01','case02','case03','case04',
              'case04','case05','case06','case05','case09', 'case10']

totalscore = []

test_category = "bag_color(from_sk)"
print("test_category: {}".format(test_category))

for select_cases in test_cases:

    # prepare testing data
    test_dataset_C = glob('D:\\GitHub\\analysis_generated_pictures\\category\\{}\\{}\\cyclecoopnet\\*.png'.format(test_category, select_cases))
   
    for sample_index in test_dataset_C: 

    #     print(sample_index)
        test_img = cv2.imread(sample_index)
        # print(test_cat)
    #     cv2.imshow('My Image', test_cat)

        test_img = cv2.resize(test_img, (img_size, img_size), cv2.INTER_LINEAR) / 255

    #     preview_cat = plt.imshow(test_cat.reshape(img_size, img_size, num_channels))

        np.set_printoptions(suppress=True)

        results = sample_prediction(test_img)
    #     print("Predicted class for test_cat: {}, score: {}".format(results[0], results[1]))

    #     print(len(results[1][0]))
    #     print(results[1][0][1])
        totalscore.append(results[1][0])

        
        
        
print("cyclecoopnet:")        
print(len(totalscore))
# print(totalscore)
print(sum(totalscore)/len(totalscore))


totalscore = []


for select_cases in test_cases:

    # prepare testing data
    test_dataset_C = glob('D:\\GitHub\\analysis_generated_pictures\\category\\{}\\{}\\cyclegan\\*.png'.format(test_category, select_cases))
   
    for sample_index in test_dataset_C: 

    #     print(sample_index)
        test_img = cv2.imread(sample_index)
        # print(test_cat)
    #     cv2.imshow('My Image', test_cat)

        test_img = cv2.resize(test_img, (img_size, img_size), cv2.INTER_LINEAR) / 255

    #     preview_cat = plt.imshow(test_cat.reshape(img_size, img_size, num_channels))

        np.set_printoptions(suppress=True)

        results = sample_prediction(test_img)
    #     print("Predicted class for test_cat: {}, score: {}".format(results[0], results[1]))
        print(results[0])

    #     print(len(results[1][0]))
    #     print(results[1][0][1])
        totalscore.append(results[1][0])

        
        
        
print("cyclegan:")        
print(len(totalscore))
# print(totalscore)
print(sum(totalscore)/len(totalscore))

totalscore = []

for select_cases in test_cases:

    # prepare testing data
    test_dataset_C = glob('D:\\GitHub\\analysis_generated_pictures\\category\\{}\\{}\\pix2pix\\*.png'.format(test_category, select_cases))
   
    for sample_index in test_dataset_C: 

    #     print(sample_index)
        test_img = cv2.imread(sample_index)
        # print(test_cat)
    #     cv2.imshow('My Image', test_cat)

        test_img = cv2.resize(test_img, (img_size, img_size), cv2.INTER_LINEAR) / 255

    #     preview_cat = plt.imshow(test_cat.reshape(img_size, img_size, num_channels))

        np.set_printoptions(suppress=True)

        results = sample_prediction(test_img)
    #     print("Predicted class for test_cat: {}, score: {}".format(results[0], results[1]))

    #     print(len(results[1][0]))
    #     print(results[1][0][1])
        totalscore.append(results[1][0])

        
        
        
print("pix2pix:")         
print(len(totalscore))
# print(totalscore)
print(sum(totalscore)/len(totalscore))
# Out:
# test_category: bag_color(from_sk)
# cyclecoopnet:
# 1100
# [0.00000009 0.9999999 ]
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# bags
# cyclegan:
# 1100
# [0.00005806 0.99994195]
# pix2pix:
# 1100
# [0. 1.]

# %% [markdown]
# # bag_sk(from_color)

# %%
test_cases = ['case00','case01','case02','case03','case04',
              'case04','case05','case06','case05','case09', 'case10']

totalscore = []

test_category = "bag_sk(from_color)"
print("test_category: {}".format(test_category))

for select_cases in test_cases:

    # prepare testing data
    test_dataset_C = glob('D:\\GitHub\\analysis_generated_pictures\\category\\{}\\{}\\cyclecoopnet\\*.png'.format(test_category, select_cases))
   
    for sample_index in test_dataset_C: 

    #     print(sample_index)
        test_img = cv2.imread(sample_index)
        # print(test_cat)
    #     cv2.imshow('My Image', test_cat)

        test_img = cv2.resize(test_img, (img_size, img_size), cv2.INTER_LINEAR) / 255

    #     preview_cat = plt.imshow(test_cat.reshape(img_size, img_size, num_channels))

        np.set_printoptions(suppress=True)

        results = sample_prediction(test_img)
    #     print("Predicted class for test_cat: {}, score: {}".format(results[0], results[1]))

    #     print(len(results[1][0]))
    #     print(results[1][0][1])
#         print(results[0])
        totalscore.append(results[1][0])

        
        
        
print("cyclecoopnet:")        
print(len(totalscore))
# print(totalscore)
print(sum(totalscore)/len(totalscore))

totalscore = []

for select_cases in test_cases:

    # prepare testing data
    test_dataset_C = glob('D:\\GitHub\\analysis_generated_pictures\\category\\{}\\{}\\cyclegan\\*.png'.format(test_category, select_cases))
   
    for sample_index in test_dataset_C: 

    #     print(sample_index)
        test_img = cv2.imread(sample_index)
        # print(test_cat)
    #     cv2.imshow('My Image', test_cat)

        test_img = cv2.resize(test_img, (img_size, img_size), cv2.INTER_LINEAR) / 255

    #     preview_cat = plt.imshow(test_cat.reshape(img_size, img_size, num_channels))

        np.set_printoptions(suppress=True)

        results = sample_prediction(test_img)
    #     print("Predicted class for test_cat: {}, score: {}".format(results[0], results[1]))

    #     print(len(results[1][0]))
    #     print(results[1][0][1])
        totalscore.append(results[1][0])

        
        
        
print("cyclegan:")        
print(len(totalscore))
# print(totalscore)
print(sum(totalscore)/len(totalscore))

totalscore = []

for select_cases in test_cases:

    # prepare testing data
    test_dataset_C = glob('D:\\GitHub\\analysis_generated_pictures\\category\\{}\\{}\\pix2pix\\*.png'.format(test_category, select_cases))
   
    for sample_index in test_dataset_C: 

    #     print(sample_index)
        test_img = cv2.imread(sample_index)
        # print(test_cat)
    #     cv2.imshow('My Image', test_cat)

        test_img = cv2.resize(test_img, (img_size, img_size), cv2.INTER_LINEAR) / 255

    #     preview_cat = plt.imshow(test_cat.reshape(img_size, img_size, num_channels))

        np.set_printoptions(suppress=True)

        results = sample_prediction(test_img)
    #     print("Predicted class for test_cat: {}, score: {}".format(results[0], results[1]))

    #     print(len(results[1][0]))
    #     print(results[1][0][1])
        totalscore.append(results[1][0])

        
        
        
print("pix2pix:")         
print(len(totalscore))
# print(totalscore)
print(sum(totalscore)/len(totalscore))
# Out:
# test_category: bag_sk(from_color)
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# bags
# bags
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# bags
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# bags
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# edges
# cyclecoopnet:
# 1100
# [0.9955399  0.00446206]
# cyclegan:
# 1100
# [0.3878573 0.6121425]
# pix2pix:
# 1100
# [0.999999   0.00000274]

# %%
totalscore
# Out:
# [array([0.99999845, 0.0000016 ], dtype=float32),
#  array([0.99999607, 0.00000393], dtype=float32),
#  array([0.9999956 , 0.00000441], dtype=float32),
#  array([0.9999974 , 0.00000263], dtype=float32),
#  array([0.9999957 , 0.00000432], dtype=float32),
#  array([0.99999475, 0.0000053 ], dtype=float32),
#  array([0.9999988 , 0.00000122], dtype=float32),
#  array([0.9999989 , 0.00000102], dtype=float32),
#  array([0.9999963 , 0.00000372], dtype=float32),
#  array([0.99999404, 0.00000593], dtype=float32),
#  array([0.999995  , 0.00000498], dtype=float32),
#  array([0.9999993 , 0.00000077], dtype=float32),
#  array([0.99999535, 0.00000471], dtype=float32),
#  array([0.99996436, 0.00003565], dtype=float32),
#  array([0.99999523, 0.00000483], dtype=float32),
#  array([0.99998415, 0.00001589], dtype=float32),
#  array([0.99999774, 0.00000228], dtype=float32),
#  array([0.9999337 , 0.00006631], dtype=float32),
#  array([0.9999982 , 0.00000182], dtype=float32),
#  array([0.9999974, 0.0000026], dtype=float32),
#  array([0.99999774, 0.0000023 ], dtype=float32),
#  array([0.9999988 , 0.00000125], dtype=float32),
#  array([0.9999987 , 0.00000134], dtype=float32),
#  array([0.99999785, 0.00000212], dtype=float32),
#  array([0.99999774, 0.00000222], dtype=float32),
#  array([0.99999654, 0.00000342], dtype=float32),
#  array([0.99999905, 0.00000091], dtype=float32),
#  array([0.99999905, 0.00000091], dtype=float32),
#  array([0.9999993 , 0.00000073], dtype=float32),
#  array([0.99999845, 0.00000157], dtype=float32),
#  array([0.9999994 , 0.00000058], dtype=float32),
#  array([0.9999994 , 0.00000058], dtype=float32),
#  array([0.99999845, 0.00000152], dtype=float32),
#  array([0.99998856, 0.0000114 ], dtype=float32),
#  array([0.9999987 , 0.00000125], dtype=float32),
#  array([0.99999726, 0.00000273], dtype=float32),
#  array([0.9999974 , 0.00000265], dtype=float32),
#  array([0.9999962 , 0.00000376], dtype=float32),
#  array([0.9999932 , 0.00000684], dtype=float32),
#  array([0.9999957 , 0.00000425], dtype=float32),
#  array([0.9999964 , 0.00000357], dtype=float32),
#  array([0.99999523, 0.00000478], dtype=float32),
#  array([0.9999993 , 0.00000068], dtype=float32),
#  array([0.9999975 , 0.00000255], dtype=float32),
#  array([0.99991703, 0.00008295], dtype=float32),
#  array([0.9999466, 0.0000534], dtype=float32),
#  array([0.9999896 , 0.00001041], dtype=float32),
#  array([0.9999968 , 0.00000326], dtype=float32),
#  array([0.99998546, 0.00001456], dtype=float32),
dtype=float32),
#  array([0.9999995 , 0.00000045], dtype=float32),
#  array([0.99999964, 0.00000034], dtype=float32),
#  array([0.9999968 , 0.00000321], dtype=float32),
#  array([0.9999994 , 0.00000064], dtype=float32),
#  array([0.9999778 , 0.00002218], dtype=float32),
#  array([0.9999964 , 0.00000357], dtype=float32),
#  array([0.99999964, 0.00000032], dtype=float32),
#  array([0.99999976, 0.00000023], dtype=float32),
#  array([0.99999976, 0.0000002 ], dtype=float32),
#  array([0.9999989 , 0.00000112], dtype=float32),
#  array([0.99999726, 0.00000272], dtype=float32),
#  array([0.99999917, 0.00000078], dtype=float32),
#  array([0.99999905, 0.0000009 ], dtype=float32),
#  array([0.99999964, 0.00000038], dtype=float32),
#  array([0.9999987 , 0.00000134], dtype=float32),
#  array([0.99999976, 0.00000019], dtype=float32),
#  array([0.9999995 , 0.00000045], dtype=float32),
#  array([0.99999964, 0.00000037], dtype=float32),
#  array([0.9999999 , 0.00000017], dtype=float32),
#  array([0.9999999, 0.0000001], dtype=float32),
#  array([0.9999999 , 0.00000017], dtype=float32),
#  array([0.9999999, 0.0000001], dtype=float32),
#  array([0.99999976, 0.00000028], dtype=float32),
#  array([0.9999999, 0.0000001], dtype=float32),
#  array([0.9999999 , 0.00000015], dtype=float32),
#  array([0.9999995 , 0.00000048], dtype=float32),
#  array([0.99999905, 0.00000097], dtype=float32),
#  array([0.99999654, 0.0000035 ], dtype=float32),
#  array([0.99999905, 0.000001  ], dtype=float32),
#  array([0.9999962 , 0.00000376], dtype=float32),
#  array([0.9999993 , 0.00000069], dtype=float32),
#  array([0.99999976, 0.00000021], dtype=float32),
#  array([0.9999999 , 0.00000015], dtype=float32),
#  array([0.99999964, 0.00000032], dtype=float32),
#  array([0.99999964, 0.00000041], dtype=float32),
#  array([0.99999845, 0.00000158], dtype=float32),
#  array([0.9999908 , 0.00000918], dtype=float32),
#  array([0.9999987 , 0.00000126], dtype=float32),
#  array([0.99999976, 0.0000002 ], dtype=float32),
#  array([0.9999932 , 0.00000679], dtype=float32),
#  array([0.99999595, 0.00000411], dtype=float32),
#  array([0.9999999 , 0.00000012], dtype=float32),
#  array([0.99999833, 0.00000168], dtype=float32),
#  array([0.9999999 , 0.00000014], dtype=float32),
#  array([0.9999999 , 0.00000013], dtype=float32),
#  array([0.9999995 , 0.00000042], dtype=float32),
#  array([0.9999994 , 0.00000065], dtype=float32),
#  array([0.9999995, 0.0000005], dtype=float32),
#  array([0.9999999 , 0.00000013], dtype=float32),
#  array([0.99999964, 0.00000038], dtype=float32),
#  array([0.99999964, 0.00000036], dtype=float32),
#  array([0.9999999 , 0.00000014], dtype=float32),
#  array([0.99999964, 0.00000035], dtype=float32),
#  array([0.9999993 , 0.00000069], dtype=float32),
#  array([0.9999995 , 0.00000046], dtype=float32),
#  array([0.99999976, 0.00000019], dtype=float32),
#  array([0.9999995 , 0.00000052], dtype=float32),
#  array([0.99999964, 0.00000038], dtype=float32),
#  array([0.9999999 , 0.00000013], dtype=float32),
#  array([0.9999994 , 0.00000061], dtype=float32),
#  array([0.99999976, 0.00000028], dtype=float32),
#  array([0.9999999 , 0.00000014], dtype=float32),
#  array([0.9999999 , 0.00000009], dtype=float32),
#  array([0.9999993 , 0.00000075], dtype=float32),
#  array([0.9999968 , 0.00000319], dtype=float32),
#  array([0.99999976, 0.00000018], dtype=float32),
#  array([0.99999976, 0.00000029], dtype=float32),
#  array([0.9999999, 0.0000001], dtype=float32),
#  array([0.9999988 , 0.00000115], dtype=float32),
#  array([0.9999994 , 0.00000061], dtype=float32),
#  array([0.9999999 , 0.00000015], dtype=float32),
#  array([0.9999999 , 0.00000012], dtype=float32),
#  array([0.9999999, 0.0000001], dtype=float32),
#  array([0.9999981 , 0.00000192], dtype=float32),
#  array([0.9999999, 0.0000001], dtype=float32),
#  array([0.99999976, 0.00000021], dtype=float32),
#  array([0.99999964, 0.00000031], dtype=float32),
#  array([0.9999999, 0.0000001], dtype=float32),
#  array([0.9999999 , 0.00000016], dtype=float32),
#  array([0.9999999, 0.0000001], dtype=float32),
#  array([0.9999999 , 0.00000009], dtype=float32),
#  array([0.9999999 , 0.00000009], dtype=float32),
#  array([0.9999999, 0.0000001], dtype=float32),
#  array([0.9999999 , 0.00000016], dtype=float32),
#  array([0.9999999 , 0.00000013], dtype=float32),
#  array([0.9999999 , 0.00000009], dtype=float32),
#  array([0.9999999 , 0.00000009], dtype=float32),
#  array([0.9999999, 0.0000001], dtype=float32),
#  array([0.9999981 , 0.00000189], dtype=float32),
#  array([0.9999999 , 0.00000012], dtype=float32),
#  array([0.9999976 , 0.00000233], dtype=float32),
#  array([0.99999785, 0.00000213], dtype=float32),
#  array([0.9999995 , 0.00000046], dtype=float32),
#  array([0.9999999 , 0.00000009], dtype=float32),
#  array([0.9999999 , 0.00000011], dtype=float32),
#  array([0.9999968 , 0.00000319], dtype=float32),
#  array([0.9999993 , 0.00000067], dtype=float32),
#  array([0.9999999 , 0.00000016], dtype=float32),
#  array([0.9999994 , 0.00000064], dtype=float32),
#  array([0.9999995 , 0.00000046], dtype=float32),
#  array([0.9999999, 0.0000001], dtype=float32),
#  array([0.9999999 , 0.00000012], dtype=float32),
#  array([0.99999976, 0.00000019], dtype=float32),
#  array([0.99999976, 0.00000024], dtype=float32),
#  array([0.9999913 , 0.00000869], dtype=float32),
#  array([0.9999956 , 0.00000436], dtype=float32),
#  array([0.99999976, 0.00000028], dtype=float32),
#  array([0.9999999 , 0.00000011], dtype=float32),
#  array([0.9999999 , 0.00000012], dtype=float32),
#  array([0.99999964, 0.00000035], dtype=float32),
#  array([0.9999993 , 0.00000068], dtype=float32),
#  array([0.9999999, 0.0000001], dtype=float32),
#  array([0.9999999 , 0.00000011], dtype=float32),
#  array([0.9999999, 0.0000001], dtype=float32),
#  array([0.9999999 , 0.00000016], dtype=float32),
#  array([0.9999999, 0.0000001], dtype=float32),
#  array([0.9999999 , 0.00000018], dtype=float32),
#  array([0.9999999 , 0.00000011], dtype=float32),
#  array([0.9999999 , 0.00000009], dtype=float32),
#  array([0.9999999, 0.0000001], dtype=float32),
#  array([0.9999999 , 0.00000012], dtype=float32),
#  array([0.9999999, 0.0000001], dtype=float32),
#  array([0.9999999 , 0.00000012], dtype=float32),
#  array([0.9999999 , 0.00000009], dtype=float32),
#  array([0.9999999 , 0.00000009], dtype=float32),
#  array([0.9999999 , 0.00000012], dtype=float32),
#  array([0.99999976, 0.00000021], dtype=float32),
#  array([0.9999999 , 0.00000017], dtype=float32),
#  array([0.9999999 , 0.00000016], dtype=float32),
#  array([0.9999994 , 0.00000057], dtype=float32),
#  array([0.9999999 , 0.00000012], dtype=float32),
#  array([0.9999999 , 0.00000009], dtype=float32),
#  array([0.9999999, 0.0000001], dtype=float32),
#  array([0.9999999, 0.0000001], dtype=float32),
#  array([0.9999999, 0.0000001], dtype=float32),
#  array([0.9999999 , 0.00000009], dtype=float32),
#  array([0.9999999 , 0.00000017], dtype=float32),
#  array([0.9999999 , 0.00000014], dtype=float32),
#  array([0.9999999 , 0.00000009], dtype=float32),
#  array([0.99999976, 0.00000029], dtype=float32),
#  array([0.99999976, 0.00000025], dtype=float32),
#  array([0.9999999 , 0.00000009], dtype=float32),
#  array([0.99999964, 0.00000035], dtype=float32),
#  array([0.9999999, 0.0000001], dtype=float32),
#  array([0.9999999 , 0.00000009], dtype=float32),
#  array([0.9999995 , 0.00000053], dtype=float32),
#  array([0.9999995 , 0.00000046], dtype=float32),
#  array([0.9999999 , 0.00000011], dtype=float32),
#  array([0.9999999, 0.0000001], dtype=float32),
#  array([0.99999964, 0.00000041], dtype=float32),
#  array([0.9999999 , 0.00000013], dtype=float32),
#  array([0.9999995 , 0.00000045], dtype=float32),
#  array([0.9999988 , 0.00000124], dtype=float32),
#  array([0.9999993 , 0.00000074], dtype=float32),
#  array([0.99999905, 0.00000101], dtype=float32),
#  array([0.9999987 , 0.00000127], dtype=float32),
#  array([0.99999857, 0.00000139], dtype=float32),
#  array([0.9999993 , 0.00000066], dtype=float32),
#  array([0.9999999 , 0.00000016], dtype=float32),
#  array([0.9999987 , 0.00000137], dtype=float32),
#  array([0.9999995 , 0.00000043], dtype=float32),
#  array([0.99999976, 0.00000021], dtype=float32),
#  array([0.9999999 , 0.00000014], dtype=float32),
#  array([0.9999988 , 0.00000115], dtype=float32),
#  array([0.99999607, 0.00000389], dtype=float32),
#  array([0.99999964, 0.00000035], dtype=float32),
#  array([0.9999994 , 0.00000064], dtype=float32),
#  array([0.9999993, 0.0000007], dtype=float32),
#  array([0.9999963, 0.0000037], dtype=float32),
#  array([0.9999988 , 0.00000119], dtype=float32),
#  array([0.9999995 , 0.00000045], dtype=float32),
#  array([0.99999905, 0.00000093], dtype=float32),
#  array([0.99999964, 0.00000038], dtype=float32),
#  array([0.99999857, 0.00000146], dtype=float32),
#  array([0.99999976, 0.00000019], dtype=float32),
#  array([0.99999964, 0.00000032], dtype=float32),
#  array([0.9999987 , 0.00000129], dtype=float32),
#  array([0.9999999 , 0.00000017], dtype=float32),
#  array([0.99999976, 0.00000028], dtype=float32),
#  array([0.9999995 , 0.00000043], dtype=float32),
#  array([0.99999976, 0.00000018], dtype=float32),
#  array([0.9999999 , 0.00000017], dtype=float32),
#  array([0.99999976, 0.00000019], dtype=float32),
#  array([0.9999995 , 0.00000052], dtype=float32),
#  array([0.9999993 , 0.00000075], dtype=float32),
#  array([0.99999976, 0.00000021], dtype=float32),
#  array([0.99999976, 0.00000027], dtype=float32),
#  array([0.9999999 , 0.00000017], dtype=float32),
#  array([0.9999989 , 0.00000109], dtype=float32),
#  array([0.99999905, 0.00000099], dtype=float32),
#  array([0.99999833, 0.00000164], dtype=float32),
#  array([0.9999974 , 0.00000259], dtype=float32),
#  array([0.9999993 , 0.00000074], dtype=float32),
#  array([0.99999976, 0.00000021], dtype=float32),
#  array([0.99999917, 0.00000086], dtype=float32),
#  array([0.9999702 , 0.00002981], dtype=float32),
#  array([0.99999666, 0.00000331], dtype=float32),
#  array([0.9999994 , 0.00000054], dtype=float32),
#  array([0.9999974, 0.0000026], dtype=float32),
#  array([0.9999976 , 0.00000234], dtype=float32),
#  array([0.9999995 , 0.00000045], dtype=float32),
#  array([0.99999964, 0.00000034], dtype=float32),
#  array([0.9999968 , 0.00000321], dtype=float32),
#  array([0.9999994 , 0.00000064], dtype=float32),
#  array([0.9999778 , 0.00002218], dtype=float32),
#  array([0.9999964 , 0.00000357], dtype=float32),
#  array([0.99999964, 0.00000032], dtype=float32),
#  array([0.99999976, 0.00000023], dtype=float32),
#  array([0.99999976, 0.0000002 ], dtype=float32),
#  array([0.9999989 , 0.00000112], dtype=float32),
#  array([0.99999726, 0.00000272], dtype=float32),
#  array([0.99999917, 0.00000078], dtype=float32),
#  array([0.99999905, 0.0000009 ], dtype=float32),
#  array([0.99999964, 0.00000038], dtype=float32),
#  array([0.9999987 , 0.00000134], dtype=float32),
#  array([0.99999976, 0.00000019], dtype=float32),
#  array([0.9999995 , 0.00000045], dtype=float32),
#  array([0.99999964, 0.00000037], dtype=float32),
#  array([0.9999999 , 0.00000017], dtype=float32),
#  array([0.9999999, 0.0000001], dtype=float32),
#  array([0.9999999 , 0.00000017], dtype=float32),
#  array([0.9999999, 0.0000001], dtype=float32),
#  array([0.99999976, 0.00000028], dtype=float32),
#  array([0.9999999, 0.0000001], dtype=float32),
#  array([0.9999999 , 0.00000015], dtype=float32),
#  array([0.9999995 , 0.00000048], dtype=float32),
#  array([0.99999905, 0.00000097], dtype=float32),
#  array([0.99999654, 0.0000035 ], dtype=float32),
#  array([0.99999905, 0.000001  ], dtype=float32),
#  array([0.9999962 , 0.00000376], dtype=float32),
#  array([0.9999993 , 0.00000069], dtype=float32),
#  array([0.99999976, 0.00000021], dtype=float32),
#  array([0.9999999 , 0.00000015], dtype=float32),
#  array([0.99999964, 0.00000032], dtype=float32),
#  array([0.99999964, 0.00000041], dtype=float32),
#  array([0.99999845, 0.00000158], dtype=float32),
#  array([0.9999908 , 0.00000918], dtype=float32),
#  array([0.9999987 , 0.00000126], dtype=float32),
#  array([0.99999976, 0.0000002 ], dtype=float32),
#  array([0.9999932 , 0.00000679], dtype=float32),
#  array([0.99999595, 0.00000411], dtype=float32),
#  array([0.9999999 , 0.00000012], dtype=float32),
#  array([0.99999833, 0.00000168], dtype=float32),
#  array([0.9999999 , 0.00000014], dtype=float32),
#  array([0.9999999 , 0.00000013], dtype=float32),
#  array([0
#  array([0.9999943, 0.0000057], dtype=float32),
#  array([0.9999976 , 0.00000241], dtype=float32),
#  array([0.99999595, 0.00000404], dtype=float32),
#  array([0.99999094, 0.00000909], dtype=float32),
#  array([0.9999908 , 0.00000922], dtype=float32),
#  array([0.999997  , 0.00000298], dtype=float32),
#  array([0.99999607, 0.00000396], dtype=float32),
#  array([0.9999957 , 0.00000431], dtype=float32),
#  array([0.99999857, 0.00000143], dtype=float32),
#  array([0.9999994 , 0.00000057], dtype=float32),
#  array([0.99999845, 0.0000015 ], dtype=float32),
#  array([0.99999917, 0.00000085], dtype=float32),
#  array([0.9999982 , 0.00000185], dtype=float32),
#  array([0.9999987 , 0.00000132], dtype=float32),
#  array([0.9999987 , 0.00000133], dtype=float32),
#  array([0.9999988 , 0.00000117], dtype=float32),
#  array([0.9999962, 0.0000038], dtype=float32),
#  array([0.99999666, 0.00000333], dtype=float32),
#  array([0.9999989 , 0.00000102], dtype=float32),
#  array([0.9999976 , 0.00000235], dtype=float32),
#  array([0.9999974 , 0.00000264], dtype=float32),
#  array([0.9999949 , 0.00000518], dtype=float32),
#  array([0.99999774, 0.00000227], dtype=float32),
#  array([0.9999957 , 0.00000429], dtype=float32),
#  array([0.9999975 , 0.00000254], dtype=float32),
#  array([0.9999982 , 0.00000174], dtype=float32),
#  array([0.99999666, 0.00000329], dtype=float32),
#  array([0.9999974 , 0.00000258], dtype=float32),
#  array([0.99999857, 0.00000142], dtype=float32),
#  array([0.9999981 , 0.00000186], dtype=float32),
#  array([0.9999969 , 0.00000306], dtype=float32),
#  array([0.9999989 , 0.00000106], dtype=float32),
#  array([0.9999956 , 0.00000435], dtype=float32),
#  array([0.99999845, 0.0000015 ], dtype=float32),
#  array([0.99999845, 0.00000158], dtype=float32),
#  array([0.99999774, 0.00000232], dtype=float32),
#  array([0.9999988 , 0.00000122], dtype=float32),
#  array([0.9999989 , 0.00000109], dtype=float32),
#  array([0.99999857, 0.00000138], dtype=float32),
#  array([0.99999845, 0.00000153], dtype=float32),
#  array([0.9999987 , 0.00000126], dtype=float32),
#  ...]

# %% [markdown]
# # recover_bag_color(from_sk)

# %%
test_cases = ['case00','case01','case02','case03','case04',
              'case04','case05','case06','case05','case09', 'case10']

totalscore = []

test_category = "recover_bag_color(from_sk)"
print("test_category: {}".format(test_category))

for select_cases in test_cases:

    # prepare testing data
    test_dataset_C = glob('D:\\GitHub\\analysis_generated_pictures\\category\\{}\\{}\\cyclecoopnet\\*.png'.format(test_category, select_cases))
   
    for sample_index in test_dataset_C: 

    #     print(sample_index)
        test_img = cv2.imread(sample_index)
        # print(test_cat)
    #     cv2.imshow('My Image', test_cat)

        test_img = cv2.resize(test_img, (img_size, img_size), cv2.INTER_LINEAR) / 255

    #     preview_cat = plt.imshow(test_cat.reshape(img_size, img_size, num_channels))

        np.set_printoptions(suppress=True)

        results = sample_prediction(test_img)
    #     print("Predicted class for test_cat: {}, score: {}".format(results[0], results[1]))

    #     print(len(results[1][0]))
    #     print(results[1][0][1])
        totalscore.append(results[1][0])

        
        
        
print("cyclecoopnet:")        
print(len(totalscore))
# print(totalscore)
print(sum(totalscore)/len(totalscore))

totalscore = []

for select_cases in test_cases:

    # prepare testing data
    test_dataset_C = glob('D:\\GitHub\\analysis_generated_pictures\\category\\{}\\{}\\cyclegan\\*.png'.format(test_category, select_cases))
   
    for sample_index in test_dataset_C: 

    #     print(sample_index)
        test_img = cv2.imread(sample_index)
        # print(test_cat)
    #     cv2.imshow('My Image', test_cat)

        test_img = cv2.resize(test_img, (img_size, img_size), cv2.INTER_LINEAR) / 255

    #     preview_cat = plt.imshow(test_cat.reshape(img_size, img_size, num_channels))

        np.set_printoptions(suppress=True)

        results = sample_prediction(test_img)
    #     print("Predicted class for test_cat: {}, score: {}".format(results[0], results[1]))

    #     print(len(results[1][0]))
    #     print(results[1][0][1])
        totalscore.append(results[1][0])

        
        
        
print("cyclegan:")        
print(len(totalscore))
# print(totalscore)
print(sum(totalscore)/len(totalscore))

# for select_cases in test_cases:

#     # prepare testing data
#     test_dataset_C = glob('D:\\GitHub\\analysis_generated_pictures\\category\\{}\\{}\\pix2pix\\*.png'.format(test_category, select_cases))
   
#     for sample_index in test_dataset_C: 

#     #     print(sample_index)
#         test_img = cv2.imread(sample_index)
#         # print(test_cat)
#     #     cv2.imshow('My Image', test_cat)

#         test_img = cv2.resize(test_img, (img_size, img_size), cv2.INTER_LINEAR) / 255

#     #     preview_cat = plt.imshow(test_cat.reshape(img_size, img_size, num_channels))

#         np.set_printoptions(suppress=True)

#         results = sample_prediction(test_img)
#     #     print("Predicted class for test_cat: {}, score: {}".format(results[0], results[1]))

#     #     print(len(results[1][0]))
#     #     print(results[1][0][1])
#         totalscore.append(results[1][0])

        
        
        
# print("pix2pix:")         
# print(len(totalscore))
# # print(totalscore)
# print(sum(totalscore)/len(totalscore))

# %% [markdown]
# # recover_bag_sk(from_color)

# %%
test_cases = ['case00','case01','case02','case03','case04',
              'case04','case05','case06','case05','case09', 'case10']

totalscore = []

test_category = "recover_bag_sk(from_color)"
print("test_category: {}".format(test_category))

for select_cases in test_cases:

    # prepare testing data
    test_dataset_C = glob('D:\\GitHub\\analysis_generated_pictures\\category\\{}\\{}\\cyclecoopnet\\*.png'.format(test_category, select_cases))
   
    for sample_index in test_dataset_C: 

    #     print(sample_index)
        test_img = cv2.imread(sample_index)
        # print(test_cat)
    #     cv2.imshow('My Image', test_cat)

        test_img = cv2.resize(test_img, (img_size, img_size), cv2.INTER_LINEAR) / 255

    #     preview_cat = plt.imshow(test_cat.reshape(img_size, img_size, num_channels))

        np.set_printoptions(suppress=True)

        results = sample_prediction(test_img)
    #     print("Predicted class for test_cat: {}, score: {}".format(results[0], results[1]))

    #     print(len(results[1][0]))
    #     print(results[1][0][1])
        totalscore.append(results[1][0])

        
        
        
print("cyclecoopnet:")        
print(len(totalscore))
# print(totalscore)
print(sum(totalscore)/len(totalscore))

totalscore = []

for select_cases in test_cases:

    # prepare testing data
    test_dataset_C = glob('D:\\GitHub\\analysis_generated_pictures\\category\\{}\\{}\\cyclegan\\*.png'.format(test_category, select_cases))
   
    for sample_index in test_dataset_C: 

    #     print(sample_index)
        test_img = cv2.imread(sample_index)
        # print(test_cat)
    #     cv2.imshow('My Image', test_cat)

        test_img = cv2.resize(test_img, (img_size, img_size), cv2.INTER_LINEAR) / 255

    #     preview_cat = plt.imshow(test_cat.reshape(img_size, img_size, num_channels))

        np.set_printoptions(suppress=True)

        results = sample_prediction(test_img)
    #     print("Predicted class for test_cat: {}, score: {}".format(results[0], results[1]))

    #     print(len(results[1][0]))
    #     print(results[1][0][1])
        totalscore.append(results[1][0])

        
        
        
print("cyclegan:")        
print(len(totalscore))
# print(totalscore)
print(sum(totalscore)/len(totalscore))

# for select_cases in test_cases:

#     # prepare testing data
#     test_dataset_C = glob('D:\\GitHub\\analysis_generated_pictures\\category\\{}\\{}\\pix2pix\\*.png'.format(test_category, select_cases))
   
#     for sample_index in test_dataset_C: 

#     #     print(sample_index)
#         test_img = cv2.imread(sample_index)
#         # print(test_cat)
#     #     cv2.imshow('My Image', test_cat)

#         test_img = cv2.resize(test_img, (img_size, img_size), cv2.INTER_LINEAR) / 255

#     #     preview_cat = plt.imshow(test_cat.reshape(img_size, img_size, num_channels))

#         np.set_printoptions(suppress=True)

#         results = sample_prediction(test_img)
#     #     print("Predicted class for test_cat: {}, score: {}".format(results[0], results[1]))

#     #     print(len(results[1][0]))
#     #     print(results[1][0][1])
#         totalscore.append(results[1][0])

        
        
        
# print("pix2pix:")         
# print(len(totalscore))
# # print(totalscore)
# print(sum(totalscore)/len(totalscore))

# %%
def get_score_cyclegan(case_no, pic_no):
    picture_index_gen = "D:\\GitHub\\!_results\\cyclegan\\10_bags\\sample\\{}\\A_gen\\testA_{}_ep{}_03_gen_A.png".format(case_no, case_no, pic_no)
#     print(picture_index_gen)
    
#     D:\GitHub\!_results\cycleGAN\10_bags\sample\00\A_gen
#     testA_00_ep02_03_gen_A

    each_score = 1
    img_size = 256
    num_channels = 3

    test_img_gen = cv2.imread(picture_index_gen)
#     preview_pic_gen = plt.imshow(test_img_gen.reshape(img_size, img_size, num_channels))

#     np.set_printoptions(suppress=True)

    test_img_gen = cv2.resize(test_img_gen, (img_size, img_size), cv2.INTER_LINEAR) / 255

    results_gen = sample_prediction(test_img_gen)
#     print(results_gen[0])

#     print("Predicted class: {}, score: {}".format(results_gen[0], results_gen[1]))





    

    if results_gen[0] == "bags":
        each_score = each_score * 1
#         print("gen correct")
    elif results_gen[0] == "edges":
        each_score = each_score * 0
#         print("gen wrong")
    else:
        raise BaseException("Error")

#     print(each_score)
    
    # ----------------------------------------------- #
    
    picture_index_recover = "D:\\GitHub\\!_results\\cyclegan\\10_bags\\sample\\{}\\A_recover\\testA_{}_ep{}_05_recovered_A.png".format(case_no, case_no, pic_no)
#     print(picture_index_recover)

    test_img_recover = cv2.imread(picture_index_recover)
#     preview_pic_recover = plt.imshow(test_img_recover.reshape(img_size, img_size, num_channels))

    test_img_recover = cv2.resize(test_img_recover, (img_size, img_size), cv2.INTER_LINEAR) / 255


    results_recover = sample_prediction(test_img_recover)
#     print("Predicted class: {}, score: {}".format(results_recover[0], results_recover[1]))
    
    if results_gen[0] == "bags":
        each_score = each_score * 1
#         print("recover correct")
    elif results_gen[0] == "edges":
        each_score = each_score * 0
#         print("recover wrong")
    else:
        raise BaseException("Error")

#     print(each_score)
    
    
    return each_score

# %%
def get_score_cyclecoopnet(case_no, pic_no):
    picture_index_gen = "D:\\GitHub\\!_results\\cyclecoopnet\\10_bags\\sample\\{}\\A_gen\\testA_{}_ep{}_03_gen_A.png".format(case_no, case_no, pic_no)
#     print(picture_index_gen)

    each_score = 1
    img_size = 256
    num_channels = 3

    test_img_gen = cv2.imread(picture_index_gen)
#     preview_pic_gen = plt.imshow(test_img_gen.reshape(img_size, img_size, num_channels))

#     np.set_printoptions(suppress=True)

    test_img_gen = cv2.resize(test_img_gen, (img_size, img_size), cv2.INTER_LINEAR) / 255

    results_gen = sample_prediction(test_img_gen)
#     print(results_gen[0])

#     print("Predicted class: {}, score: {}".format(results_gen[0], results_gen[1]))





    

    if results_gen[0] == "bags":
        each_score = each_score * 1
#         print("gen correct")
    elif results_gen[0] == "edges":
        each_score = each_score * 0
#         print("gen wrong")
    else:
        raise BaseException("Error")

#     print(each_score)
    
    # ----------------------------------------------- #
    
    picture_index_recover = "D:\\GitHub\\!_results\\cyclecoopnet\\10_bags\\sample\\{}\\A_recover\\testA_{}_ep{}_05_recovered_A.png".format(case_no, case_no, pic_no)
#     print(picture_index_recover)

    test_img_recover = cv2.imread(picture_index_recover)
#     preview_pic_recover = plt.imshow(test_img_recover.reshape(img_size, img_size, num_channels))

    test_img_recover = cv2.resize(test_img_recover, (img_size, img_size), cv2.INTER_LINEAR) / 255


    results_recover = sample_prediction(test_img_recover)
#     print("Predicted class: {}, score: {}".format(results_recover[0], results_recover[1]))
    
    if results_gen[0] == "bags":
        each_score = each_score * 1
#         print("recover correct")
    elif results_gen[0] == "edges":
        each_score = each_score * 0
#         print("recover wrong")
    else:
        raise BaseException("Error")

#     print(each_score)
    
    
    return each_score

# %% [markdown]
# # single generate score

# %%
test_cases = ['00','01','02','03','04',
              '05','06','07','08','09','10']

total_score_cyclecoopnet = 0
total_score_cyclegan = 0


# # 114-213  
for case_no in test_cases:
    print("case: {}".format(case_no))
    for pic_no in range(114, 214):
    #     print(i)
        total_score_cyclecoopnet = total_score_cyclecoopnet + get_score_cyclecoopnet(case_no, pic_no)
        total_score_cyclegan = total_score_cyclegan + get_score_cyclegan(case_no, pic_no)
    
print("cyclecoopnet = {}".format(total_score_cyclecoopnet))
print("cyclegan = {}".format(total_score_cyclegan))
# Out:
# case: 00
# case: 01
# case: 02
# case: 03
# case: 04
# case: 05
# case: 06
# case: 07
# case: 08
# case: 09
# case: 10
# 1100
# 1090

# %%
picture_index_gen = "D:\\GitHub\\analysis_generated_pictures\\category\\bag_color(from_sk)\\case03\\real.jpg"



# picture_index_gen = "D:\\GitHub\\!_results\\cyclecoopnet\\10_bags\\sample\\00\\A_gen\\testA_00_ep{}_03_gen_A.png".format(219)

print(picture_index_gen)

img_size = 256
num_channels = 3

test_img_gen = cv2.imread(picture_index_gen)
preview_pic_gen = plt.imshow(test_img_gen.reshape(img_size, img_size, num_channels))

np.set_printoptions(suppress=True)

results_gen = sample_prediction(test_img_gen)

print("Predicted class: {}, score: {}".format(results_gen[0], results_gen[1]))

each_score = 1

if results_gen[0] == "bags":
    each_score = each_score * 1
    print("gen correct")
elif results_gen[0] == "edges":
    each_score = each_score * 0
    print("gen wrong")
else:
    raise BaseException("Error")
    
print(each_score)
# Out:
# D:\GitHub\analysis_generated_pictures\category\bag_color(from_sk)\case03\real.jpg
# Predicted class: bags, score: [[0. 1.]]
# gen correct
# 1

# %%
# picture_index_recover = "D:\GitHub\\!_results\\cyclecoopnet\\10_bags\\sample\\00\\A_recover\\real.jpg"

picture_index_recover = "D:\\GitHub\\!_results\\cyclecoopnet\\10_bags\\sample\\00\\A_recover\\testA_00_ep{}_05_recovered_A.png".format(299)

print(picture_index_recover)

img_size = 256
num_channels = 3

test_img_recover = cv2.imread(picture_index_recover)
preview_pic_recover = plt.imshow(test_img_recover.reshape(img_size, img_size, num_channels))


results_recover = sample_prediction(test_img_recover)
print("Predicted class: {}, score: {}".format(results_recover[0], results_recover[1]))
# Out:
# D:\GitHub\!_results\cyclecoopnet\10_bags\sample\00\A_recover\testA_00_ep299_05_recovered_A.png
# Predicted class: edges, score: [[1. 0.]]

# %%
np.set_printoptions(suppress=True)

results_gen = sample_prediction(test_img_gen)
print("Predicted class: {}, score: {}".format(results_gen[0], results_gen[1]))

results_recover = sample_prediction(test_img_recover)
print("Predicted class: {}, score: {}".format(results_recover[0], results_recover[1]))
# Out:
# Predicted class: edges, score: [[1. 0.]]
# Predicted class: edges, score: [[1. 0.]]

# %%
# test_cases = ['case00','case01','case02','case03','case04',
#               'case04','case05','case06','case05','case09', 'case10']

# # totalscore = []

# test_category = "bag_color(from_sk)"
# print("test_category: {}".format(test_category))


# # prepare testing data
# # test_dataset_C = glob('D:\\GitHub\\analysis_generated_pictures\\category\\{}\\{}\\cyclecoopnet\\*.png'.format(test_category, select_cases))
   
    
# # 114-216    
# picture_index_gen = "D:\\GitHub\\!_results\\cyclecoopnet\\10_bags\\sample\\00\\A_gen\\testA_00_ep{}_03_gen_A.png".format(121)

# print(picture_index_gen)


# # 114-216    
# picture_index_recover = "D:\\GitHub\\!_results\\cyclecoopnet\\10_bags\\sample\\00\\A_recover\\testA_00_ep{}_05_recovered_A.png".format(121)

# print(picture_index_recover)



# img_size = 256
# num_channels = 3

# test_img_gen = cv2.imread(picture_index_gen)
# preview_pic_gen = plt.imshow(test_img_gen.reshape(img_size, img_size, num_channels))

# test_img_recover = cv2.imread(picture_index_recover)
# preview_pic_recover = plt.imshow(test_img_recover.reshape(img_size, img_size, num_channels))

# for select_cases in test_cases:

    
#     for sample_index in test_dataset_C: 

#     #     print(sample_index)
#         test_img = cv2.imread(sample_index)
#         # print(test_cat)
#     #     cv2.imshow('My Image', test_cat)

#         test_img = cv2.resize(test_img, (img_size, img_size), cv2.INTER_LINEAR) / 255

#     #     preview_cat = plt.imshow(test_cat.reshape(img_size, img_size, num_channels))

#         np.set_printoptions(suppress=True)

#         results = sample_prediction(test_img)
#     #     print("Predicted class for test_cat: {}, score: {}".format(results[0], results[1]))

#     #     print(len(results[1][0]))
#     #     print(results[1][0][1])
#         totalscore.append(results[1][0])

        
        
        
# print("cyclecoopnet:")        
# print(len(totalscore))
# # print(totalscore)
# print(sum(totalscore)/len(totalscore))
